# %% [markdown]
# # Exploring Terms in the Encyclopaedia Britannica

# %% [markdown]
# ### Loading the necessary libraries

# %%
import yaml
import matplotlib.pyplot as plt
import numpy as np
import collections
import matplotlib as mpl

# %%
import pandas as pd
from yaml import safe_load
from pandas.io.json import json_normalize

# %% [markdown]
# ## We have dataframe with these information
#
#
# - definition:           Definition of the article
# - edition_num:          1,2,3,4,5,6,7,8
# - header:               Header of the page's article
# - num_article_words:    Number of words per article
# - place:                Place where the volume was edited (e.g. Edinburgh)
# - related_terms:        Related articles (see X article)
# - source_text_file:     File Path of the XML file from which the article belongs
# - term:                 Article name
# - term_id_in_page:      Number of article in the page
# - start_page:           Number page in which the article starts
# - end_page:             Number page in which the article ends
# - title:               Title of the Volume
# - type_article:            Type of Page [Full Page| Topic| Mix | Articles]
# - year:                 Year of the Volume
# - volume:               volume (e.g. 1)
# - letters:              leters of the volume (A-B)

# %% [markdown]
# ### 1. Load dataframe from JSON file

# %%
df = pd.read_json('./results_NLS/results_eb_1_edition_postprocess_dataframe', orient="index")

# %%
df = df[["term", "definition", "related_terms", "num_article_words", "header", "start_page", "end_page",  "term_id_in_page", "type_article", "edition_num", "volume", "letters", "year", "title",  "place", "source_text_file"  ]]
df
# Out:
#                term                                         definition  \
# 1      FIRSTARTICLE                          S :u -I >;J .1 M U a C V'
# 10              AAM  a Dutch measure for liquids, containing about ...
# 100        ABEYANCE  in law, the expedtancy of an edate. Thus if la...
# 1000        ALCACER  de Sal, or Alcarez, a town of Portugal in the ...
# 10000    NYCTALOPIA  in medicine, a two-sold disorder or the eye, o...
# ...             ...                                                ...
# 9995         NUTMEG  the kernel of a large fruit, not unlike the Th...
# 9996      NUTRITION  in the animal ceconomy, is the repairing the c...
# 9997           NUYS       a town of Germany, twenty miles north of Co-
# 9998        INYBURG  a town of Denmark, situated at the eafiend of ...
# 9999   NYCHTHEMERON  the natural day, or day and night, which toget...
#
#                                            related_terms  num_article_words  \
# 1                                                     []                 10
# 10                                                    []                 17
# 100                                                   []                 36
# 1000                                                  []                 26
# 10000                                                 []                 67
# ...                                                  ...                ...
# 9995   [MACE, PEEMED, DUTCH, THELARGEFT, EAP-INDIES, ...                451
# 9996                                         [PISTACHIA]                486
# 9997                                                  []                  9
# 9998                                                  []                 25
# 9999                                                  []                 13
#
#                         header  start_page  end_page  term_id_in_page  \
# 1                        **■*            8         8                0
# 10     EncyclopaediaBritannica          15        15                5
# 100                        ABE          18        18                0
# 1000                    ALBALC         106       106               24
# 10000                   NYBNYS         473       473                4
# ...                        ...         ...       ...              ...
# 9995                    NUTNUT         472       472               10
# 9996                    NUTNUT         472       473               11
# 9997                    NYBNYS         473       473                1
# 9998                    NYBNYS         473       473                2
# 9999                    NYBNYS         473       473                3
#
#       type_article  edition_num  volume letters  year  \
# 1          Article            1       1     A-B  1771
# 10         Article            1       1     A-B  1771
# 100        Article            1       1     A-B  1771
# 1000           Mix            1       1     A-B  1771
# 10000      Article            1       3     M-Z  1771
# ...            ...          ...     ...     ...   ...
# 9995       Article            1       3     M-Z  1771
# 9996       Article            1       3     M-Z  1771
# 9997       Article            1       3     M-Z  1771
# 9998       Article            1       3     M-Z  1771
# 9999       Article            1       3     M-Z  1771
#
#                                                    title      place  \
# 1      Encyclopaedia Britannica; or, A dictionary of ...  Edinburgh
# 10     Encyclopaedia Britannica; or, A dictionary of ...  Edinburgh
# 100    Encyclopaedia Britannica; or, A dictionary of ...  Edinburgh
# 1000   Encyclopaedia Britannica; or, A dictionary of ...  Edinburgh
# 10000  Encyclopaedia Britannica; or, A dictionary of ...  Edinburgh
# ...                                                  ...        ...
# 9995   Encyclopaedia Britannica; or, A dictionary of ...  Edinburgh
# 9996   Encyclopaedia Britannica; or, A dictionary of ...  Edinburgh
# 9997   Encyclopaedia Britannica; or, A dictionary of ...  Edinburgh
# 9998   Encyclopaedia Britannica; or, A dictionary of ...  Edinburgh
# 9999   Encyclopaedia Britannica; or, A dictionary of ...  Edinburgh
#
#                       source_text_file
# 1      144133901/alto/188082813.34.xml
# 10     144133901/alto/188082904.34.xml
# 100    144133901/alto/188082943.34.xml
# 1000   144133901/alto/188084090.34.xml
# 10000  144133903/alto/144810223.34.xml
# ...                                ...
# 9995   144133903/alto/144810211.34.xml
# 9996   144133903/alto/144810211.34.xml
# 9997   144133903/alto/144810223.34.xml
# 9998   144133903/alto/144810223.34.xml
# 9999   144133903/alto/144810223.34.xml
#
# [27455 rows x 16 columns]

# %% [markdown]
# ### 2. Group results by year

# %%
df.groupby("year").count()
# Out:
#        term  definition  related_terms  num_article_words  header  start_page  \
# year
# 1771  13623       13623          13623              13623   13623       13623
# 1773  13832       13832          13832              13832   13832       13832
#
#       end_page  term_id_in_page  type_article  edition_num  volume  letters  \
# year
# 1771     13623            13623         13623        13623   13623    13623
# 1773     13832            13832         13832        13832   13832    13832
#
#       title  place  source_text_file
# year
# 1771  13623  13623             13623
# 1773  13832  13832             13832

# %% [markdown]
# #### Remark:
# So, we have 13623 terms in 1771 and 13832 terms in 1773. Note, that some of those terms can be repeated

# %% [markdown]
# ### 3. Group results by letters

# %%
df.groupby("letters").count()
# Out:
#           term  definition  related_terms  num_article_words  header  \
# letters
#  A-B      7906        7906           7906               7906    7906
#  C-L     10172       10172          10172              10172   10172
#  M-Z      9377        9377           9377               9377    9377
#
#          start_page  end_page  term_id_in_page  type_article  edition_num  \
# letters
#  A-B           7906      7906             7906          7906         7906
#  C-L          10172     10172            10172         10172        10172
#  M-Z           9377      9377             9377          9377         9377
#
#          volume   year  title  place  source_text_file
# letters
#  A-B       7906   7906   7906   7906              7906
#  C-L      10172  10172  10172  10172             10172
#  M-Z       9377   9377   9377   9377              9377

# %% [markdown]
# ### 4. Group results by letters and years

# %%
df.groupby(['year', 'letters'])["letters"].count()
# Out:
# year  letters
# 1771   A-B       3900
#        C-L       5097
#        M-Z       4626
# 1773   A-B       4006
#        C-L       5075
#        M-Z       4751
# Name: letters, dtype: int64

# %% [markdown]
# #### Remark:
# Note, that some of those terms can be repeated

# %% [markdown]
# ### 5. Filtering by TERMS: ABACUS
#
# We are going to explore the term ABACUS
#
# Notice that the first edition of the EB, there 6 volumes, 3 published in 1771, and 3 published in 1773. However, the volumes from 1773 are a re-print from the ones of 1771.

# %%
df_by_term=df.groupby(['term', 'year'])["term"].count()
df_by_term["ABACUS"]
# Out:
# year
# 1771    4
# 1773    2
# Name: term, dtype: int64

# %% [markdown]
# ### 5.1 Exploring ABACUS in 1771
#
# We are going to explore the term "ABACUS" in the volumes from 1771.

# %%
abacus_df= df[df['term'].str.contains("ABACUS")]
abacus_df = abacus_df[abacus_df['year'] == 1771]
abacus_df
# Out:
#       term                                         definition related_terms  \
# 25  ABACUS  a table strewed over with dust or sand, upon w...            []
# 26  ABACUS  in architeflure, signifies the superior part o...            []
# 27  ABACUS  is also the name of an ancient instrument for ...            []
# 28  ABACUS  logijlicus, a right-angled triangle, whose sid...            []
#
#     num_article_words                   header  start_page  end_page  \
# 25                 23  EncyclopaediaBritannica          15        15
# 26                122  EncyclopaediaBritannica          15        16
# 27                125                   ABAABB          16        16
# 28                 50                   ABAABB          16        16
#
#     term_id_in_page type_article  edition_num  volume letters  year  \
# 25               20      Article            1       1     A-B  1771
# 26               21      Article            1       1     A-B  1771
# 27                1      Article            1       1     A-B  1771
# 28                2      Article            1       1     A-B  1771
#
#                                                 title      place  \
# 25  Encyclopaedia Britannica; or, A dictionary of ...  Edinburgh
# 26  Encyclopaedia Britannica; or, A dictionary of ...  Edinburgh
# 27  Encyclopaedia Britannica; or, A dictionary of ...  Edinburgh
# 28  Encyclopaedia Britannica; or, A dictionary of ...  Edinburgh
#
#                    source_text_file
# 25  144133901/alto/188082904.34.xml
# 26  144133901/alto/188082904.34.xml
# 27  144133901/alto/188082917.34.xml
# 28  144133901/alto/188082917.34.xml

# %% [markdown]
# #### Remark:
# So, the TERM "ABACUS" appears 4 times, across two pages.

# %% [markdown]
# #### 5.2 Getting the definnition for each of them

# %%
for i in abacus_df["definition"]:
    print ("ABACUS - Definition: %s" %i)
    print("---")
# Out:
# ABACUS - Definition: a table strewed over with dust or sand, upon which the ancient mathematicians drew their figures, It also signified a cupboard, or buffet.
# ---
# ABACUS - Definition: in architeflure, signifies the superior part or member of the capital of a column, and serves as a kind of crowning to both. It was originally intended to represent a square tile covering a basket. The form of the abacus is not the same in all orders: in the Tuscan, Doric, and Ionic, it‘is generally square; but in the Corinthian and Compofite, its four sides are arched ir Avards, and embellilhed in the middle withornament, as a rose or other flower, Scammozzi uses abacus for a concave moulding on the capital of the Tuscan pedefial; and Palladio calls the plinth above the echinus, or boultin, in the Tufean and Doric orders, by the same name. See plate I. fig. i. and
# ---
# ABACUS - Definition: is also the name of an ancient instrument for facilitating operations in arithmetic. It is vadoully contrived. That chiefly used in Europe is made by drawing any number of parallel lines at the di(lance of two diameters of one of the counters used in the calculation. A counter placed on.the lowed line, signifies r; on the sd, 10; on the 3d, 100; on the 4th, 1000, &c. In the intermediate spaces, the same counters are eflimated at one Jialf of the value of the line immediately superior, viz. between the id and 2d, 5; between the 2d and 3d, 50, &c. See plate I. fig. 2. A B, where the same number, 1768 for example, is represented under both by different dispositions of the counters.
# ---
# ABACUS - Definition: logijlicus, a right-angled triangle, whose sides forming the right angle contain the numbers from 1 to 60, and its area the fafta of every two of the numbers perpendicularly opposite. This is also called a canon Jk^&cus Pythagvricus, the multiplication-table, or any table of numbers that facilitates operations in arith-
# ---

# %% [markdown]
# #### 5.3 Creating groups of terms and years

# %%
df.groupby(['term', 'year']).groups.keys()
# Out:
# dict_keys([('A', 1771), ('A', 1773), ('AA', 1771), ('AA', 1773), ('AAB', 1773), ('AABAM', 1771), ('AACH', 1771), ('AADE', 1771), ('AAHUS', 1771), ('AAM', 1771), ('AAR', 1771), ('AARSEO', 1771), ('AATTER', 1771), ('AB', 1771), ('AB', 1773), ('ABA', 1771), ('ABAC', 1771), ('ABACATUAIA', 1771), ('ABACH', 1771), ('ABACISCUS', 1771), ('ABACO', 1771), ('ABACOT', 1771), ('ABACRE', 1771), ('ABACTORES', 1771), ('ABACTUS', 1771), ('ABACUS', 1771), ('ABACUS', 1773), ('ABADAN', 1771), ('ABADAN', 1773), ('ABADDON', 1771), ('ABADDON', 1773), ('ABADIR', 1771), ('ABADIR', 1773), ('ABAFT', 1771), ('ABAFT', 1773), ('ABAI', 1771), ('ABAISED', 1771), ('ABAISED', 1773), ('ABAISSE', 1771), ('ABAISSE', 1773), ('ABALIENATION', 1771), ('ABALIENATION', 1773), ('ABANBO', 1771), ('ABANBO', 1773), ('ABANCAI', 1771), ('ABANCAI', 1773), ('ABANO', 1771), ('ABANO', 1773), ('ABAPTISTON', 1771), ('ABAPTISTON', 1773), ('ABARCA', 1771), ('ABARCA', 1773), ('ABARTICULATION', 1771), ('ABAS', 1771), ('ABAS', 1773), ('ABASCIA', 1771), ('ABASCIA', 1773), ('ABASING', 1771), ('ABASING', 1773), ('ABASSI', 1771), ('ABASSI', 1773), ('ABATAMENTUM', 1771), ('ABATAMENTUM', 1773), ('ABATE', 1771), ('ABATE', 1773), ('ABATEMENT', 1771), ('ABATEMENT', 1773), ('ABATIS', 1771), ('ABATIS', 1773), ('ABATOR', 1773), ('ABAVO', 1771), ('ABAVO', 1773), ('ABAYANCE', 1771), ('ABAYANCE', 1773), ('ABB', 1771), ('ABB', 1773), ('ABBA', 1771), ('ABBA', 1773), ('ABBAT', 1771), ('ABBAT', 1773), ('ABBATIS', 1771), ('ABBATIS', 1773), ('ABBEFORD', 1771), ('ABBEFORD', 1773), ('ABBESS', 1771), ('ABBESS', 1773), ('ABBEVILLE', 1771), ('ABBEVILLE', 1773), ('ABBEY', 1771), ('ABBEY', 1773), ('ABBEYBOYLE', 1771), ('ABBEYBOYLE', 1773), ('ABBOT', 1771), ('ABBOT', 1773), ('ABBREVIATE', 1771), ('ABBREVIATE', 1773), ('ABBREVIATOR', 1771), ('ABBREVIATOR', 1773), ('ABBREVIATORS', 1771), ('ABBREVIATORS', 1773), ('ABBREVOIR', 1771), ('ABBREVOIR', 1773), ('ABBROCHMENT', 1771), ('ABBROCHMENT', 1773), ('ABBUTTALS', 1771), ('ABBUTTALS', 1773), ('ABC', 1771), ('ABC', 1773), ('ABCASSES', 1771), ('ABCASSES', 1773), ('ABCD', 1773), ('ABCDARIA', 1771), ('ABCDARY', 1771), ('ABCDARY', 1773), ('ABDALS', 1771), ('ABDALS', 1773), ('ABDELAVI', 1771), ('ABDELAVL', 1773), ('ABDEST', 1771), ('ABDEST', 1773), ('ABDICARIAN', 1771), ('ABDICARIAN', 1773), ('ABDICATION', 1771), ('ABDICATION', 1773), ('ABDOMEN', 1771), ('ABDOMEN', 1773), ('ABDUCTION', 1771), ('ABDUCTION', 1773), ('ABDUCTOR', 1771), ('ABDUCTOR', 1773), ('ABELIANS', 1773), ('ABELMOSCH', 1771), ('ABELMOSCH', 1773), ('ABELTREE', 1771), ('ABELTREE', 1773), ('ABENSBURG', 1771), ('ABENSBURG', 1773), ('ABERBROTHOCK', 1771), ('ABERBROTHOCK', 1773), ('ABERDEEN', 1771), ('ABERDEEN', 1773), ('ABERDOUR', 1771), ('ABERDOUR', 1773), ('ABERGAVENY', 1771), ('ABERGAVENY', 1773), ('ABERMURDER', 1771), ('ABERMURDER', 1773), ('ABERRATION', 1771), ('ABERRATION', 1773), ('ABERYSWITH', 1771), ('ABERYSWITH', 1773), ('ABESTA', 1771), ('ABESTA', 1773), ('ABESTON', 1771), ('ABESTON', 1773), ('ABETTOR', 1771), ('ABETTOR', 1773), ('ABEVACUATION', 1771), ('ABEVACUATION', 1773), ('ABEX', 1773), ('ABEYANCE', 1771), ('ABEYANCE', 1773), ('ABHEL', 1771), ('ABHEL', 1773), ('ABIB', 1773), ('ABIDING', 1773), ('ABIES', 1771), ('ABIES', 1773), ('ABIGEAT', 1771), ('ABIGEAT', 1773), ('ABIGEATUS', 1773), ('ABIGIES', 1773), ('ABILITY', 1771), ('ABILITY', 1773), ('ABINGDON', 1771), ('ABINGDON', 1773), ('ABINTESTATE', 1771), ('ABINTESTATE', 1773), ('ABISHERING', 1771), ('ABISHERING', 1773), ('ABIT', 1771), ('ABIT', 1773), ('ABJURATION', 1771), ('ABJURATION', 1773), ('ABLAC', 1771), ('ABLAC', 1773), ('ABLACQUEATION', 1771), ('ABLACQUEATION', 1773), ('ABLACTATION', 1771), ('ABLACTATION', 1773), ('ABLATIVE', 1771), ('ABLATIVE', 1773), ('ABLAY', 1771), ('ABLAY', 1773), ('ABLECTI', 1771), ('ABLECTI', 1773), ('ABLEGMINA', 1771), ('ABLET', 1771), ('ABLET', 1773), ('ABLUENTS', 1771), ('ABLUENTS', 1773), ('ABLUTION', 1771), ('ABLUTION', 1773), ('ABO', 1771), ('ABO', 1773), ('ABOARD', 1771), ('ABOARD', 1773), ('ABOLITION', 1771), ...

# %%
len(df.groupby(['term']).groups['ABACUS'])
# Out:
# 6

# %% [markdown]
# ### 6. Grouping the results by TERM, YEAR and DEFINITION

# %% [markdown]
# Group data by term and years, and count each group. This will help us to see how many times each term is repeated by year.

# %%
a=df.groupby(['term', 'year'])['definition'].count()
a
# Out:
# term         year
# A            1771    7
#              1773    6
# AA           1771    2
#              1773    3
# AAB          1773    1
#                     ..
# ZYGOMA       1771    1
#              1773    1
# ZYGOMATICUS  1773    1
# ZYGOPHYLLUM  1771    1
#              1773    1
# Name: definition, Length: 26771, dtype: int64

# %% [markdown]
# **Remark**: This means that the term "A" appears 7 times  in 1771, and 6 times in 1773.

# %% [markdown]
# #### 6.1 Obtaining for each term, its years and the definitions

# %% [markdown]
# We are going to create groups of ("TERM", "YEAR"), and for each of those groups, we are going to print their definition.
#
# **Remark**: I am going to restrict them to 10 groups.

# %%
groups = df[['term', 'year', 'definition']].groupby(['term', 'year'])
cont = 0
for group_key, group_value in groups:
    group = groups.get_group(group_key)
    print(group)
    print("---- Len of this group: %s - group_key %s " %(len(group), group_key))
    cont+=1
    if cont > 10:
        break
# Out:
#       term  year                                         definition
# 1016     A  1771                                    See Alchemilla.
# 1086     A  1771  gives a—by and “ the investigation of that sur...
# 12048    A  1771  r Y\ C / 7 f C.A ( ^y \ ~^\ \ C' A h \A v m aa...
# 12049    A  1771  I -w 'i <? ^' 0 IY\, y f‘ 1 A_-A IV^-/Y\< -'/W...
# 12722    A  1771  /kins may be tawed : but thc-se chiefly used f...
# 3236     A  1771  -Bladder, in physiology. See Air. ^//-Bladders...
# 6933     A  1771  in London is cieditor to (B) in Paris, value 1...
# ---- Len of this group: 7 - group_key ('A', 1771)
#       term  year                                         definition
# 20828    A  1773  in London is creditor to (B) in Paris, value t...
# 22717    A  1773  so served, and the day of appearance. When the...
# 23623    A  1773                                     f a 2±= m I ±P
# 24233    A  1773  l class. ' The calix consists of five leaves, ...
# 25141    A  1773  worate performance. Government lias, however, ...
# 25901    A  1773  are petals, hollow m their lower part, but in ...
# ---- Len of this group: 6 - group_key ('A', 1773)
#       term  year                                         definition
# 12033   AA  1771  The platform, or orlop, where provision is mad...
# 9449    AA  1771  The superior parts of the offa ilium. C, The m...
# ---- Len of this group: 2 - group_key ('AA', 1771)
#       term  year                                         definition
# 14905   AA  1773  A. L G E than na, so that c^la—kb, then a : b ...
# 23389   AA  1773  The superior parts of the offa ilium. C, The m...
# 26016   AA  1773  The platform, or orlop, where provision is mad...
# ---- Len of this group: 3 - group_key ('AA', 1773)
#       term  year                                         definition
# 25174  AAB  1773  a city of Lower Hungary, situated at the conto...
# ---- Len of this group: 1 - group_key ('AAB', 1773)
#     term  year                           definition
# 6  AABAM  1771  a term, among alchemifts, for lead,
# ---- Len of this group: 1 - group_key ('AABAM', 1771)
#    term  year                                         definition
# 7  AACH  1771  the name of a town and river in Swabia. It is ...
# ---- Len of this group: 1 - group_key ('AACH', 1771)
#    term  year                                         definition
# 8  AADE  1771  the name of two rivers, one in the country of ...
# ---- Len of this group: 1 - group_key ('AADE', 1771)
#     term  year                                definition
# 9  AAHUS  1771  a small town and diftrift in Weftphalia.
# ---- Len of this group: 1 - group_key ('AAHUS', 1771)
#    term  year                                         definition
# 10  AAM  1771  a Dutch measure for liquids, containing about ...
# ---- Len of this group: 1 - group_key ('AAM', 1771)
#    term  year                                         definition
# 11  AAR  1771  the name of two rivers, one in Weftphalia, and...
# ---- Len of this group: 1 - group_key ('AAR', 1771)

# %% [markdown]
# #### 6.2 Exploring how many times each term appears per year

# %% [markdown]
# Now, lets get the size of those groups, so we can see how many definitions we have per term and per year.
# This exactly the same that we did in the 6.1, but having the results in dataframe format.

# %%
g_year_term=df.groupby(['term', 'year']).size().reset_index()
g_year_term
# Out:
#               term  year  0
# 0                A  1771  7
# 1                A  1773  6
# 2               AA  1771  2
# 3               AA  1773  3
# 4              AAB  1773  1
# ...            ...   ... ..
# 26766       ZYGOMA  1771  1
# 26767       ZYGOMA  1773  1
# 26768  ZYGOMATICUS  1773  1
# 26769  ZYGOPHYLLUM  1771  1
# 26770  ZYGOPHYLLUM  1773  1
#
# [26771 rows x 3 columns]

# %% [markdown]
# #### 6.2.1 Grouping the previous results per year.
# This will give us the number of terms that we have per year.
# **Remember that a term can appear several time per volume**.

# %%
g_year_term.groupby(['year']).size()
# Out:
# year
# 1771    13252
# 1773    13519
# dtype: int64

# %% [markdown]
# #### 6.3 Exploring in how many years each term appears across years

# %% [markdown]
# Here we are interested to explore, for each unique term, in how many years appears.
#
# **Remark**: In the first eddition of the EB, 3 volumes (A-B, C-L, and M-Z) are published in two years: 1771 and 1773. So, the miminum time that each term appears in the first eddition is one, being two the maximum number of times.

# %%
#here we get if a term appears 1 or in 2 sub_edditions. 
terms_per_ed=g_year_term[['term', 'year']].groupby(['term']).count()
#print(terms_per_ed.max())
terms_per_ed
# Out:
#              year
# term
# A               2
# AA              2
# AAB             1
# AABAM           1
# AACH            1
# ...           ...
# ZUYDERSEE       2
# ZWEIBRUGGEN     2
# ZYGOMA          2
# ZYGOMATICUS     1
# ZYGOPHYLLUM     2
#
# [15465 rows x 1 columns]

# %% [markdown]
# This means that the term "A" appears in two years. And the term "AAB" only appears in one year

# %% [markdown]
# #### 6.3.1 Exploring the terms that only appear in 1 year

# %%
terms_only_once=terms_per_ed[terms_per_ed["year"]<2].reset_index()
terms_only_once
# Out:
#              term  year
# 0             AAB     1
# 1           AABAM     1
# 2            AACH     1
# 3            AADE     1
# 4           AAHUS     1
# ...           ...   ...
# 4154       ZEDILE     1
# 4155       ZEGIAS     1
# 4156  ZEGILETHRON     1
# 4157         ZINC     1
# 4158  ZYGOMATICUS     1
#
# [4159 rows x 2 columns]

# %% [markdown]
# Spliting the previous results, so we can know how many terms (that only appears once), correspond to "1771" and to "1773" years.

# %%
list_terms_once=terms_only_once["term"].to_list()
cont_dict={1771:0, 1773:0}

for i in list_terms_once:
    i_year=g_year_term.loc[g_year_term['term'] == i]["year"].to_string(index=False)

    cont_dict[int(i_year)]+=1
cont_dict
# Out:
# {1771: 1946, 1773: 2213}

# %% [markdown]
# **Remark**: This means that 1946 UNIQUE terms appear only in 1771. And 2213 UNIQUE terms appear only in 1773.

# %% [markdown]
# #### 6.3.2 Exploring the terms that only appear in 2 years

# %%
terms_more_once=terms_per_ed[terms_per_ed["year"]>1].reset_index()
terms_more_once
# Out:
#               term  year
# 0                A     2
# 1               AA     2
# 2               AB     2
# 3           ABACUS     2
# 4           ABADAN     2
# ...            ...   ...
# 11301      ZUTPHEN     2
# 11302    ZUYDERSEE     2
# 11303  ZWEIBRUGGEN     2
# 11304       ZYGOMA     2
# 11305  ZYGOPHYLLUM     2
#
# [11306 rows x 2 columns]
