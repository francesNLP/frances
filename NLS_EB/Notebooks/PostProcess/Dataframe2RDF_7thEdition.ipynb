# %% [markdown]
# # RDF-   NLS -  Encyclopaedia Britannica
#
# This notebook is going to create the RDF triples to generate our RDLIB GRAPH
#
# For each postprocess edition dataframe that we got from **Merging_EB_Terms.ipynb** (e.g. results_eb_1_edition_dataframe, results_eb_2_edition_dataframe, etc) we are going to add the information from the dataframe that we got from **Metadata_EB.ipynb** (metadata_eb_dataframe).
#
# The idea is to have per edition dataframe (and also supplement dataframe), all the information (which currently is splitted across several dataframes) in one.
#
#
# This notebook will store the final dataframes in results_NLS directory, and their name schema will be **final_eb_< NUM_EDITION >_dataframe**.
#
# Per entry in these new dataframes we will have the following columns (see an example of one entry of the first edition):
#
# - MMSID:
# - editionTitle:                          First edition, 1771, Volume 1, A-B
# - editor:                                                  Smellie, William
# - editor_date:                                                   1740-1795
# - genre:                                                       encyclopedia
# - language:                                                             eng
# - termsOfAddress:                                                       NaN
# - numberOfPages:                                                        832
# - physicalDescription:               3 v., 160 plates : ill. ; 26 cm. (4to)
# - place:                                                         Edinburgh
# - publisher:              Printed for A. Bell and C. Macfarquhar; and so...
# - referencedBy:           [Alston, R.C.  Engl. language III, 560, ESTC T...
# - shelfLocator:                                                        EB.1
# - editionSubTitle:        Illustrated with one hundred and sixty copperp...
# - volumeTitle:            Encyclopaedia Britannica; or, A dictionary of ...
# - year:                                                                1771
# - volumeId:                                                       144133901
# - metsXML:                                               144133901-mets.xml
# - permanentURL:                            https://digital.nls.uk/144133901
# - publisherPersons:                     [C. Macfarquhar, Colin Macfarquhar]
# - volumeNum:                                                              1
# - letters:                                                              A-B
# - part:                                                                   0
# - editionNum:                                                             1
# - supplementTitle:
# - supplementSubTitle:
# - supplementsTo:                                                         []
# - numberOfVolumes:                                                        6
# - term:                                                                  OR
# - definition:             A NEW A D I C T I A A, the name of several riv...
# - relatedTerms:                                                          []
# - header:                                           EncyclopaediaBritannica
# - startsAt:                                                              15
# - endsAt:                                                                15
# - numberOfTerms:                                                         22
# - numberOfWords:                                                         54
# - positionPage:                                                           0
# - typeTerm:                                                         Article
# - altoXML:                                  144133901/alto/188082904.34.xml

# %% [markdown]
# ### Loading the necessary libraries

# %%
import yaml
import numpy as np
import collections
import string
import copy
from datetime import datetime

# %%
import pandas as pd
from yaml import safe_load
from pandas.io.json import json_normalize
from difflib import SequenceMatcher

# %% [markdown]
# ### Functions

# %%
def edition2rdf(data, g, eb):

    edition = URIRef("https://w3id.org/eb/i/Edition/"+str(data["MMSID"]))
    edition_title= "Edition "+ str(data["editionNum"])+"," +str(data["year"])
    g.add((edition, RDF.type, eb.Edition))
    g.add((edition, eb.number, Literal(data["editionNum"], datatype=XSD.integer)))
    g.add((edition, eb.title, Literal(edition_title, datatype=XSD.string)))
    g.add((edition, eb.subtitle, Literal(data["editionSubTitle"], datatype=XSD.string)))
    g.add((edition, eb.publicationYear, Literal(data["year"], datatype=XSD.integer)))
    g.add((edition, eb.printedAt, Literal(data["place"], datatype=XSD.string)))
    g.add((edition, eb.mmsid, Literal(str(data["MMSID"]), datatype=XSD.string)))
    g.add((edition, eb.physicalDescription, Literal(data["physicalDescription"], datatype=XSD.string)))
    g.add((edition, eb.genre, Literal(data["genre"], datatype=XSD.string)))
    g.add((edition, eb.language, Literal(data["language"], datatype=XSD.string)))
    g.add((edition, eb.shelfLocator, Literal(data["shelfLocator"], datatype=XSD.string)))
    g.add((edition, eb.numberOfVolumes, Literal(data["numberOfVolumes"], datatype=XSD.integer)))

    #### Editor 

    name=data["editor"].replace(" ", "")
    editor = URIRef("https://w3id.org/eb/i/Person/"+str(name))
    g.add((editor, RDF.type, eb.Person))
    g.add((editor, eb.name, Literal(data["editor"], datatype=XSD.string)))

    if data["editor_date"]!=0:
        tmpDate=data["editor_date"].split("-")
        birthDate=datetime.strptime(tmpDate[0], '%Y')
        deathDate=datetime.strptime(tmpDate[1], '%Y')
        g.add((editor, eb.birthDate, Literal(birthDate, datatype=XSD.dateTime)))
        g.add((editor, eb.deathDate, Literal(deathDate, datatype=XSD.dateTime)))
    
    if data["termsOfAddress"] != 0:
        g.add((editor, eb.termsOfAddress, Literal(data["termsOfAddress"], datatype=XSD.string)))

    g.add((edition, eb.editor, editor))

    #### Publishers Persons 

    #This was the result to pass entity recognition to publisher

    if data["publisherPersons"] != 0:
        publisherPersons=name=data["publisherPersons"]
        for p in publisherPersons: 
            name=p.replace(" ", "")
            publisher = URIRef("https://w3id.org/eb/i/Person/"+name)
            g.add((publisher, RDF.type, eb.Person))
            g.add((publisher, eb.name, Literal(p, datatype=XSD.string)))
            g.add((edition, eb.publisher, publisher))
        
    #### Is Referenced by  

    if data["referencedBy"] != 0:
        references=data["referencedBy"]
        for r in references: 
            name=r.replace(" ", "")
            book = URIRef("https://w3id.org/eb/i/Book/"+name)
            g.add((book, RDF.type, eb.Book))
            g.add((book, eb.title, Literal(r, datatype=XSD.string)))
            g.add((edition, eb.referencedBy, book))
            
    return g, edition

# %% [markdown]
# ### 1. Loading the final dataframe

# %%
df= pd.read_json('../../results_NLS/final_eb_7_dataframe', orient="index")

# %%
df=df.fillna(0)

# %%
df.loc[0]
# Out:
# MMSID                                                   9910796273804340
# editionTitle                              Seventh edition, General index
# editor                                                   Stewart, Dugald
# editor_date                                                    1753-1828
# genre                                                       encyclopedia
# language                                                             eng
# termsOfAddress                                                       Sir
# numberOfPages                                                        184
# physicalDescription                                   21 v. in 22 ; 4to.
# place                                                          Edinburgh
# publisher                                                  A. & C. Black
# referencedBy                                                         0.0
# shelfLocator                                                       EB.15
# editionSubTitle                                                      0.0
# volumeTitle                                     Encyclopaedia Britannica
# year                                                                1842
# volumeId                                                       192547789
# metsXML                                               192547789-mets.xml
# permanentURL                            https://digital.nls.uk/192547789
# publisherPersons                                                      []
# volumeNum                                                              0
# letters
# part                                                                   0
# editionNum                                                             7
# supplementTitle
# supplementSubTitle
# supplementsTo                                                         []
# numberOfVolumes                                                       22
# term                                                       ENCYCLOPAEDIA
# definition             but to serve the far more important purpose of...
# relatedTerms                                                          []
# header                                                      GENERALINDEX
# startsAt                                                              11
# endsAt                                                                11
# numberOfTerms                                                         21
# numberOfWords                                                        118
# positionPage                                                           0
# typeTerm                                                         Article
# altoXML                                  192547789/alto/192890211.34.xml
# Name: 0, dtype: object

# %%
df_year=df[df['year'] == 1771].reset_index(drop=True)

# %%
related_df_entries=df_year[df_year["term"] == "DRAWING"].reset_index(drop=True)

# %%
related_df_entries["relatedTerms"]
# Out:
# Series([], Name: relatedTerms, dtype: object)

# %%
vl=related_df_entries["volumeNum"].unique()
vl
# Out:
# array([], dtype=int64)

# %% [markdown]
# Lets get the first element of the "final_eb_1_dataframe" dataframe and extract the information of the 1st Edition class.

# %% [markdown]
# ### 2. Create a Graph and import the information of the 1st Edition class to it.

# %%
from rdflib import Graph, URIRef, Literal, Namespace, XSD
from rdflib.namespace import RDF, RDFS


# Create a Graph
g = Graph()

g.namespace_manager.bind('eb', Namespace("https://w3id.org/eb#"), override="False")
eb = Namespace("https://w3id.org/eb#")

#### Edition-1771 Information

list_years=df["year"].unique()
ed_revisions=[]

for y in range(0, len(list_years)):
    
    ### EDITION
    print("YEAR %s" %list_years[y])
    
    df_year=df[df['year'] == list_years[y]].reset_index(drop=True)
    edition_data = df_year.loc[0]
    g, edition = edition2rdf(edition_data,g, eb)
    ed_revisions.append(edition)
    
    ### VOLUMES 
    list_vols = df_year["volumeNum"].unique()
    for v in range(0,len(list_vols)):
        print("Vol %s" % list_vols[v])
        df_year_vl=df_year[df_year["volumeNum"] == list_vols[v]].reset_index(drop=True)
        volume_data=df_year_vl.loc[0]
        volume_id=volume_data["volumeId"]
        volume = URIRef("https://w3id.org/eb/i/Volume/"+str(volume_data["MMSID"])+"_"+str(volume_data["volumeId"]))
        g.add((volume, RDF.type, eb.Volume))
        g.add((volume, eb.number, Literal(volume_data["volumeNum"], datatype=XSD.integer)))
        g.add((volume, eb.letters, Literal(volume_data["letters"], datatype=XSD.string)))
        g.add((volume, eb.volumeId, Literal(volume_data["volumeId"], datatype=XSD.int)))
        g.add((volume, eb.title, Literal(volume_data["volumeTitle"], datatype=XSD.string)))
        
        if volume_data["part"]!=0:
            g.add((volume, eb.part, Literal(volume_data["part"], datatype=XSD.string)))
    
        g.add((volume, eb.metsXML, Literal(volume_data["metsXML"], datatype=XSD.string)))
        g.add((volume, eb.permanentURL, Literal(volume_data["permanentURL"], datatype=XSD.string)))
        g.add((volume, eb.numberOfPages, Literal(volume_data["numberOfPages"], datatype=XSD.string)))
    
        g.add((edition, eb.hasPart, volume))
    
        df_by_term=df_year_vl.groupby(['term'],)["term"].count().reset_index(name='counts')
                        
        #### TERMS
        for t_index in range(0, len(df_by_term)):
            t=df_by_term.loc[t_index]["term"]
            c=df_by_term.loc[t_index]["counts"]
            df_entries= df_year_vl[df_year_vl["term"] == t].reset_index(drop=True)
            for t_count in range(0, c):
                df_entry= df_entries.loc[t_count]
                if df_entry["typeTerm"] == "Article" :
                    term= URIRef("https://w3id.org/eb/i/Article/"+str(df_entry["MMSID"])+"_"+str(df_entry["volumeId"])+"_"+t+"_"+str(t_count))
                    g.add((term, RDF.type, eb.Article))
                elif df_entry["typeTerm"] == "Topic" :
                    term= URIRef("https://w3id.org/eb/i/Topic/"+str(df_entry["MMSID"])+"_"+str(df_entry["volumeId"])+"_"+t+"_"+str(t_count))
                    g.add((term, RDF.type, eb.Topic))
                else:
                    pass
                g.add((term, eb.name, Literal(t, datatype=XSD.string)))
                g.add((term, eb.definition, Literal(df_entry["definition"], datatype=XSD.string)))
                g.add((term, eb.position, Literal(df_entry["positionPage"], datatype=XSD.int)))
                g.add((term, eb.numberOfWords, Literal(df_entry["numberOfWords"], datatype=XSD.int)))
                g.add((volume, eb.hasPart, term))
            
                ## startsAt
                page_startsAt= URIRef("https://w3id.org/eb/i/Page/"+ str(df_entry["MMSID"])+"_"+str(df_entry["volumeId"])+"_"+str(df_entry["startsAt"]))
                g.add((page_startsAt, RDF.type, eb.Page))
                g.add((page_startsAt, eb.number, Literal(df_entry["startsAt"], datatype=XSD.int)))
                g.add((page_startsAt, eb.header, Literal(df_entry["header"], datatype=XSD.string)))
                g.add((page_startsAt, eb.numberOfTerms, Literal(df_entry["numberOfTerms"], datatype=XSD.int)))
                g.add((volume, eb.hasPart, page_startsAt))
                g.add((term, eb.startsAtPage, page_startsAt))
                g.add((page_startsAt, eb.hasPart, term))
            
                ## endsAt
                page_endsAt= URIRef("https://w3id.org/eb/i/Page/"+ str(df_entry["MMSID"])+"_"+str(df_entry["volumeId"])+"_"+str(df_entry["endsAt"]))
                g.add((page_endsAt, RDF.type, eb.Page))
                g.add((page_endsAt, eb.number, Literal(df_entry["endsAt"], datatype=XSD.int)))
                g.add((volume, eb.hasPart, page_endsAt))
                g.add((term, eb.endsAtPage, page_endsAt))
                g.add((page_endsAt, eb.hasPart, term))
                
                ## related terms
                
                if df_entry["relatedTerms"]:
                    for rt in df_entry["relatedTerms"]:
                        if rt!= t:
                            related_df_entries= df_year[df_year["term"] == rt].reset_index(drop=True)
                            list_r_vl=related_df_entries["volumeNum"].unique()
                            for r_vl in list_r_vl:
                                df_r_vl=related_df_entries[related_df_entries["volumeNum"] == r_vl].reset_index(drop=True)
                                for r_c in range (0, len(df_r_vl)):
                                    r_entry= df_r_vl.loc[r_c]
                                    if r_entry["typeTerm"] == "Article" :
                                        r_term= URIRef("https://w3id.org/eb/i/Article/"+str(r_entry["MMSID"])+"_"+str(r_entry["volumeId"])+"_"+rt+"_"+str(r_c))
                                    elif r_entry["typeTerm"] == "Topic" :
                                        r_term= URIRef("https://w3id.org/eb/i/Topic/"+str(r_entry["MMSID"])+"_"+str(r_entry["volumeId"])+"_"+rt+"_"+str(r_c))
                                        
                                    g.add((term, eb.relatedTerms, r_term))
                        


try:
    g.add((ed_revisions[1], eb.revisionOf, ed_revisions[0]))
except:
    pass
# Out:
# YEAR 1842
# Vol 0
# Vol 12
# Vol 1
# Vol 2
# Vol 3
# Vol 19
# Vol 4
# Vol 13
# Vol 8
# Vol 14
# Vol 6
# Vol 10
# Vol 17
# Vol 18
# Vol 11
# Vol 5
# Vol 9
# Vol 7
# Vol 15
# Vol 21
# Vol 20
# Vol 16

# %%
# Save the Graph in the RDF Turtle format
g.serialize(format="turtle", destination="edition7.ttl")
# Out:
# <Graph identifier=N91e001bcd7ca4493833a1554f640ca1e (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# List all the elements that we have added for the last Edition added in the graph

# %%
for s,p,o in g.triples((edition, None, None)):
  print(s,p,o)
# Out:
# https://w3id.org/eb/i/Edition/9910796273804340 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/eb#Edition
# https://w3id.org/eb/i/Edition/9910796273804340 https://w3id.org/eb#number 7
# https://w3id.org/eb/i/Edition/9910796273804340 https://w3id.org/eb#title Edition 7,1842
# https://w3id.org/eb/i/Edition/9910796273804340 https://w3id.org/eb#subtitle 0.0
# https://w3id.org/eb/i/Edition/9910796273804340 https://w3id.org/eb#publicationYear 1842
# https://w3id.org/eb/i/Edition/9910796273804340 https://w3id.org/eb#printedAt Edinburgh
# https://w3id.org/eb/i/Edition/9910796273804340 https://w3id.org/eb#mmsid 9910796273804340
# https://w3id.org/eb/i/Edition/9910796273804340 https://w3id.org/eb#physicalDescription 21 v. in 22 ; 4to.
# https://w3id.org/eb/i/Edition/9910796273804340 https://w3id.org/eb#genre encyclopedia
# https://w3id.org/eb/i/Edition/9910796273804340 https://w3id.org/eb#language eng
# https://w3id.org/eb/i/Edition/9910796273804340 https://w3id.org/eb#shelfLocator EB.15
# https://w3id.org/eb/i/Edition/9910796273804340 https://w3id.org/eb#numberOfVolumes 22
# https://w3id.org/eb/i/Edition/9910796273804340 https://w3id.org/eb#editor https://w3id.org/eb/i/Person/Stewart,Dugald
# https://w3id.org/eb/i/Edition/9910796273804340 https://w3id.org/eb#hasPart https://w3id.org/eb/i/Volume/9910796273804340_192547789
# https://w3id.org/eb/i/Edition/9910796273804340 https://w3id.org/eb#hasPart https://w3id.org/eb/i/Volume/9910796273804340_192693199
# https://w3id.org/eb/i/Edition/9910796273804340 https://w3id.org/eb#hasPart https://w3id.org/eb/i/Volume/9910796273804340_192984258
# https://w3id.org/eb/i/Edition/9910796273804340 https://w3id.org/eb#hasPart https://w3id.org/eb/i/Volume/9910796273804340_192984259
# https://w3id.org/eb/i/Edition/9910796273804340 https://w3id.org/eb#hasPart https://w3id.org/eb/i/Volume/9910796273804340_193057500
# https://w3id.org/eb/i/Edition/9910796273804340 https://w3id.org/eb#hasPart https://w3id.org/eb/i/Volume/9910796273804340_193057501
# https://w3id.org/eb/i/Edition/9910796273804340 https://w3id.org/eb#hasPart https://w3id.org/eb/i/Volume/9910796273804340_193108322
# https://w3id.org/eb/i/Edition/9910796273804340 https://w3id.org/eb#hasPart https://w3id.org/eb/i/Volume/9910796273804340_193108323
# https://w3id.org/eb/i/Edition/9910796273804340 https://w3id.org/eb#hasPart https://w3id.org/eb/i/Volume/9910796273804340_193322688
# https://w3id.org/eb/i/Edition/9910796273804340 https://w3id.org/eb#hasPart https://w3id.org/eb/i/Volume/9910796273804340_193322689
# https://w3id.org/eb/i/Edition/9910796273804340 https://w3id.org/eb#hasPart https://w3id.org/eb/i/Volume/9910796273804340_193322690
# https://w3id.org/eb/i/Edition/9910796273804340 https://w3id.org/eb#hasPart https://w3id.org/eb/i/Volume/9910796273804340_193469090
# https://w3id.org/eb/i/Edition/9910796273804340 https://w3id.org/eb#hasPart https://w3id.org/eb/i/Volume/9910796273804340_193469091
# https://w3id.org/eb/i/Edition/9910796273804340 https://w3id.org/eb#hasPart https://w3id.org/eb/i/Volume/9910796273804340_193469092
# https://w3id.org/eb/i/Edition/9910796273804340 https://w3id.org/eb#hasPart https://w3id.org/eb/i/Volume/9910796273804340_193638940
# https://w3id.org/eb/i/Edition/9910796273804340 https://w3id.org/eb#hasPart https://w3id.org/eb/i/Volume/9910796273804340_193696083
# https://w3id.org/eb/i/Edition/9910796273804340 https://w3id.org/eb#hasPart https://w3id.org/eb/i/Volume/9910796273804340_193696084
# https://w3id.org/eb/i/Edition/9910796273804340 https://w3id.org/eb#hasPart https://w3id.org/eb/i/Volume/9910796273804340_193819043
# https://w3id.org/eb/i/Edition/9910796273804340 https://w3id.org/eb#hasPart https://w3id.org/eb/i/Volume/9910796273804340_193819044
# https://w3id.org/eb/i/Edition/9910796273804340 https://w3id.org/eb#hasPart https://w3id.org/eb/i/Volume/9910796273804340_193819045
# https://w3id.org/eb/i/Edition/9910796273804340 https://w3id.org/eb#hasPart https://w3id.org/eb/i/Volume/9910796273804340_193913444
# https://w3id.org/eb/i/Edition/9910796273804340 https://w3id.org/eb#hasPart https://w3id.org/eb/i/Volume/9910796273804340_194474782

# %%
for s,p,o in g.triples((None, eb.relatedTerms, None)):
  print(s,p,o)
# Out:
# https://w3id.org/eb/i/Article/9910796273804340_192547789_ACCIPITER_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193638940_HAWK_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193638940_HAWK_0
# https://w3id.org/eb/i/Topic/9910796273804340_192984258_INDEX_2 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193638940_HAWK_0
# https://w3id.org/eb/i/Article/9910796273804340_192547789_ACCIPITER_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192984259_ACCOLADE_0
# https://w3id.org/eb/i/Article/9910796273804340_192547789_ACESINES_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819045_VINEGAR_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_BAIROUT_0
# https://w3id.org/eb/i/Topic/9910796273804340_193108322_ASTRONOMY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_BAIROUT_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193108323_LAPLACE_0
# https://w3id.org/eb/i/Topic/9910796273804340_192984259_BACCA_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193108323_LAPLACE_0
# https://w3id.org/eb/i/Topic/9910796273804340_193108323_LAPLAND_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193108323_LAPLACE_0
# https://w3id.org/eb/i/Topic/9910796273804340_193469092_PROBABILITY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193108323_LAPLACE_0
# https://w3id.org/eb/i/Topic/9910796273804340_193819043_COMET_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193108323_LAPLACE_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819045_TWEED_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0
# https://w3id.org/eb/i/Topic/9910796273804340_192984259_AGRICULTURE_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0
# https://w3id.org/eb/i/Topic/9910796273804340_193057501_RETICULATION_1 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0
# https://w3id.org/eb/i/Topic/9910796273804340_193108322_ASTRONOMY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0
# https://w3id.org/eb/i/Article/9910796273804340_193108323_LARK_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0
# https://w3id.org/eb/i/Article/9910796273804340_193108323_LARVA_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0
# https://w3id.org/eb/i/Article/9910796273804340_193322688_DOVE_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0
# https://w3id.org/eb/i/Article/9910796273804340_193322688_DUCK_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0
# https://w3id.org/eb/i/Article/9910796273804340_193322688_EAGLE_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0
# https://w3id.org/eb/i/Article/9910796273804340_193322689_MALIVAGUNGA_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0
# https://w3id.org/eb/i/Article/9910796273804340_193322689_MALLARD_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0
# https://w3id.org/eb/i/Topic/9910796273804340_193322690_CANARIES_1 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0
# https://w3id.org/eb/i/Topic/9910796273804340_193322690_CARPENTRY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0
# https://w3id.org/eb/i/Article/9910796273804340_193469090_GOONEE_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0
# https://w3id.org/eb/i/Topic/9910796273804340_193469091_PERSPECTIVE_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0
# https://w3id.org/eb/i/Article/9910796273804340_193469092_QUAIL_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0
# https://w3id.org/eb/i/Article/9910796273804340_193638940_HAWICK_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0
# https://w3id.org/eb/i/Topic/9910796273804340_193638940_HELMINTHOLOGY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0
# https://w3id.org/eb/i/Topic/9910796273804340_193696083_BOTANY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0
# https://w3id.org/eb/i/Article/9910796273804340_193696084_FALCO_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0
# https://w3id.org/eb/i/Article/9910796273804340_193819043_COCK_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0
# https://w3id.org/eb/i/Article/9910796273804340_193819043_CONTINUED_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0
# https://w3id.org/eb/i/Article/9910796273804340_193819043_CURFEU_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0
# https://w3id.org/eb/i/Article/9910796273804340_193819043_CYDONIA_1 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0
# https://w3id.org/eb/i/Article/9910796273804340_193819043_US_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0
# https://w3id.org/eb/i/Article/9910796273804340_194474782_NIDIFICATION_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819045_VIRE_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ENTOMOLOGY_0
# https://w3id.org/eb/i/Topic/9910796273804340_193057500_ANIMALKINGDOM_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ENTOMOLOGY_0
# https://w3id.org/eb/i/Article/9910796273804340_193057500_APHIS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ENTOMOLOGY_0
# https://w3id.org/eb/i/Topic/9910796273804340_193057500_ARACHNIDES_1 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ENTOMOLOGY_0
# https://w3id.org/eb/i/Topic/9910796273804340_193108322_ASTRONOMY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ENTOMOLOGY_0
# https://w3id.org/eb/i/Topic/9910796273804340_193696083_BOTANY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ENTOMOLOGY_0
# https://w3id.org/eb/i/Article/9910796273804340_193696084_FORFICULA_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ENTOMOLOGY_0
# https://w3id.org/eb/i/Article/9910796273804340_193819043_CONNOISSEUR_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ENTOMOLOGY_0
# https://w3id.org/eb/i/Topic/9910796273804340_193819044_MICROMETER_1 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ENTOMOLOGY_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193696084_ENTOMOLOGY_0
# https://w3id.org/eb/i/Topic/9910796273804340_193057500_ANIMALKINGDOM_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193696084_ENTOMOLOGY_0
# https://w3id.org/eb/i/Article/9910796273804340_193057500_APHIS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193696084_ENTOMOLOGY_0
# https://w3id.org/eb/i/Topic/9910796273804340_193057500_ARACHNIDES_1 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193696084_ENTOMOLOGY_0
# https://w3id.org/eb/i/Topic/9910796273804340_193108322_ASTRONOMY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193696084_ENTOMOLOGY_0
# https://w3id.org/eb/i/Topic/9910796273804340_193696083_BOTANY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193696084_ENTOMOLOGY_0
# https://w3id.org/eb/i/Article/9910796273804340_193696084_FORFICULA_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193696084_ENTOMOLOGY_0
# https://w3id.org/eb/i/Article/9910796273804340_193819043_CONNOISSEUR_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193696084_ENTOMOLOGY_0
# https://w3id.org/eb/i/Topic/9910796273804340_193819044_MICROMETER_1 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193696084_ENTOMOLOGY_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_192693199_ICHTHYOLOGY_0
# https://w3id.org/eb/i/Topic/9910796273804340_193108322_ASTRONOMY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_192693199_ICHTHYOLOGY_0
# https://w3id.org/eb/i/Article/9910796273804340_193322688_EEL_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_192693199_ICHTHYOLOGY_0
# https://w3id.org/eb/i/Topic/9910796273804340_193322690_CARPENTRY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_192693199_ICHTHYOLOGY_0
# https://w3id.org/eb/i/Article/9910796273804340_193469091_PERCH_1 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_192693199_ICHTHYOLOGY_0
# https://w3id.org/eb/i/Topic/9910796273804340_193469091_PERSPECTIVE_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_192693199_ICHTHYOLOGY_0
# https://w3id.org/eb/i/Article/9910796273804340_193638940_GUDGEON_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_192693199_ICHTHYOLOGY_0
# https://w3id.org/eb/i/Topic/9910796273804340_193696083_BOTANY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_192693199_ICHTHYOLOGY_0
# https://w3id.org/eb/i/Article/9910796273804340_193696084_FLYING_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_192693199_ICHTHYOLOGY_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819045_TYROL_0
# https://w3id.org/eb/i/Topic/9910796273804340_193108322_ASTRONOMY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819045_TYROL_0
# https://w3id.org/eb/i/Article/9910796273804340_193696084_FONTAINE_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819045_TYROL_0
# https://w3id.org/eb/i/Topic/9910796273804340_194474782_NIEBUHR_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819045_TYROL_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193469090_GALICIA_0
# https://w3id.org/eb/i/Topic/9910796273804340_193696083_BOTANY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193469090_GALICIA_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193322690_CARAMANIA_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193322688_DISCIPLINE_0
# https://w3id.org/eb/i/Topic/9910796273804340_193057500_ARACHNIDES_1 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193322688_DISCIPLINE_0
# https://w3id.org/eb/i/Article/9910796273804340_193469090_GREENWICH_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193322688_DISCIPLINE_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_194474782_NORMANS_0
# https://w3id.org/eb/i/Article/9910796273804340_193696084_FAREHAM_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_194474782_NORMANS_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_DANUBE_0
# https://w3id.org/eb/i/Topic/9910796273804340_193108322_ASTRONOMY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_DANUBE_0
# https://w3id.org/eb/i/Topic/9910796273804340_193322688_EGYPT_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_DANUBE_0
# https://w3id.org/eb/i/Topic/9910796273804340_193322689_MAMMALIA_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_DANUBE_0
# https://w3id.org/eb/i/Topic/9910796273804340_193819045_TURKEY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_DANUBE_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193057500_DAG_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_DAOUD_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_DAOUDNAGUR_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_DAPHNE_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_DAPIFER_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_DARABJIRB_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_DARAH_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_DARAPTI_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_DARDA_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_DARDANELLES_0
# https://w3id.org/eb/i/Topic/9910796273804340_193108322_ASTRONOMY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_DARDANELLES_0
# https://w3id.org/eb/i/Topic/9910796273804340_193469090_GALILEO_1 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_DARDANELLES_0
# https://w3id.org/eb/i/Topic/9910796273804340_193819045_TURKEY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_DARDANELLES_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_DARFUR_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_AFRICA_0
# https://w3id.org/eb/i/Topic/9910796273804340_192693199_ICHTHYOLOGY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_AFRICA_0
# https://w3id.org/eb/i/Topic/9910796273804340_192984258_INDEX_2 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_AFRICA_0
# https://w3id.org/eb/i/Article/9910796273804340_192984259_ABOULFEDA_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_AFRICA_0
# https://w3id.org/eb/i/Topic/9910796273804340_193057500_ANGLING_1 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_AFRICA_0
# https://w3id.org/eb/i/Topic/9910796273804340_193057501_REPTILIA_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_AFRICA_0
# https://w3id.org/eb/i/Topic/9910796273804340_193108322_ASTRONOMY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_AFRICA_0
# https://w3id.org/eb/i/Topic/9910796273804340_193322688_EGYPT_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_AFRICA_0
# https://w3id.org/eb/i/Topic/9910796273804340_193322689_MAMMALIA_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_AFRICA_0
# https://w3id.org/eb/i/Topic/9910796273804340_193322690_CARPENTRY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_AFRICA_0
# https://w3id.org/eb/i/Topic/9910796273804340_193469091_PERSPECTIVE_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_AFRICA_0
# https://w3id.org/eb/i/Topic/9910796273804340_193696083_BOTANY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_AFRICA_0
# https://w3id.org/eb/i/Topic/9910796273804340_193696084_ENTOMOLOGY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_AFRICA_0
# https://w3id.org/eb/i/Article/9910796273804340_193913444_SEMIPELAGIANS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_AFRICA_0
# https://w3id.org/eb/i/Topic/9910796273804340_193913444_SERPENTS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_AFRICA_0
# https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_AFRICA_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_192984259_AFRICA_0
# https://w3id.org/eb/i/Topic/9910796273804340_192693199_ICHTHYOLOGY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_192984259_AFRICA_0
# https://w3id.org/eb/i/Topic/9910796273804340_192984258_INDEX_2 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_192984259_AFRICA_0
# https://w3id.org/eb/i/Article/9910796273804340_192984259_ABOULFEDA_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_192984259_AFRICA_0
# https://w3id.org/eb/i/Topic/9910796273804340_193057500_ANGLING_1 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_192984259_AFRICA_0
# https://w3id.org/eb/i/Topic/9910796273804340_193057501_REPTILIA_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_192984259_AFRICA_0
# https://w3id.org/eb/i/Topic/9910796273804340_193108322_ASTRONOMY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_192984259_AFRICA_0
# https://w3id.org/eb/i/Topic/9910796273804340_193322688_EGYPT_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_192984259_AFRICA_0
# https://w3id.org/eb/i/Topic/9910796273804340_193322689_MAMMALIA_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_192984259_AFRICA_0
# https://w3id.org/eb/i/Topic/9910796273804340_193322690_CARPENTRY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_192984259_AFRICA_0
# https://w3id.org/eb/i/Topic/9910796273804340_193469091_PERSPECTIVE_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_192984259_AFRICA_0
# https://w3id.org/eb/i/Topic/9910796273804340_193696083_BOTANY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_192984259_AFRICA_0
# https://w3id.org/eb/i/Topic/9910796273804340_193696084_ENTOMOLOGY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_192984259_AFRICA_0
# https://w3id.org/eb/i/Article/9910796273804340_193913444_SEMIPELAGIANS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_192984259_AFRICA_0
# https://w3id.org/eb/i/Topic/9910796273804340_193913444_SERPENTS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_192984259_AFRICA_0
# https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_192984259_AFRICA_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_DARIEN_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193819043_DARIEN_1
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_DARIUS_0
# https://w3id.org/eb/i/Topic/9910796273804340_193108323_MACEDONIA_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_DARIUS_0
# https://w3id.org/eb/i/Article/9910796273804340_193819043_CYRUS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_DARIUS_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193469092_PRUSSIA_0
# https://w3id.org/eb/i/Topic/9910796273804340_192984258_INDEX_2 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193469092_PRUSSIA_0
# https://w3id.org/eb/i/Topic/9910796273804340_192984259_ACADEMY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193469092_PRUSSIA_0
# https://w3id.org/eb/i/Topic/9910796273804340_193057501_RETICULATION_1 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193469092_PRUSSIA_0
# https://w3id.org/eb/i/Topic/9910796273804340_193108322_ASTRONOMY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193469092_PRUSSIA_0
# https://w3id.org/eb/i/Article/9910796273804340_193322688_DRONI_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193469092_PRUSSIA_0
# https://w3id.org/eb/i/Topic/9910796273804340_193322689_MAMMALIA_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193469092_PRUSSIA_0
# https://w3id.org/eb/i/Topic/9910796273804340_193696083_BOTANY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193469092_PRUSSIA_0
# https://w3id.org/eb/i/Topic/9910796273804340_194474782_NIEBUHR_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193469092_PRUSSIA_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_DARKNESS_0
# https://w3id.org/eb/i/Topic/9910796273804340_193469090_GEOGRAPHY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_DARKNESS_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819045_WALES_0
# https://w3id.org/eb/i/Topic/9910796273804340_192693199_ICHTHYOLOGY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819045_WALES_0
# https://w3id.org/eb/i/Topic/9910796273804340_192984258_INDEXCAP_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819045_WALES_0
# https://w3id.org/eb/i/Topic/9910796273804340_193057500_ARACHNIDES_1 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819045_WALES_0
# https://w3id.org/eb/i/Topic/9910796273804340_193057501_REPTILIA_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819045_WALES_0
# https://w3id.org/eb/i/Topic/9910796273804340_193108322_ASTRONOMY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819045_WALES_0
# https://w3id.org/eb/i/Topic/9910796273804340_193108323_LIVERPOOL_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819045_WALES_0
# https://w3id.org/eb/i/Topic/9910796273804340_193322688_ENGLAND_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819045_WALES_0
# https://w3id.org/eb/i/Topic/9910796273804340_193322689_MAMMALIA_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819045_WALES_0
# https://w3id.org/eb/i/Article/9910796273804340_193638940_HAWICK_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819045_WALES_0
# https://w3id.org/eb/i/Topic/9910796273804340_193638940_HELMINTHOLOGY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819045_WALES_0
# https://w3id.org/eb/i/Topic/9910796273804340_193696083_BOTANY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819045_WALES_0
# https://w3id.org/eb/i/Article/9910796273804340_193696084_ANNERS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819045_WALES_0
# https://w3id.org/eb/i/Article/9910796273804340_193696084_FAREHAM_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819045_WALES_0
# https://w3id.org/eb/i/Topic/9910796273804340_193819044_MICROMETER_1 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819045_WALES_0
# https://w3id.org/eb/i/Article/9910796273804340_194474782_BEDFORD_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819045_WALES_0
# https://w3id.org/eb/i/Article/9910796273804340_194474782_ORLEANS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819045_WALES_0
# https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819045_WALES_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193322688_DURHAM_0
# https://w3id.org/eb/i/Topic/9910796273804340_192984258_INDEX_2 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193322688_DURHAM_0
# https://w3id.org/eb/i/Topic/9910796273804340_192984259_AGRICULTURE_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193322688_DURHAM_0
# https://w3id.org/eb/i/Topic/9910796273804340_193108322_ASTRONOMY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193322688_DURHAM_0
# https://w3id.org/eb/i/Topic/9910796273804340_193108323_LAWOFNATIONS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193322688_DURHAM_0
# https://w3id.org/eb/i/Topic/9910796273804340_193322688_ENGLAND_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193322688_DURHAM_0
# https://w3id.org/eb/i/Topic/9910796273804340_193819045_ZEALANDNEW_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193322688_DURHAM_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_DARMAPOORAM_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_DARMSTADT_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_0
# https://w3id.org/eb/i/Article/9910796273804340_192984258_DARW_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_0
# https://w3id.org/eb/i/Topic/9910796273804340_192984258_INDEX_2 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_0
# https://w3id.org/eb/i/Topic/9910796273804340_193057500_ARACHNIDES_1 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_0
# https://w3id.org/eb/i/Topic/9910796273804340_193057501_RASRAS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_0
# https://w3id.org/eb/i/Topic/9910796273804340_193108322_ASTRONOMY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_0
# https://w3id.org/eb/i/Article/9910796273804340_193322688_DOVE_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_0
# https://w3id.org/eb/i/Topic/9910796273804340_193322689_MAMMALIA_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_0
# https://w3id.org/eb/i/Article/9910796273804340_193469090_PEITOC_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_0
# https://w3id.org/eb/i/Topic/9910796273804340_193469091_PAPERMONEY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_0
# https://w3id.org/eb/i/Topic/9910796273804340_193469091_PERSPECTIVE_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_0
# https://w3id.org/eb/i/Article/9910796273804340_193469092_PORTLAND_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_0
# https://w3id.org/eb/i/Topic/9910796273804340_193638940_HELMINTHOLOGY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_0
# https://w3id.org/eb/i/Article/9910796273804340_193696084_FLANEL_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_0
# https://w3id.org/eb/i/Topic/9910796273804340_193696084_FLUXIONS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_1
# https://w3id.org/eb/i/Article/9910796273804340_192984258_DARW_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_1
# https://w3id.org/eb/i/Topic/9910796273804340_192984258_INDEX_2 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_1
# https://w3id.org/eb/i/Topic/9910796273804340_193057500_ARACHNIDES_1 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_1
# https://w3id.org/eb/i/Topic/9910796273804340_193057501_RASRAS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_1
# https://w3id.org/eb/i/Topic/9910796273804340_193108322_ASTRONOMY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_1
# https://w3id.org/eb/i/Article/9910796273804340_193322688_DOVE_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_1
# https://w3id.org/eb/i/Topic/9910796273804340_193322689_MAMMALIA_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_1
# https://w3id.org/eb/i/Article/9910796273804340_193469090_PEITOC_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_1
# https://w3id.org/eb/i/Topic/9910796273804340_193469091_PAPERMONEY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_1
# https://w3id.org/eb/i/Topic/9910796273804340_193469091_PERSPECTIVE_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_1
# https://w3id.org/eb/i/Article/9910796273804340_193469092_PORTLAND_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_1
# https://w3id.org/eb/i/Topic/9910796273804340_193638940_HELMINTHOLOGY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_1
# https://w3id.org/eb/i/Article/9910796273804340_193696084_FLANEL_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_1
# https://w3id.org/eb/i/Topic/9910796273804340_193696084_FLUXIONS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_1
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_2
# https://w3id.org/eb/i/Article/9910796273804340_192984258_DARW_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_2
# https://w3id.org/eb/i/Topic/9910796273804340_192984258_INDEX_2 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_2
# https://w3id.org/eb/i/Topic/9910796273804340_193057500_ARACHNIDES_1 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_2
# https://w3id.org/eb/i/Topic/9910796273804340_193057501_RASRAS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_2
# https://w3id.org/eb/i/Topic/9910796273804340_193108322_ASTRONOMY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_2
# https://w3id.org/eb/i/Article/9910796273804340_193322688_DOVE_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_2
# https://w3id.org/eb/i/Topic/9910796273804340_193322689_MAMMALIA_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_2
# https://w3id.org/eb/i/Article/9910796273804340_193469090_PEITOC_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_2
# https://w3id.org/eb/i/Topic/9910796273804340_193469091_PAPERMONEY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_2
# https://w3id.org/eb/i/Topic/9910796273804340_193469091_PERSPECTIVE_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_2
# https://w3id.org/eb/i/Article/9910796273804340_193469092_PORTLAND_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_2
# https://w3id.org/eb/i/Topic/9910796273804340_193638940_HELMINTHOLOGY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_2
# https://w3id.org/eb/i/Article/9910796273804340_193696084_FLANEL_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_2
# https://w3id.org/eb/i/Topic/9910796273804340_193696084_FLUXIONS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_2
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_3
# https://w3id.org/eb/i/Article/9910796273804340_192984258_DARW_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_3
# https://w3id.org/eb/i/Topic/9910796273804340_192984258_INDEX_2 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_3
# https://w3id.org/eb/i/Topic/9910796273804340_193057500_ARACHNIDES_1 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_3
# https://w3id.org/eb/i/Topic/9910796273804340_193057501_RASRAS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_3
# https://w3id.org/eb/i/Topic/9910796273804340_193108322_ASTRONOMY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_3
# https://w3id.org/eb/i/Article/9910796273804340_193322688_DOVE_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_3
# https://w3id.org/eb/i/Topic/9910796273804340_193322689_MAMMALIA_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_3
# https://w3id.org/eb/i/Article/9910796273804340_193469090_PEITOC_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_3
# https://w3id.org/eb/i/Topic/9910796273804340_193469091_PAPERMONEY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_3
# https://w3id.org/eb/i/Topic/9910796273804340_193469091_PERSPECTIVE_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_3
# https://w3id.org/eb/i/Article/9910796273804340_193469092_PORTLAND_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_3
# https://w3id.org/eb/i/Topic/9910796273804340_193638940_HELMINTHOLOGY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_3
# https://w3id.org/eb/i/Article/9910796273804340_193696084_FLANEL_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_3
# https://w3id.org/eb/i/Topic/9910796273804340_193696084_FLUXIONS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_3
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_4
# https://w3id.org/eb/i/Article/9910796273804340_192984258_DARW_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_4
# https://w3id.org/eb/i/Topic/9910796273804340_192984258_INDEX_2 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_4
# https://w3id.org/eb/i/Topic/9910796273804340_193057500_ARACHNIDES_1 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_4
# https://w3id.org/eb/i/Topic/9910796273804340_193057501_RASRAS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_4
# https://w3id.org/eb/i/Topic/9910796273804340_193108322_ASTRONOMY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_4
# https://w3id.org/eb/i/Article/9910796273804340_193322688_DOVE_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_4
# https://w3id.org/eb/i/Topic/9910796273804340_193322689_MAMMALIA_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_4
# https://w3id.org/eb/i/Article/9910796273804340_193469090_PEITOC_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_4
# https://w3id.org/eb/i/Topic/9910796273804340_193469091_PAPERMONEY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_4
# https://w3id.org/eb/i/Topic/9910796273804340_193469091_PERSPECTIVE_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_4
# https://w3id.org/eb/i/Article/9910796273804340_193469092_PORTLAND_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_4
# https://w3id.org/eb/i/Topic/9910796273804340_193638940_HELMINTHOLOGY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_4
# https://w3id.org/eb/i/Article/9910796273804340_193696084_FLANEL_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_4
# https://w3id.org/eb/i/Topic/9910796273804340_193696084_FLUXIONS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ISLAND_4
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193469092_ISLAND_0
# https://w3id.org/eb/i/Article/9910796273804340_192984258_DARW_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193469092_ISLAND_0
# https://w3id.org/eb/i/Topic/9910796273804340_192984258_INDEX_2 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193469092_ISLAND_0
# https://w3id.org/eb/i/Topic/9910796273804340_193057500_ARACHNIDES_1 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193469092_ISLAND_0
# https://w3id.org/eb/i/Topic/9910796273804340_193057501_RASRAS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193469092_ISLAND_0
# https://w3id.org/eb/i/Topic/9910796273804340_193108322_ASTRONOMY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193469092_ISLAND_0
# https://w3id.org/eb/i/Article/9910796273804340_193322688_DOVE_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193469092_ISLAND_0
# https://w3id.org/eb/i/Topic/9910796273804340_193322689_MAMMALIA_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193469092_ISLAND_0
# https://w3id.org/eb/i/Article/9910796273804340_193469090_PEITOC_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193469092_ISLAND_0
# https://w3id.org/eb/i/Topic/9910796273804340_193469091_PAPERMONEY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193469092_ISLAND_0
# https://w3id.org/eb/i/Topic/9910796273804340_193469091_PERSPECTIVE_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193469092_ISLAND_0
# https://w3id.org/eb/i/Article/9910796273804340_193469092_PORTLAND_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193469092_ISLAND_0
# https://w3id.org/eb/i/Topic/9910796273804340_193638940_HELMINTHOLOGY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193469092_ISLAND_0
# https://w3id.org/eb/i/Article/9910796273804340_193696084_FLANEL_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193469092_ISLAND_0
# https://w3id.org/eb/i/Topic/9910796273804340_193696084_FLUXIONS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193469092_ISLAND_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_DARRA_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_DARTFORD_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_DARTMOUTH_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_DARWAR_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_DASAN_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_DATA_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_DATE_0
# https://w3id.org/eb/i/Topic/9910796273804340_193469092_POORLAWS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_DATE_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193322688_DRAGOONING_0
# https://w3id.org/eb/i/Topic/9910796273804340_192984258_INDEX_2 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193322688_DRAGOONING_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193322688_DRAGUIGNAN_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193322688_DRAINING_0
# https://w3id.org/eb/i/Topic/9910796273804340_192984258_INDEX_2 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193322688_DRAINING_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193322690_CAMBRIDGESHIRE_0
# https://w3id.org/eb/i/Topic/9910796273804340_192984258_INDEX_2 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193322690_CAMBRIDGESHIRE_0
# https://w3id.org/eb/i/Topic/9910796273804340_192984259_AGRICULTURE_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193322690_CAMBRIDGESHIRE_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193913444_SHAKSPEARE_0
# https://w3id.org/eb/i/Topic/9910796273804340_192984258_INDEX_2 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193913444_SHAKSPEARE_0
# https://w3id.org/eb/i/Topic/9910796273804340_193322688_DRAMA_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193913444_SHAKSPEARE_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193322688_DRAMA_0
# https://w3id.org/eb/i/Topic/9910796273804340_192984258_INDEX_2 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193322688_DRAMA_0
# https://w3id.org/eb/i/Article/9910796273804340_192984259_ACTOR_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193322688_DRAMA_0
# https://w3id.org/eb/i/Article/9910796273804340_193696084_EPIGONI_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193322688_DRAMA_0
# https://w3id.org/eb/i/Article/9910796273804340_193696084_FARCE_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193322688_DRAMA_0
# https://w3id.org/eb/i/Article/9910796273804340_193819043_COMEDY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193322688_DRAMA_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193322688_DURBUNGAH_0
# https://w3id.org/eb/i/Topic/9910796273804340_192547789_INDEX_3 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193322688_DUREN_0
# ...
# https://w3id.org/eb/i/Topic/9910796273804340_193819045_VALDO_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193819045_VALDENSES_0
# https://w3id.org/eb/i/Article/9910796273804340_193819045_WALDECK_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193819045_VALDENSES_0
# https://w3id.org/eb/i/Topic/9910796273804340_193819045_VALDO_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193108323_LAON_0
# https://w3id.org/eb/i/Article/9910796273804340_193819045_VAUCLUSE_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193469090_FREYBURG_0
# https://w3id.org/eb/i/Article/9910796273804340_193819045_VESTA_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_CYBELE_0
# https://w3id.org/eb/i/Article/9910796273804340_193819045_VOCALIZE_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193913444_SOLFA_0
# https://w3id.org/eb/i/Topic/9910796273804340_193819045_VOLTAICELECTRICITY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193469092_PLATINA_0
# https://w3id.org/eb/i/Topic/9910796273804340_193819045_VOLTAICELECTRICITY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819045_ZINC_0
# https://w3id.org/eb/i/Topic/9910796273804340_193819045_VOLTAICELECTRICITY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193638940_HARE_0
# https://w3id.org/eb/i/Topic/9910796273804340_193819045_VOLTAICELECTRICITY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193819043_DAVY_0
# https://w3id.org/eb/i/Topic/9910796273804340_193819045_WALESNEWSOUTH_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193469092_POPULATION_0
# https://w3id.org/eb/i/Topic/9910796273804340_193819045_WATERWORKS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193469092_PUMP_0
# https://w3id.org/eb/i/Article/9910796273804340_193819045_WI_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_194474782_NEWBURY_0
# https://w3id.org/eb/i/Article/9910796273804340_193819045_WOTTON_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_194474782_NEYER_0
# https://w3id.org/eb/i/Article/9910796273804340_193819045_WOTTON_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193638940_GUJERAT_0
# https://w3id.org/eb/i/Article/9910796273804340_193819045_WOTTON_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193819043_CUTCH_0
# https://w3id.org/eb/i/Topic/9910796273804340_193913444_SPINNING_1 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193819043_CUTCH_0
# https://w3id.org/eb/i/Topic/9910796273804340_193819045_ZEALANDNEW_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193108323_LIMA_0
# https://w3id.org/eb/i/Topic/9910796273804340_193819045_ZEALANDNEW_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819045_ALL_0
# https://w3id.org/eb/i/Topic/9910796273804340_193819045_ZEALANDNEW_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_NICHOLAS_0
# https://w3id.org/eb/i/Topic/9910796273804340_193819045_ZEALANDNEW_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193469091_PARKER_0
# https://w3id.org/eb/i/Article/9910796273804340_193819045_ZETLAND_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819045_YELL_0
# https://w3id.org/eb/i/Article/9910796273804340_193819045_ZETLAND_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819045_UNICORN_0
# https://w3id.org/eb/i/Topic/9910796273804340_193819045_ZOOPHYTES_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193322688_ECHINUS_0
# https://w3id.org/eb/i/Topic/9910796273804340_193819045_ZOOPHYTES_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193696084_EARN_0
# https://w3id.org/eb/i/Article/9910796273804340_193913444_SEMIPELAGIANS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193469091_PELAGIANS_0
# https://w3id.org/eb/i/Article/9910796273804340_193913444_SEMIPELAGIANS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193469091_PELAGIUS_0
# https://w3id.org/eb/i/Article/9910796273804340_193913444_SEMIPELAGIANS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_194474782_NUMIDIA_0
# https://w3id.org/eb/i/Article/9910796273804340_193913444_SEMIPELAGIANS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_194474782_NUMIDIA_1
# https://w3id.org/eb/i/Article/9910796273804340_193913444_SEMIPELAGIANS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193469091_PAULINUS_0
# https://w3id.org/eb/i/Article/9910796273804340_193913444_SERINAGUR_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193108323_LAHORE_0
# https://w3id.org/eb/i/Article/9910796273804340_193913444_SERINAGUR_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193108323_LAHORE_1
# https://w3id.org/eb/i/Article/9910796273804340_193913444_SERINAGUR_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_DEVAPRAYAGA_0
# https://w3id.org/eb/i/Article/9910796273804340_193913444_SERPENS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193913444_SIRENS_0
# https://w3id.org/eb/i/Topic/9910796273804340_193913444_SERPENTS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819045_BOA_0
# https://w3id.org/eb/i/Topic/9910796273804340_193913444_SERPENTS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819045_BOA_1
# https://w3id.org/eb/i/Topic/9910796273804340_193913444_SERPENTS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819045_SWAMMERDAM_0
# https://w3id.org/eb/i/Topic/9910796273804340_193913444_SERPENTS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_COLUBER_0
# https://w3id.org/eb/i/Topic/9910796273804340_193913444_SERPENTS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193108323_LABAT_0
# https://w3id.org/eb/i/Topic/9910796273804340_193913444_SERPENTS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ABADIR_0
# https://w3id.org/eb/i/Topic/9910796273804340_193913444_SERPENTS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192984259_ABADIR_0
# https://w3id.org/eb/i/Topic/9910796273804340_193913444_SERPENTS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193108323_MAGI_0
# https://w3id.org/eb/i/Topic/9910796273804340_193913444_SERPENTS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_COLCHIS_0
# https://w3id.org/eb/i/Topic/9910796273804340_193913444_SERPENTS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ABADDON_0
# https://w3id.org/eb/i/Topic/9910796273804340_193913444_SERPENTS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192984259_ABADDON_0
# https://w3id.org/eb/i/Article/9910796273804340_193913444_SEWISTAN_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193913444_SEISTAN_0
# https://w3id.org/eb/i/Topic/9910796273804340_193913444_SHESHIMMS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193322690_CARNATIC_0
# https://w3id.org/eb/i/Topic/9910796273804340_193913444_SHESHIMMS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ARCOT_0
# https://w3id.org/eb/i/Topic/9910796273804340_193913444_SHESHIMMS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_COMORIN_0
# https://w3id.org/eb/i/Topic/9910796273804340_193913444_SHIPBUILDING_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193469092_PROFILE_0
# https://w3id.org/eb/i/Topic/9910796273804340_193913444_SILKWORM_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819045_CAB_0
# https://w3id.org/eb/i/Topic/9910796273804340_193913444_SOCRATES_1 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ASSEMBLY_0
# https://w3id.org/eb/i/Topic/9910796273804340_193913444_SOCRATES_1 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193057501_RAN_0
# https://w3id.org/eb/i/Article/9910796273804340_193913444_SOLEURE_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193913444_SOLOTHURN_0
# https://w3id.org/eb/i/Topic/9910796273804340_193913444_SPAIN_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_BARCELONA_0
# https://w3id.org/eb/i/Topic/9910796273804340_193913444_SPINNING_1 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193108323_LUSITANIA_0
# https://w3id.org/eb/i/Topic/9910796273804340_193913444_SPINNING_1 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193913444_SCULPTURE_0
# https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193913444_SCULPTURE_0
# https://w3id.org/eb/i/Topic/9910796273804340_193913444_SPINNING_1 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_194474782_NEPOS_0
# https://w3id.org/eb/i/Topic/9910796273804340_193913444_SPINNING_1 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_BAHAR_0
# https://w3id.org/eb/i/Article/9910796273804340_194474782_BEDFORD_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_194474782_NEWBURGH_0
# https://w3id.org/eb/i/Topic/9910796273804340_194474782_NAVIGATIONINLAND_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_COMMON_0
# https://w3id.org/eb/i/Topic/9910796273804340_194474782_NAVIGATIONINLAND_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_CANALS_0
# https://w3id.org/eb/i/Topic/9910796273804340_194474782_NAVIGATIONINLAND_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193108323_LEWES_0
# https://w3id.org/eb/i/Article/9910796273804340_194474782_NEALING_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ANNEALING_0
# https://w3id.org/eb/i/Article/9910796273804340_194474782_NEALING_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193057500_ANNEALING_0
# https://w3id.org/eb/i/Article/9910796273804340_194474782_NECESSITY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193469092_PREDESTINATION_0
# https://w3id.org/eb/i/Article/9910796273804340_194474782_NECESSITY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193469091_PATROCLUS_0
# https://w3id.org/eb/i/Article/9910796273804340_194474782_NEEDHAM_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_BARKING_0
# https://w3id.org/eb/i/Topic/9910796273804340_194474782_NILE_1 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193696084_MOUTH_0
# https://w3id.org/eb/i/Topic/9910796273804340_194474782_NILE_1 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ARGO_0
# https://w3id.org/eb/i/Topic/9910796273804340_194474782_NILE_1 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193322688_DONGOLA_0
# https://w3id.org/eb/i/Topic/9910796273804340_194474782_NILE_1 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193322688_ELEPHANTINE_0
# https://w3id.org/eb/i/Article/9910796273804340_194474782_NOAH_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_DEUCALION_0
# https://w3id.org/eb/i/Article/9910796273804340_194474782_NOYOGOROD_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_194474782_NOWOGOROD_0
# https://w3id.org/eb/i/Topic/9910796273804340_194474782_OPTICS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_192984259_ABERRATION_0
# https://w3id.org/eb/i/Topic/9910796273804340_194474782_OPTICS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193108323_LOAD_0
# https://w3id.org/eb/i/Topic/9910796273804340_194474782_OPTICS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_CYANOMETER_0
# https://w3id.org/eb/i/Article/9910796273804340_194474782_ORLEANS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819045_USK_0
# https://w3id.org/eb/i/Article/9910796273804340_194474782_ORLEANS_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819045_WIGHT_0
# https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193322688_TAN_0
# https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819045_TAN_0
# https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193322688_DUNCAN_0
# https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193913444_SELBY_0
# https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193057500_APICIUS_0
# https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193057501_RESURRECTION_0
# https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193108323_LIPPI_0
# https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_APOLLODORUS_0
# https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193057500_APOLLODORUS_0
# https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193057500_ANGELO_0
# https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193322689_MAJORCA_0
# https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_192547789_ALPHABET_0
# https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_DESERT_0
# https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Article/9910796273804340_193819043_DAMASCUS_0
# https://w3id.org/eb/i/Topic/9910796273804340_194474782_ORNITHOLOGY_0 https://w3id.org/eb#relatedTerms https://w3id.org/eb/i/Topic/9910796273804340_193819043_DAMASCUS_1

# %%
#G = rdflib_to_networkx_multidigraph(result)

# Plot Networkx instance of RDF Graph
#pos = nx.spring_layout(G, scale=2)
#edge_labels = nx.get_edge_attributes(G, 'r')
#nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)
#nx.draw(G, with_labels=True)

#if not in interactive mode for 
#plt.show()
