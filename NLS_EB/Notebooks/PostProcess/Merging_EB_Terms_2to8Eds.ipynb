# %% [markdown]
# # Merging EB terms-  NLS -  Encyclopaedia Britannica

# %% [markdown]
# ### Loading the necessary libraries

# %%
import yaml
import numpy as np
import collections
import string
import copy
import re

# %%
import pandas as pd
from yaml import safe_load
from pandas.io.json import json_normalize
from difflib import SequenceMatcher

# %%
from collections import Counter

# %% [markdown]
# ### Functions

# %%
def read_query_results(filename):
    with open('../../results_NLS/'+filename, 'r') as f:
        query_results = safe_load(f)
    return query_results

# %%
def write_query_results(filename, results):
    with open('../../results_NLS/'+filename, 'w') as f:
        documents = yaml.dump(results, f)

# %%
def sort_query_results(query_results):
    new_results={}
    for edition in query_results:
        new_results[edition]=[]
        page_list=[]
        for page_idx in range(0, len(query_results[edition])):
            page_num = query_results[edition][page_idx][0]
            if not page_list:
                page_list.append(page_num)
                new_results[edition].append(query_results[edition][page_idx])
            
            else:
                last_element=page_list[-1]
                if page_num >= last_element:
                    page_list.append(page_num)
                    new_results[edition].append(query_results[edition][page_idx])
                else:
                    ## insert the new page in page_list
                    i_dx=0
                    while page_list[i_dx] < page_num:
                        i_dx+=1
                    page_list.insert(i_dx, page_num)
                    new_results[edition].insert(i_dx,query_results[edition][page_idx])
    return new_results

# %%
def consistency_query_results(query_results):
      for i in query_results:
        for j in range(0, len(query_results[i])):
            page_num = query_results[i][j][0]
            if j < (len(query_results[i])-1):
                next_page_num = query_results[i][j+1][0]
                if page_num > next_page_num:
                    print("INCONSISTENCY for %s: %s and %s"% (i, page_num, next_page_num))

# %%
def create_dataframe(query_results):

    for edition in query_results:
        for page in query_results[edition]:
            #print(page[1].keys())
            column_list=list(page[1].keys())
            break
        break
        
    data=[]
    for edition in query_results:
        for page in query_results[edition]:
            try:
                data.append(page[1])
               
            except:
                pass
    df = pd.DataFrame(data, columns = column_list)
    #removing the columns that I dont need 
    df= df.drop(['model', 'num_page_words', 'text_unit', 'type_archive'], axis=1)
    #df= df.drop(['last_term_in_page', 'model', 'num_page_words', 'text_unit', 'type_archive'], axis=1)
    #renaming the page num
    df= df.rename(columns={"text_unit_id": "startsAt", "end_page":"endsAt",\
                           "type_page": "typeTerm", "edition":"editionTitle",\
                           "title":"volumeTitle", "related_terms":"relatedTerms",\
                           "source_text_file": "altoXML", "num_articles": "numberOfTerms", "num_text_unit": "numberOfPages", \
                           "num_article_words":"numberOfWords", "term_id_in_page":"positionPage"})
     
    #removing 'Page' from the string
    df["startsAt"] = df["startsAt"].str.replace("Page", "", regex=True)
    df["startsAt"] = df["startsAt"].astype(int)
    df["endsAt"] = df["endsAt"].astype(int)
   
    
    df['term'] = df["term"].str.replace("_def", "",  regex=True)
    df['term']= df["term"].str.replace('[^a-zA-Z0-9]', '',  regex=True)
    
    #mask=df["term"].str.isalpha()
    #df_new=df.loc[mask]
    
    
    
    df['term'] = df['term'].str.upper()
    
    
    df["volumeNum"] = 0
    df["letters"] = ""
    df["part"] = 0
    
    
    mask = df["editionTitle"].str.contains('Volume')
    for i in range(0, len (mask)):
     
        if mask[i]:
            tmp=df.loc[i,'editionTitle'].split("Volume ")[1].split(",")
            if len(tmp)>=1:
                volume= tmp[0]
                letters = tmp[-1].replace(" ","")
                part_tmp = volume.split("Part ")
                if len(part_tmp)>1:
                    volume=part_tmp[0]
                    part = part_tmp[1]
    
                    try:
                        part = int(part)
                    except:
                        if "I" in part:
                            part = 1
                else:
                    part=0

                volume = int(volume)
                df.loc[i, "letters"] = letters
                df.loc[i,"part"] = part
                df.loc[i ,"volumeNum"] = volume
    
    df["editionNum"] = "0"
    list_editions={"1":["first", "First"], "2":["second", "Second"],"3":["third", "Third"],
                   "4":["fourth", "Fourth"], "5":["fifth","Fifth"], "6":["sixth","Sixth"], 
                   "7":["seventh", "Seventh"], "8":["eighth", "Eighth"]}
    
    for ed in list_editions:
        for ed_versions in list_editions[ed]:
            mask = df["editionTitle"].str.contains(ed_versions)
            df.loc[mask, 'editionNum'] = ed
            
            
    df['editionNum']=df["editionNum"].astype(int)    
    df["supplementTitle"]=""
    df["supplementsTo"]=""
    
    mask= df["volumeTitle"].str.contains("Supplement")
    for i in range(0, len (mask)):
        if mask[i]:
            df.loc[i, 'supplementTitle'] = df.loc[i, 'volumeTitle']
            df.loc[i, 'volumeTitle'] = df.loc[i, 'volumeTitle'] + ","+df.loc[i, 'editionTitle']
            title= df.loc[i, 'supplementTitle']
            related_editions=[]
            for ed in list_editions:
                for ed_versions in list_editions[ed]:
                    if ed_versions in title:
                        related_editions.append(ed)
                        
            df.loc[i, "supplementsTo"]=','.join(related_editions)
            
    df["supplementsTo"] = df.supplementsTo.str.split(",").tolist()
    a=df["archive_filename"].str.split("/").str[-1]
    df['altoXML']= a+ "/" + df["altoXML"]   
    df= df.drop(['archive_filename'], axis=1)
   
    df = df[["term", "definition", "relatedTerms", "header", "startsAt", "endsAt", "numberOfTerms","numberOfWords", "numberOfPages", \
             "positionPage", "typeTerm", "editionTitle", "editionNum", "supplementTitle", "supplementsTo", \
             "year", "place", "volumeTitle", "volumeNum", "letters", "part", "altoXML"]]
    
    df = df[df['term'] != '']
    mask=df["term"].str.isalpha()
    df=df.loc[mask] 
    
    ### NEW DECISION: Move Mix Articles as Article
    mask = df["typeTerm"].str.contains("Mix")
    df.loc[mask, 'typeTerm'] = "Article"
    ###########
    return df

# %%
def similar(a, b):
    a=a.lower()
    b=b.lower()
    return SequenceMatcher(None, a, b).ratio()

# %%
def most_frequent_simple(List):
    ### removed '' and ' ' keys
    if '' in List: 
        List.remove('')
    if len(List) > 1:
        a= max(set(List), key = List.count)
        return a
    else:
        return ''

# %%
def most_frequent(words_list, prev_car=None):
    
    result=''
    if '' in words_list: 
        words_list.remove('')
        
    for i in words_list:
        if len(i)<=2:
            words_list.remove(i)
        
    if prev_car=="":
        prev_car= None
        
    if len(words_list) > 1:
        
        c = [item for item in Counter(words_list).most_common(2)]
        
        if len(c) > 1:
            if len(c[0][0]) < 1 and len(c[1][0])>=1:
                result= c[1][0]
        
            elif len(c[0][0]) >= 1 and len(c[1][0])<1:
                result= c[0][0]

            elif len(c[0][0]) < 1 and len(c[1][0])<1:
                result=''
            
            elif c[0][1] == c[1][1]:
        
                similar_count={}
                similar_count[c[0][0]]=0
                similar_count[c[1][0]]=0
        
                for i in words_list:
                    if i != c[0][0] and i!=c[1][0]:
                        
                
                        if similar(i, c[0][0]) > similar(i, c[1][0]):
                            similar_count[c[0][0]]+=1
                    
                        elif similar(i, c[0][0]) < similar(i, c[1][0]):
                            similar_count[c[1][0]]+=1
                 
                if  similar_count[c[0][0]] > similar_count[c[1][0]]:
                    result= c[0][0]
                
                elif similar_count[c[0][0]] < similar_count[c[1][0]]:
        
                    result= c[1][0]
            
            
                if prev_car:
                    if c[0][0][0] == prev_car:
                    
                        result= c[0][0]
                        
                    elif c[1][0][0] == prev_car:
                     
                        result= c[1][0]
                    
                    elif c[0][0][0]> prev_car:
                        result= c[0][0]
                    
                    else:
                        result= c[1][0]
                     
                
                else:
                    result= c[0][0]
            else:
                 result= c[0][0]
        else:
            result= c[0][0]
    return result

# %%
def check_string(term, List):
    flag = 0
    for element in List:
        if term in element:
            flag = 1
            break
    if flag == 1:
        return True
    else:
        return False

# %%
def clean_topics_terms(term):
    table = str.maketrans('', '', string.ascii_lowercase)
    return term.translate(table)

# %%
def create_dataframe_from_file(filename):
    with open('../../results_NLS/'+filename, 'r') as f:
        query_results = safe_load(f)
    
    df = create_dataframe(query_results)
    return df

# %%
def prune_json(json_dict):
    """
    Method that given a JSON object, removes all its empty fields.
    This method simplifies the resultant JSON.
    :param json_dict input JSON file to prune
    :return JSON file removing empty values
    """
    final_dict = {}
    if not (isinstance(json_dict, dict)):
        # Ensure the element provided is a dict
        return json_dict
    else:
        for a, b in json_dict.items():
            if b or isinstance(b, bool):
                if isinstance(b, dict):
                    aux_dict = prune_json(b)
                    if aux_dict:  # Remove empty dicts
                        final_dict[a] = aux_dict
                elif isinstance(b, list):
                    aux_list = list(filter(None, [prune_json(i) for i in b]))
                    if len(aux_list) > 0:  # Remove empty lists
                        final_dict[a] = aux_list
                else:
                    final_dict[a] = b
    return final_dict

# %%
def delete_entries(query_results_updated, eliminate_pages):
    new_results={}
    for edition in query_results_updated:
        new_results[edition]=[]
        for page_idx in range(0, len(query_results_updated[edition])):
            if page_idx not in eliminate_pages[edition]:
                new_results[edition].append(query_results_updated[edition][page_idx])
    return new_results

# %%
def deleting_adding_entries(query_results_up, eliminate_pages, create_entries):
    new_results={}
    flag = 1
    for edition in query_results_up:
        new_results[edition]=[]
        for page_idx in range(0, len(query_results_up[edition])):
            if page_idx not in eliminate_pages[edition]:
                new_results[edition].append(query_results_up[edition][page_idx])
            else:
                for new_pages in create_entries[edition][page_idx]:
                    new_results[edition].append(new_pages)
            
        
    return new_results

# %%
def related_terms_info(related_terms):
    related_data=[]
    for elem in related_terms:
        if elem.isupper() or "." in elem or "," in elem:
            elem=elem.split(".")[0]
            term=elem.split(",")[0]
            if len(term)>2 and term[0].isupper() :
                m = re.search('^([0-9]+)|([IVXLCM]+)\\.?$', term)
                if m is None:
                    term_up = term.upper()
                    if term_up !="FIG" and term_up !="NUMBER" and term_up!="EXAMPLE" and term_up!="PLATE" and term_up!="FIGURE":
                        #related_data.append(term_up) and term_up!="EXAMPLE" and term_up!="PLATE" and term_up!="FIGURE"
                        related_data.append(term_up.strip())
    return related_data

# %%
def page2full_pages(element):

    
    term = element["term"]
    header = element["header"]
    type_page = element["type_page"]
    definition = element["definition"]
  
   
    if (type_page == "Empty") and len(definition)<100 and element["num_articles"]<2:
        type_page ="FullPage"
    
    elif ("PREFACE" in term) or ("PREFACE" in header):
        term = "PREFACE"
        header = "PREFACE"
        type_page="FullPage"
       
    
    elif ("PLATE" in term) or ("PLARF" in term) or ("ELATE" in term) or ("TLAFE" in term):
        header = "Plate"
        term = "Plate"
        type_page = "FullPage"
      
        
    elif ("PLATE" in header) or ("PLAFR" in header) or ("ELATE" in header) or ("TLAFE" in header):
        header = "Plate"
        term = "Plate"
        type_page = "FullPage"
      
        
    elif ("ARTSANDSCI" in term) or ("ARTSANDSCI" in header):
        header = "FrontPage"
        term = "FrontPage"
        type_page="FullPage"
        

        
    elif "ERRATA" in term or ("ERRATA" in header):
        header = "ERRATA"
        term = "ERRATA"
        type_page="FullPage"
       
        
   
    elif (" LISTOFAUTHORSC" in term) or ("LISTOFAUTHORS" in term) or ("LISTOFAUTHORSC" in term) or ("LISTAUTHORS" in term):
        header = "AuthorList"
        term = "AuthorList"
        type_page="FullPage"
        
        
    elif (" LISTOFAUTHORSC" in header) or ("LISTOFAUTHORS" in header) or ("LISTOFAUTHORSC" in header) or ("LISTAUTHORS" in header):
        header = "AuthorList"
        term = "AuthorList"
        type_page="FullPage"
       
        
    
    element["term"] = term
    element["header"] = header
    element["type_page"] = type_page
   
    return element

# %%
def fixing_fullPages(query_results):
    parts_string=["Part", "Fart", "Parc", "CPart","P", "PI", "PII", "PIII", "P", "C", "PXXIV", "IV", "VI" "VII", "VIII", "IX", "XI"]
    create_entries={}
    eliminate_pages={}
    for edition in query_results:
        create_entries[edition]={}
        eliminate_pages[edition]=[]
        flag_p = 1
        for page_idx in range(0, len(query_results[edition])):
            element = query_results[edition][page_idx][1]
            current_page = query_results[edition][page_idx][0]
            
            if int(current_page) <= 10:
                element["type_page"] = "FullPage"
            
            elif int(current_page) > 10 and int(current_page) < 20:
                if element["type_page"]!="FullPage":
                    element = page2full_pages(element)
                    next_element= query_results[edition][page_idx+1][1]
                    
                if element["type_page"]!="FullPage" and next_element["type_page"]=="FullPage" and len(element["definition"])<50:
                    #print("changing-3 to FULL PAGE %s" %current_page)
                    element["type_page"] = "FullPage"
                
            elif int(current_page)>=20 and element["type_page"] == "Empty" and (len(element["term"])<=5 or check_string(element["term"], parts_string)) and element["num_articles"]< 2 and len(element["definition"])<100:
                element["type_page"] = "FullPage"
                #print("changing-1 to FULL PAGE %s" %current_page)
            
            elif int(current_page)>=20 and element["type_page"] == "Topic" and (len(element["term"])<=5 or check_string(element["term"], parts_string)) and len(element["definition"])<100:
                element["type_page"] = "FullPage"
                #print("changing-2 to FULL PAGE %s" %current_page)
                
            
            
        
                
                
            
    return query_results

# %%
def fixing_articles(query_results):
    create_entries={}
    eliminate_pages={}
    parts_string=["S", "HXXA", "P", "C","", " ", "_", "-", "Part", "Fart", "Parc", "CPart","P", "PI", "PII", "PIII", "P", "C", "IV", "VI" "VII", "VIII", "IX", "XI"]
    for edition in query_results:
        create_entries[edition]={}
        eliminate_pages[edition]=[]
        flag_p = 1
        for page_idx in range(0, len(query_results[edition])):
            element = query_results[edition][page_idx][1]
            element_page = query_results[edition][page_idx][0]
            if page_idx >=1 and page_idx < len(query_results[edition])-1:
                    prev_element = query_results[edition][page_idx-1][1]
            if page_idx < len(query_results[edition])-1:
                    next_element=query_results[edition][page_idx+1][1]
            flag = 0
            
            if (element["type_page"]=="Empty" and element["num_articles"]>2):
                
                #print("Moving %s which is empty to Articles" %element_page)
                element["type_page"]="Article"
        
            
            elif (element["type_page"]=="Topic") or (element["type_page"]=="FullPage" and element_page>15) or (element["type_page"]=="Empty" and element["num_articles"]==1):
                print("ENTRO Page %s  - type page %s, term %s" %(element_page, element["type_page"], element["term"]))
                list_terms=[]
                new_entries=[]
                definition=element["definition"]
                definition_list= definition.split(" ")
                term = element["term"].strip()
                flag = 0
                sub_elements=[]
                for word_idx in range(0, len(definition_list)):
                    word = definition_list[word_idx]
                    if ((word.isupper() and "," in word) or (word.isupper() and ";" in word)) and len(word)>3 and "See "!= definition_list[word_idx-1] and "SEE " != definition_list[word_idx-1]:
                        if "," in word:
                            sub_elements.append((word.split(",")[0],word_idx))
                        elif ";" in word:
                            sub_elements.append((word.split(";")[0],word_idx))
                        flag = 1
                
                ### rest_of_editions
                if page_idx < len(query_results[edition])-1:
                    if len(sub_elements) > 1 and next_element["type_page"]=="Article":
                        flag = 1
                        
                if page_idx >=1 and page_idx < len(query_results[edition])-1:

                    if (definition_list[1] == prev_element["definition"].split(" ")[-1]):
                        flag = 1            
                
                if flag: 
                    print("ENTRO-2 Page %s - new def %s" % (element_page, sub_elements))
                    for elem_idx in range(0, len(sub_elements)):
                        term_id = 0
                       
                        new_element={}
                        elem=sub_elements[elem_idx]
                        new_element["term"]=elem[0].strip()
     
                        if elem_idx+1 < len(sub_elements):
                            sentence=definition_list[elem[1]+1: sub_elements[elem_idx+1][1]]
                            new_element["definition"]=' '.join(sentence)
                       
                            
                        else:
                            new_element["last_term_in_page"] = 1
                            try:
                                sentence= definition_list[elem[1]+1:][1]
                                new_element["definition"]=' '.join(sentence)
        
                            except:
                                sentence= definition_list[elem[1]:]
                                if len(sentence) > 3:
                                    new_element["definition"]=' '.join(sentence)
       
                        if "definition" in new_element: 
                            #%and len(new_element["term"])>=3:
                            
                            new_element["type_page"] = "Article" 
                            new_element["num_article_words"] = len(sentence)  
                            #### related terms ##### 
                            related_terms=[]
                            if "See " in new_element["definition"]:
                                related_terms= new_element["definition"].split("See ")[1]
                            elif "SEE " in new_element["definition"]:
                                related_terms= new_element["definition"].split("SEE ")[1]  
                            new_element["related_terms"]=related_terms_info(related_terms)
                            ####
                            
                            new_element["term_id_in_page"]=term_id 
                            new_element["archive_filename"]= element["archive_filename"]
                            new_element["header"] = element["header"]
                            new_element["model"] = element["model"]
                            new_element["num_page_words"]= element["num_page_words"]
                            new_element["num_text_unit"] = element["num_text_unit"]
                            new_element["place"] = element["place"]
                            new_element["source_text_file"] = element["source_text_file"]
                            new_element["text_unit"] = element["text_unit"]
                            new_element["text_unit_id"] = element["text_unit_id"]
                            new_element["title"] = element["title"]
                            new_element["type_archive"] = element["type_archive"]
                            new_element["year"] = element["year"]
                            new_element["end_page"] =int(element['text_unit_id'].split("Page")[1])
                            new_element["edition"] = element["edition"]
                            
                            new_entries.append(new_element)
                            list_terms.append(new_element["term"].strip())
                            term_id += 1
                            
                print("------ BEFORE %s - len %s" %(list_terms, len(list_terms)))
                
                r_removals=[]
                l_term = 0
                for l_term in range(0, len(list_terms)):
                    print("element  %s" %list_terms[l_term])
                    if check_special_caracters(list_terms[l_term]) or has_numbers(list_terms[l_term]):
                        r_removals.append(list_terms[l_term]) 
                    l_term=l_term +1
                    
                for r_term in r_removals:
                    list_terms.remove(r_term)
                
                
                print("AFTER %s - len %s" %(list_terms, len(list_terms)))
                        
                if len(list_terms) >= 1:
                    if len(list_terms) == 1 and list_terms[0]== element["term"]:
                        pass
                    elif len(list_terms)<=6 and next_element["type_page"]=="Topic" and prev_element["type_page"]=="Topic":
                        pass
                    else:
                        for i in new_entries:
                            i["num_articles"] = len(list_terms)
                        print("MOVING TOPICS TO ARTILCES PAGE %s" %query_results[edition][page_idx][0])
                        eliminate_pages[edition].append(page_idx)
                        create_entries[edition][page_idx]=[]
                        for new_d in new_entries:
                            create_entries[edition][page_idx].append([element_page, new_d])
                             
   
    new_results = deleting_adding_entries(query_results, eliminate_pages, create_entries)
    return new_results

# %%
def check_special_caracters(mystring):
    return any(not c.isalnum() for c in mystring)

# %%
def has_numbers(mystring):
    return any(c.isdigit() for c in mystring)

# %%
def fixing_topics(query_results):
    eliminate_pages={}
    for edition in query_results:
        eliminate_pages[edition]=[]
        page_idx = 0
        
        while page_idx < len(query_results[edition]):
            element = query_results[edition][page_idx][1]
            current_page = query_results[edition][page_idx][0]

            if  (element["type_page"]=="Mix") or (element["type_page"]=="Empty" and element["num_articles"]<2):
                prev_element = query_results[edition][page_idx-1][1]
                
                if prev_element["type_page"]=="Topic":
                    #print("ED %s MOVING Page %s - type_page %s term %s to Topic" %(edition, current_page, element["type_page"],  element["term"]))
                    
                    tmp_type = element["type_page"]
                    element["type_page"] = "Topic"

                    if tmp_type =="Empty":
                        element["term"] = prev_element["term"]
                    
                    elif similar(prev_element["term"].strip(), element["header"].strip()) > 0.70 or similar(prev_element["term"].strip(), element["term"].strip()) or prev_element["term"].strip() in element["definition"]:
                        element["term"] = prev_element["term"]
                    else:
                        element["term"] = element["header"].strip()
                    
                    if element["num_articles"] > 1:
                        for i in range(1, element["num_articles"]):
                            if page_idx + 1 < len(query_results[edition]):
                                page_idx += 1
                                n_element = query_results[edition][page_idx][1]
                                element["definition"]+=n_element["definition"]
                                element["num_article_words"]+=n_element["num_article_words"]
                                element["related_terms"]+= n_element["related_terms"]
                                eliminate_pages[edition].append(page_idx)
                            else:
                                print("Dont entering here - element %s - term %s -  page %s - page_idx %s - len %s" %(edition, element["term"], query_results[edition][page_idx][0], page_idx, len(query_results[edition])))
                            
                    element["num_articles"] = 1    
            page_idx +=1   
        
    new_results= delete_entries(query_results, eliminate_pages)              
    return new_results

# %%
def merge_articles(query_results):
    eliminate_pages={}
    page_number_dict={}
    for edition in query_results:
        eliminate_pages[edition]=[]
        page_number_dict[edition]={}

        for page_idx in range(0, len(query_results[edition])):
            prev_number = -1
            current_page=query_results[edition][page_idx][0]
            
            if current_page not in page_number_dict[edition]:
                page_number_dict[edition][current_page]=page_idx
            
            element = query_results[edition][page_idx][1]                               
                
            
            ###########################################        
            
            if "previous_page" in element['term']:
                current_definition= element["definition"]
                previous_page_idx= page_idx -1
                num_article_words=element["num_article_words"]
                related_terms=element["related_terms"]
            
                prev_elements = query_results[edition][previous_page_idx][1]
                prev_number = query_results[edition][previous_page_idx][0]
                if prev_elements["last_term_in_page"] and current_page > prev_number:
                    prev_elements["definition"]+=current_definition
                    prev_elements["num_article_words"]+=num_article_words
                    prev_elements["related_terms"]+= related_terms
                    prev_elements["end_page"] = current_page
                    
                    if prev_number in page_number_dict[edition] and prev_number != -1:
                        for prev_articles_idx in range(page_number_dict[edition][prev_number], page_idx):
                       
                            if query_results[edition][prev_articles_idx][0] == prev_number:
                           
                                 query_results[edition][prev_articles_idx][1]["num_page_words"]+=num_article_words
                    else:
                        print("Edition %s -ERROR between current page %s  and prev page %s-" % (edition,current_page, prev_number))
                  
                    pd_i = page_idx 
                    for i in range(1, element["num_articles"]):
                        if pd_i + 1 < len(query_results[edition]):
                            pd_i += 1
                            if query_results[edition][pd_i][0] == current_page:
                                n_element = query_results[edition][pd_i][1]
                                n_element["num_page_words"]-=num_article_words
                                n_element["num_articles"]-=1
                 
    
                
                eliminate_pages[edition].append(page_idx)
            else:
                element["end_page"] = current_page  
   
    new_results= delete_entries(query_results, eliminate_pages)
    
    return new_results

# %%
def removing_fullpages(query_results):
    
    eliminate_pages={}
    for edition in query_results:
        eliminate_pages[edition]=[]
        for page_idx in range(0, len(query_results[edition])):
            element=query_results[edition][page_idx][1]
            if element["type_page"]=="FullPage":
                eliminate_pages[edition].append(page_idx)
        

    new_results= delete_entries(query_results, eliminate_pages)
    
    return new_results

# %%
def merge_topics_orig(query_results):
    eliminate_pages={}
    provenance_removal={}
    freq_topics_terms={}
    merged_topics={}
    character_terms=[]
    parts_string=["Part", "Fart", "Parc", "CPart","P", "PI", "PII", "PIII", "P", "C", "PXXIV","IV", "VI" "VII", "VIII", "IX", "XI"]
    for edition in query_results:
        eliminate_pages[edition]=[]
        provenance_removal[edition]=[]
        freq_topics_terms[edition]={}
        merged_topics[edition]={}
        
        page_idx = 0
        while page_idx < len(query_results[edition]):
            current_page=query_results[edition][page_idx][0]        
            element = query_results[edition][page_idx][1]

            if "Topic" in element['type_page'] and element["term"]!="" and element["term"]!=" " and len(element["term"])>=2:
        
                term=element["term"].strip()
                clean_term=clean_topics_terms(term)
                p_id= page_idx + 1
                flag_force = 0  
                if p_id < len(query_results[edition]):
                    flag = 0
                    while p_id < len(query_results[edition]) and flag == 0:
                        
                        next_element = query_results[edition][p_id][1]
                        
   
                        if not check_string(next_element["term"], parts_string):
                            next_term=clean_topics_terms(next_element["term"].strip())
            
                        else:
                            next_term=next_element["term"].strip()
                            
                        
                        if p_id < len(query_results[edition])-1:             
                            two_next_element = query_results[edition][p_id+1][1]
                            if not check_string(two_next_element["term"], parts_string):
                                two_next_term=clean_topics_terms(two_next_element["term"])
                            else:
                                two_next_term=two_next_element["term"].strip()
                                
                        #m1 = re.search('^([0-9]+)|([IVXLCM]+)\\.?$', next_element["term"])
                        #m2 = re.search('^([0-9]+)|([IVXLCM]+)\\.?$', two_next_element["term"])
                        
                        definition1= next_element["definition"]
                        
                        #print("PAGE %s, len def %s" %(query_results[edition][p_id][0], len(definition)))
                    
                        if (similar(clean_term, next_term) > 0.70) or len(definition1)<=30  or check_string(next_term, parts_string) or check_string(two_next_term, parts_string)  or next_term in clean_term or next_term == "P" or two_next_term == "P" or similar(clean_term, two_next_term) > 0.70 or len(next_term)<=2 or len(two_next_term)<=3: 
                           
                            if clean_term!="" or clean_term!=" ":
                                if clean_term not in merged_topics[edition]:
                                    merged_topics[edition][clean_term]=[]
                                    merged_topics[edition][clean_term].append(clean_term)
                        
                                if not check_string(next_term, parts_string) and len(next_term)>3:
                                     merged_topics[edition][clean_term].append(next_term)
                            
                         
                            element["definition"]+=next_element["definition"]
                            element["num_article_words"]+=next_element["num_article_words"]
                            element["num_page_words"]+=next_element["num_page_words"]                  
                            element["related_terms"]+= next_element["related_terms"]
                            element["end_page"] = next_element['end_page']
                            provenance_removal[edition].append(element["end_page"])
                            eliminate_pages[edition].append(p_id)
                            #print("SIMILAR-TERMS, clean term %s, next_term %s, similarity %s,  len def1 %s, check1 %s, check 2 % future similarity %s, two_next_term %s" %(clean_term, next_term, similar(clean_term, next_term), len(definition1), check_string(next_term, parts_string),  check_string(two_next_term, parts_string), similar(clean_term, two_next_term), two_next_term))
                            p_id= p_id + 1
                            
                            if similar(clean_term, two_next_term) > 0.70 or len(two_next_term)<=2  or len(two_next_term)<=3 or check_string(two_next_term, parts_string):
                                
                                ## adding the two nexts ones. 
                                
                                element["definition"]+=two_next_element["definition"]
                                element["num_article_words"]+=two_next_element["num_article_words"]
                                element["num_page_words"]+=two_next_element["num_page_words"]                  
                                element["related_terms"]+= two_next_element["related_terms"]
                                element["end_page"] = two_next_element['end_page']
                                
                                provenance_removal[edition].append(element["end_page"])
                                
                                if not check_string(two_next_term, parts_string)  and two_next_term!="P" and len(two_next_term)>3:
                                     merged_topics[edition][clean_term].append(two_next_term)
                                        
                                eliminate_pages[edition].append(p_id)
                                #print("SIMILAR-2TERMS, clean term %s, two_next_terms %s, check %s" %(clean_term, two_next_term, check_string(two_next_term, parts_string)))
                                p_id= p_id + 1

                                
                        
                        else:
                            print("PASANDO AL SIGUIENTE: clean_term %s, next_term %s, two_next_terms %s " %(clean_term, next_term, two_next_term))
                            p_id= p_id + 1
                            flag = 1
                    
                    #print("FLAG %s, next page is %s" %(flag, query_results[edition][p_id][0]))
        
               
                page_idx = p_id
                if clean_term in merged_topics[edition]:
                   
                    if character_terms:
                        freq_term=most_frequent(merged_topics[edition][clean_term], character_terms[-1])
                    else:
                        freq_term=most_frequent(merged_topics[edition][clean_term])
                        
                    #print(">>>> ATENTION, merged_topics of %s are % and freq is %s" %(clean_term, merged_topics[edition][clean_term], freq_term))
                            
                    freq_topics_terms[edition][clean_term]=freq_term
                                        
                    element["term"]=freq_term.strip()
                    
                    
                else:
                    element["term"]=clean_term.strip()
        
                    
                if len(clean_term)>1:
                    character_terms.append(clean_term[0])  

            else:
                #print(">>> me salto %s - page %s" %(element["term"], current_page))
                page_idx += 1
                
            
        
    new_results= delete_entries(query_results, eliminate_pages)
    
    return new_results, merged_topics, freq_topics_terms, provenance_removal

# %%
def merge_topics(query_results):
    eliminate_pages={}
    provenance_removal={}
    freq_topics_terms={}
    merged_topics={}
    character_terms=[]
    parts_string=["S", "HXXA", "P", "C","", " ", "_", "-", "Part", "Fart", "Parc", "CPart","P", "PI", "PII", "PIII", "P", "C", "IV", "VI" "VII", "VIII", "IX", "XI"]
    for edition in query_results:
        eliminate_pages[edition]=[]
        provenance_removal[edition]=[]
        freq_topics_terms[edition]={}
        merged_topics[edition]={}
        
        page_idx = 0
        while page_idx < len(query_results[edition]):
            current_page=query_results[edition][page_idx][0]        
            element = query_results[edition][page_idx][1]

            if "Topic" in element['type_page']:
                term=element["term"].strip()
                while check_string(term, parts_string) and page_idx < len(query_results[edition]):
    
                    page_idx = page_idx + 1
                    next_element = query_results[edition][page_idx][1]
                    term= next_element["term"].strip()
                    element["definition"]+=next_element["definition"]
                    element["num_article_words"]+=next_element["num_article_words"]
                    element["num_page_words"]+=next_element["num_page_words"]                  
                    element["related_terms"]+= next_element["related_terms"]
                    element["end_page"] = next_element['end_page']
                    provenance_removal[edition].append(element["end_page"])
                    eliminate_pages[edition].append(page_idx)
                    page_idx + 1
                
                print("STUDYING %s at %s" %(term, query_results[edition][page_idx][0] ))
                clean_term=clean_topics_terms(term)
        
                p_id= page_idx + 1
                flag_force = 0  
                if p_id < len(query_results[edition]):
                    flag = 0
                    
                    while p_id < len(query_results[edition]) and flag == 0:
                        
                        next_element = query_results[edition][p_id][1]
                        
                        if not check_string(next_element["term"], parts_string):
                            next_term=clean_topics_terms(next_element["term"].strip())
            
                        else:
                            next_term=next_element["term"].strip()
                            
                        if p_id < len(query_results[edition])-1:    
                            
                            two_next_element = query_results[edition][p_id+1][1]
                            if not check_string(two_next_element["term"], parts_string):
                                two_next_term=clean_topics_terms(two_next_element["term"])
                            else:
                                two_next_term=two_next_element["term"].strip()
                         
                        else:
                            two_next_term=""
                            
                    
                                
                        #m1 = re.search('^([0-9]+)|([IVXLCM]+)\\.?$', next_element["term"])
                        #m2 = re.search('^([0-9]+)|([IVXLCM]+)\\.?$', two_next_element["term"])
                        
                        definition1= next_element["definition"]
                        
                        #print("PAGE %s, len def %s" %(query_results[edition][p_id][0], len(definition)))
                    
                        if similar(clean_term, next_term) > 0.70 or len(next_term)<=3 or len(two_next_term)<=3 or len(definition1)<=30  or check_string(next_term, parts_string) or check_string(two_next_term, parts_string)  or next_term in clean_term or two_next_term in clean_term or similar(clean_term, two_next_term) > 0.70: 
                           
                            if clean_term!="" or clean_term!=" ":
                                if clean_term not in merged_topics[edition]:
                                    merged_topics[edition][clean_term]=[]
                                    merged_topics[edition][clean_term].append(clean_term)
                        
                                if not check_string(next_term, parts_string) and len(next_term)>3:
                                     merged_topics[edition][clean_term].append(next_term)
                            
                         
                            element["definition"]+=next_element["definition"]
                            element["num_article_words"]+=next_element["num_article_words"]
                            element["num_page_words"]+=next_element["num_page_words"]                  
                            element["related_terms"]+= next_element["related_terms"]
                            element["end_page"] = next_element['end_page']
                            provenance_removal[edition].append(element["end_page"])
                            eliminate_pages[edition].append(p_id)
                            print("SIMILAR-TERMS, clean term %s, next_term %s, similarity %s,  len def1 %s, check1 %s, check 2 % future similarity %s, two_next_term %s" %(clean_term, next_term, similar(clean_term, next_term), len(definition1), check_string(next_term, parts_string),  check_string(two_next_term, parts_string), similar(clean_term, two_next_term), two_next_term))
                            p_id= p_id + 1
                            
                            if similar(clean_term, two_next_term) > 0.70 or len(two_next_term)<=3  or check_string(two_next_term, parts_string) or two_next_term in clean_term:   
                                ## adding the two nexts ones. 
                                
                                element["definition"]+=two_next_element["definition"]
                                element["num_article_words"]+=two_next_element["num_article_words"]
                                element["num_page_words"]+=two_next_element["num_page_words"]                  
                                element["related_terms"]+= two_next_element["related_terms"]
                                element["end_page"] = two_next_element['end_page']
                                
                                provenance_removal[edition].append(element["end_page"])
                                
                                if not check_string(two_next_term, parts_string) and len(two_next_term)>3:
                                     merged_topics[edition][clean_term].append(two_next_term)
                                        
                                eliminate_pages[edition].append(p_id)
                                print("SIMILAR-2TERMS, clean term %s, two_next_terms %s, check %s" %(clean_term, two_next_term, check_string(two_next_term, parts_string)))
                                p_id= p_id + 1

                                
                        
                        else:
                            print("PASANDO AL SIGUIENTE: clean_term %s, next_term %s, two_next_terms %s " %(clean_term, next_term, two_next_term))
                            p_id= p_id + 1
                            flag = 1
                    
                    #print("FLAG %s, next page is %s" %(flag, query_results[edition][p_id][0]))
        
               
                page_idx = p_id
                if clean_term in merged_topics[edition]:
                   
                    if character_terms:
                        freq_term=most_frequent(merged_topics[edition][clean_term], character_terms[-1])
                    else:
                        freq_term=most_frequent(merged_topics[edition][clean_term])
                        
                    #print(">>>> ATENTION, merged_topics of %s are % and freq is %s" %(clean_term, merged_topics[edition][clean_term], freq_term))
                            
                    freq_topics_terms[edition][clean_term]=freq_term
                                        
                    element["term"]=freq_term.strip()
                    
                    
                else:
                    element["term"]=clean_term.strip()
        
                    
                if len(clean_term)>1:
                    character_terms.append(clean_term[0])  

            else:
                #print(">>> me salto %s - page %s" %(element["term"], current_page))
                page_idx += 1
                
            
        
    new_results= delete_entries(query_results, eliminate_pages)
    
    return new_results, merged_topics, freq_topics_terms, provenance_removal

# %%
def merge_topics_refine(query_results):
    
    topics_editions={}
    eliminate_pages={}
    merged_topics_refine={}
    provenance_removal={}
    for edition in query_results:
        eliminate_pages[edition]=[]
        provenance_removal[edition]=[]
        topics_editions[edition]={}
        merged_topics_refine[edition]=[]
        page_idx = 0
        character="A"
        while page_idx < len(query_results[edition]):
            
            element = query_results[edition][page_idx][1]
            term = element["term"].strip()

            m = re.search('^([0-9]+)|([IVXLCM]+)\\.?$', term)
            
            if "Topic" in element['type_page'] and term!="" and len(term)>=3:
            #and m is None:
            #and term[0] >= character:
                
                if term not in topics_editions[edition]:
                    topics_editions[edition][term]={}
                    topics_editions[edition][term]["start"]=page_idx
                    topics_editions[edition][term]["end"]= page_idx
                    #print("NEW: Topic --%s-- - Start Page: %s, EN Page:%s "%(term, topics_editions[edition][term]["start"], topics_editions[edition][term]["end"]))
                else:
                    topics_editions[edition][term]["end"]=page_idx
                    #print("UPDATE: Topic --%s-- - Start Page: %s, EN Page:%s "%(term, topics_editions[edition][term]["start"], topics_editions[edition][term]["end"]))        
            
            page_idx += 1
            #if term:
            #    character=term[0]
        
        
        
        
        for term in topics_editions[edition]:
            
            p_start= topics_editions[edition][term]["start"]
            p_end =  topics_editions[edition][term]["end"]
            first_element= query_results[edition][p_start][1]
            #print("NEW: Topic --%s-- - Start Page: %s, EN Page:%s "%(term, query_results[edition][topics_editions[edition][term]["start"]][0], query_results[edition][topics_editions[edition][term]["end"]][0]))
            
            for p_id in range (p_start + 1, p_end+1):
                element = query_results[edition][p_id][1]
                first_element["definition"]+=element["definition"]
                first_element["num_article_words"]+=element["num_article_words"]
                first_element["num_page_words"]+=element["num_page_words"]                  
                first_element["related_terms"]+= element["related_terms"]
                first_element["end_page"] = element['end_page']
                provenance_removal[edition].append(first_element["end_page"])
                merged_topics_refine[edition].append(term)
                eliminate_pages[edition].append(p_id)
        
    new_results= delete_entries(query_results, eliminate_pages)
    
    return new_results, provenance_removal, merged_topics_refine

# %% [markdown]
# ### 1. Reading data

# %% [markdown]
# Here we are going to take the output of the defoe files, and we are going to merge the terms that splitted across pages.
#
# The next line takes time!

# %%
#query_results=read_query_results('toy_1771')
query_results=read_query_results('results_eb_2_edition_new')

# %%
dc_results = copy.deepcopy(query_results)

# %% [markdown]
# It turns out that the results are order by the ALTO PAGE NUMB. And there are some ALTO PAGES NUM which have a higher value than the PAGE NUMBER. So, we have to sort the elements to make sure that we dont have inconsistencies.

# %%
sorted_results= sort_query_results(dc_results)

# %%
consistency_query_results(sorted_results)

# %% [markdown]
# ### 2. Merging articles splitted across pages
#
# Articles normaly have a lenght of one or two paragraphs, but they could be splitted across two consecutive pages.
# So, we are going to merge the detected splitted articles into one.
#
# **NEW** Furthemore, we are going to check the first 20 elements (pages), and check again if they should be FullPage or not based on their header and terms.

# %%
query_results_articles_fp=fixing_fullPages(sorted_results)

# %%
query_results_articles = merge_articles(query_results_articles_fp)

# %% [markdown]
# Since some pages with articles could have wronlgy been classified as "topics", we are going to go through the "TOPICS" pages, and try to extract again articles from those again - reclassifying those as Articles.

# %%
articles_refined=fixing_articles(query_results_articles)
# Out:
# ENTRO Page 15  - type page Topic, term &C
# ENTRO-2 Page 15 - new def [('ARTS', 5), ('SCIENCES', 6), ('AACH', 586), ('AAHUS', 641), ('AAM', 679), ('AAR', 693), ('AARON', 717)]
# ------ BEFORE ['ARTS', 'SCIENCES', 'AACH', 'AAHUS', 'AAM', 'AAR', 'AARON'] - len 7
# element  ARTS
# element  SCIENCES
# element  AACH
# element  AAHUS
# element  AAM
# element  AAR
# element  AARON
# AFTER ['ARTS', 'SCIENCES', 'AACH', 'AAHUS', 'AAM', 'AAR', 'AARON'] - len 7
# MOVING TOPICS TO ARTILCES PAGE 15
# ENTRO Page 75  - type page Topic, term C
# ENTRO-2 Page 75 - new def [('ABC', 60)]
# ------ BEFORE ['ABC'] - len 1
# element  ABC
# AFTER ['ABC'] - len 1
# MOVING TOPICS TO ARTILCES PAGE 75
# ENTRO Page 76  - type page Topic, term ACOUSTICSC
# ENTRO-2 Page 76 - new def [('ACOUSTICS', 0)]
# ------ BEFORE ['ACOUSTICS'] - len 1
# element  ACOUSTICS
# AFTER ['ACOUSTICS'] - len 1
# ENTRO Page 77  - type page Topic, term C
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 78  - type page Topic, term ACOUSTICS
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 79  - type page Topic, term
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 80  - type page Topic, term ASTICS
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 81  - type page Topic, term I
# ENTRO-2 Page 81 - new def [('ABC', 617), ('DDD', 646), ('EEE', 654), ('BHEFC', 1126), ('4X78', 1135)]
# ------ BEFORE ['ABC', 'DDD', 'EEE', 'BHEFC', '4X78'] - len 5
# element  ABC
# element  DDD
# element  EEE
# element  BHEFC
# element  4X78
# AFTER ['ABC', 'DDD', 'EEE', 'BHEFC'] - len 4
# ENTRO Page 82  - type page Topic, term ACOUSTICS
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 84  - type page Topic, term ACOUSTICS
# ENTRO-2 Page 84 - new def [('ACQS', 409), ('ACQUA-CHE-TAVELLA', 447), ('AQUAPENDENTE', 487), ('ACQUARIA', 538), ('ACQUEST', 574), ('ACQUI', 587), ('ACQUISITION', 660), ('ACQUITTAL', 687), ('ACQUITTANCE', 705), ('ACRA', 794), ('ACRAGAS', 1000)]
# ------ BEFORE ['ACQS', 'ACQUA-CHE-TAVELLA', 'AQUAPENDENTE', 'ACQUARIA', 'ACQUEST', 'ACQUI', 'ACQUISITION', 'ACQUITTAL', 'ACQUITTANCE', 'ACRA', 'ACRAGAS'] - len 11
# element  ACQS
# element  ACQUA-CHE-TAVELLA
# element  AQUAPENDENTE
# element  ACQUARIA
# element  ACQUEST
# element  ACQUI
# element  ACQUISITION
# element  ACQUITTAL
# element  ACQUITTANCE
# element  ACRA
# element  ACRAGAS
# AFTER ['ACQS', 'AQUAPENDENTE', 'ACQUARIA', 'ACQUEST', 'ACQUI', 'ACQUISITION', 'ACQUITTAL', 'ACQUITTANCE', 'ACRA', 'ACRAGAS'] - len 10
# MOVING TOPICS TO ARTILCES PAGE 84
# ENTRO Page 107  - type page FullPage, term ADMSADO
# ENTRO-2 Page 107 - new def [('ADMIRATION', 784), ('ADMONITION', 814), ('ADMORTIZATION', 914), ('ADNATA', 932), ('ADNOUN', 967), ('ADOLESCENCE', 1026), ('ADOLLAM', 1144)]
# ------ BEFORE ['ADMIRATION', 'ADMONITION', 'ADMORTIZATION', 'ADNATA', 'ADNOUN', 'ADOLESCENCE', 'ADOLLAM'] - len 7
# element  ADMIRATION
# element  ADMONITION
# element  ADMORTIZATION
# element  ADNATA
# element  ADNOUN
# element  ADOLESCENCE
# element  ADOLLAM
# AFTER ['ADMIRATION', 'ADMONITION', 'ADMORTIZATION', 'ADNATA', 'ADNOUN', 'ADOLESCENCE', 'ADOLLAM'] - len 7
# MOVING TOPICS TO ARTILCES PAGE 107
# ENTRO Page 147  - type page Topic, term AGRICULTURE
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 148  - type page Topic, term AGRICULTURE
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 149  - type page Topic, term PI
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 150  - type page Topic, term AGRICULTURE
# ENTRO-2 Page 150 - new def []
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 151  - type page Topic, term P
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 153  - type page Topic, term P
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 155  - type page Topic, term P
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 156  - type page Topic, term AGRICULTURE
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 157  - type page Topic, term P
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 158  - type page Topic, term AGRICTJ
# ENTRO-2 Page 158 - new def []
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 159  - type page Topic, term P
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 160  - type page Topic, term AGRICULTURE
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 162  - type page Topic, term AGRICULTURE
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 163  - type page Topic, term PIAGRICULTURE
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 164  - type page Topic, term T
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 165  - type page Topic, term II
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 166  - type page Topic, term HAGRICULTURE
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 169  - type page Topic, term PII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 170  - type page Topic, term AGRICULTURE
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 171  - type page Topic, term PII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 172  - type page Topic, term AGRICULTURE
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 173  - type page Topic, term IPII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 175  - type page Topic, term PII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 176  - type page Topic, term AGRICULTURE
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 177  - type page Topic, term PII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 178  - type page Topic, term AGRICU
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 179  - type page Topic, term PII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 180  - type page Topic, term AGRICULTURE
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 181  - type page Topic, term PII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 187  - type page Topic, term PII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 188  - type page Topic, term AGRICULTURE
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 189  - type page Topic, term PIT
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 190  - type page Topic, term AGRICULTURE
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 193  - type page Topic, term PII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 194  - type page Topic, term AGRICULTURE
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 195  - type page Topic, term PII
# ENTRO-2 Page 195 - new def []
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 196  - type page Topic, term AGRICULTURE
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 199  - type page Topic, term AGRICULTURE
# ENTRO-2 Page 199 - new def [('AGRIFOLIUM', 393), ('AGRIMONIA', 398)]
# ------ BEFORE ['AGRIFOLIUM', 'AGRIMONIA'] - len 2
# element  AGRIFOLIUM
# element  AGRIMONIA
# AFTER ['AGRIFOLIUM', 'AGRIMONIA'] - len 2
# MOVING TOPICS TO ARTILCES PAGE 199
# ENTRO Page 257  - type page Topic, term S
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 259  - type page Topic, term S
# ENTRO-2 Page 259 - new def [('+XXXX', 988)]
# ------ BEFORE ['+XXXX'] - len 1
# element  +XXXX
# AFTER [] - len 0
# ENTRO Page 260  - type page Topic, term ALGEBRA
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 261  - type page Topic, term S
# ENTRO-2 Page 261 - new def [('X\\/2', 129)]
# ------ BEFORE ['X\\/2'] - len 1
# element  X\/2
# AFTER [] - len 0
# ENTRO Page 262  - type page Topic, term ALGEBRA
# ENTRO-2 Page 262 - new def [('4X—2=8', 526), ('3X+2X', 712)]
# ------ BEFORE ['4X—2=8', '3X+2X'] - len 2
# element  4X—2=8
# element  3X+2X
# AFTER [] - len 0
# ENTRO Page 263  - type page Topic, term S
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 264  - type page Topic, term 2$2
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 265  - type page Topic, term S
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 266  - type page Topic, term ALGEB
# ENTRO-2 Page 266 - new def []
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 267  - type page Topic, term S
# ENTRO-2 Page 267 - new def [('X—4=1+4', 97)]
# ------ BEFORE ['X—4=1+4'] - len 1
# element  X—4=1+4
# AFTER [] - len 0
# ENTRO Page 268  - type page Topic, term ALGEBRA
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 269  - type page Topic, term S
# ENTRO-2 Page 269 - new def [('ALGEDO', 592), ('ALGENEB', 704), ('ALGEZIRA', 739), ('ALGHIER', 813), ('ALGIABARII', 875), ('ALGIERS', 940)]
# ------ BEFORE ['ALGEDO', 'ALGENEB', 'ALGEZIRA', 'ALGHIER', 'ALGIABARII', 'ALGIERS'] - len 6
# element  ALGEDO
# element  ALGENEB
# element  ALGEZIRA
# element  ALGHIER
# element  ALGIABARII
# element  ALGIERS
# AFTER ['ALGEDO', 'ALGENEB', 'ALGEZIRA', 'ALGHIER', 'ALGIABARII', 'ALGIERS'] - len 6
# MOVING TOPICS TO ARTILCES PAGE 269
# ENTRO Page 300  - type page FullPage, term X
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 303  - type page FullPage, term SGA
# ENTRO-2 Page 303 - new def [('ALTIMETRY', 414), ('ALTIN', 428), ('ALTITUDE', 945), ('ALTKIRK', 1009), ('ALTMORE', 1031), ('ALTON', 1056)]
# ------ BEFORE ['ALTIMETRY', 'ALTIN', 'ALTITUDE', 'ALTKIRK', 'ALTMORE', 'ALTON'] - len 6
# element  ALTIMETRY
# element  ALTIN
# element  ALTITUDE
# element  ALTKIRK
# element  ALTMORE
# element  ALTON
# AFTER ['ALTIMETRY', 'ALTIN', 'ALTITUDE', 'ALTKIRK', 'ALTMORE', 'ALTON'] - len 6
# MOVING TOPICS TO ARTILCES PAGE 303
# ENTRO Page 372  - type page Topic, term ANATOMY
# ENTRO-2 Page 372 - new def []
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 373  - type page Topic, term H
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 374  - type page Topic, term ANATOMY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 375  - type page Topic, term PI
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 376  - type page Topic, term ANATOMY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 377  - type page Topic, term PI
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 378  - type page Topic, term ANATOMY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 379  - type page Topic, term ANATOMY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 380  - type page Topic, term PANATOMY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 381  - type page Topic, term ANATOMY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 382  - type page Topic, term ANATOMY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 384  - type page Topic, term ANATOMY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 385  - type page Topic, term PI
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 386  - type page Topic, term ANATOMY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 387  - type page Topic, term I
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 389  - type page Topic, term PI
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 390  - type page Topic, term ANATOMY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 391  - type page Topic, term ANATOMY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 397  - type page Topic, term P
# ENTRO-2 Page 397 - new def [('GENERAL', 907)]
# ------ BEFORE ['GENERAL'] - len 1
# element  GENERAL
# AFTER ['GENERAL'] - len 1
# MOVING TOPICS TO ARTILCES PAGE 397
# ENTRO Page 398  - type page Topic, term ANATOMY
# ENTRO-2 Page 398 - new def []
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 399  - type page Topic, term PII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 400  - type page Topic, term ANATOMY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 403  - type page Topic, term ATABLENM
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 405  - type page Topic, term ATABLEMUSCLES
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 406  - type page FullPage, term MIO
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 409  - type page Topic, term PIII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 410  - type page Topic, term ANATOMY
# ENTRO-2 Page 410 - new def [('ABDOMEN', 457)]
# ------ BEFORE ['ABDOMEN'] - len 1
# element  ABDOMEN
# AFTER ['ABDOMEN'] - len 1
# ENTRO Page 413  - type page Topic, term ANATOMY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 414  - type page Topic, term ANAOMY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 415  - type page Topic, term IV
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 416  - type page Topic, term ANATOMY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 417  - type page Topic, term IV
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 419  - type page Topic, term
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 420  - type page Topic, term ANATOMY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 421  - type page Topic, term ANATOMY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 422  - type page Topic, term ANATOMY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 423  - type page Topic, term IV
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 424  - type page Topic, term ANATOMY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 425  - type page Topic, term ANATOMY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 426  - type page Topic, term ANATOMY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 427  - type page Topic, term ANATOMY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 428  - type page Topic, term ANATOMY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 429  - type page Topic, term PV
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 430  - type page Topic, term ANATOMY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 431  - type page Topic, term PV
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 432  - type page Topic, term PANATOMY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 433  - type page Topic, term ANATOMY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 434  - type page Topic, term ANATOMY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 439  - type page Topic, term V
# ENTRO-2 Page 439 - new def [('OOO', 775)]
# ------ BEFORE ['OOO'] - len 1
# element  OOO
# AFTER ['OOO'] - len 1
# ENTRO Page 440  - type page Topic, term ANATOMY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 443  - type page Topic, term ANATOMY
# ENTRO-2 Page 443 - new def [('INTEGUMENTS', 558)]
# ------ BEFORE ['INTEGUMENTS'] - len 1
# element  INTEGUMENTS
# AFTER ['INTEGUMENTS'] - len 1
# ENTRO Page 444  - type page Topic, term ANATOMY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 445  - type page Topic, term ANATOMY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 446  - type page Topic, term PANATOMY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 449  - type page Topic, term
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 450  - type page Topic, term ANATOMY
# ENTRO-2 Page 450 - new def [('VII', 2)]
# ------ BEFORE ['VII'] - len 1
# element  VII
# AFTER ['VII'] - len 1
# ENTRO Page 451  - type page Topic, term ANATOMY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 452  - type page Topic, term PVANATOMY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 453  - type page Topic, term PVH
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 454  - type page Topic, term ANATOMY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 459  - type page Topic, term ANCLANC
# ENTRO-2 Page 459 - new def [('ANCIENT', 576)]
# ------ BEFORE ['ANCIENT'] - len 1
# element  ANCIENT
# AFTER ['ANCIENT'] - len 1
# MOVING TOPICS TO ARTILCES PAGE 459
# ENTRO Page 465  - type page Topic, term 730
# ENTRO-2 Page 465 - new def [('ANDRAPODISMUS', 341), ('ANDRAPODOCAPELI', 378)]
# ------ BEFORE ['ANDRAPODISMUS', 'ANDRAPODOCAPELI'] - len 2
# element  ANDRAPODISMUS
# element  ANDRAPODOCAPELI
# AFTER ['ANDRAPODISMUS', 'ANDRAPODOCAPELI'] - len 2
# MOVING TOPICS TO ARTILCES PAGE 465
# ENTRO Page 475  - type page FullPage, term TXOI
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 486  - type page FullPage, term ANGANGANG
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 491  - type page FullPage, term IA
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 495  - type page Topic, term C
# ENTRO-2 Page 495 - new def [('ANGR1VARII', 270), ('ANGROGNA', 428), ('ANGUILLA', 447), ('ANGUILLIFORM', 720), ('ANGUIS', 1113)]
# ------ BEFORE ['ANGR1VARII', 'ANGROGNA', 'ANGUILLA', 'ANGUILLIFORM', 'ANGUIS'] - len 5
# element  ANGR1VARII
# element  ANGROGNA
# element  ANGUILLA
# element  ANGUILLIFORM
# element  ANGUIS
# AFTER ['ANGROGNA', 'ANGUILLA', 'ANGUILLIFORM', 'ANGUIS'] - len 4
# MOVING TOPICS TO ARTILCES PAGE 495
# ENTRO Page 504  - type page Topic, term AF
# ENTRO-2 Page 504 - new def [('A.NIMALCULE', 386)]
# ------ BEFORE ['A.NIMALCULE'] - len 1
# element  A.NIMALCULE
# AFTER [] - len 0
# ENTRO Page 512  - type page FullPage, term PXXIV
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 518  - type page FullPage, term PJOOV
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 527  - type page Topic, term ANNUITIES
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 528  - type page Topic, term ANNUITIES
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 529  - type page Topic, term ANNUI
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 531  - type page Topic, term ANNUITIES
# ENTRO-2 Page 531 - new def [('16.1X14.12X10', 616)]
# ------ BEFORE ['16.1X14.12X10'] - len 1
# element  16.1X14.12X10
# AFTER [] - len 0
# ENTRO Page 571  - type page FullPage, term APHAPHJ
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 573  - type page Topic, term APIAPICES
# ENTRO-2 Page 573 - new def [('APHRONITRE', 85), ('APHTHAE', 101), ('APHYLLANTPIES', 151), ('APPIYTIS', 247), ('APIARY', 265), ('APIASTER', 274), ('APICES', 290), ('APINA', 407), ('APION', 449), ('APIS', 493), ('APIS', 588)]
# ------ BEFORE ['APHRONITRE', 'APHTHAE', 'APHYLLANTPIES', 'APPIYTIS', 'APIARY', 'APIASTER', 'APICES', 'APINA', 'APION', 'APIS', 'APIS'] - len 11
# element  APHRONITRE
# element  APHTHAE
# element  APHYLLANTPIES
# element  APPIYTIS
# element  APIARY
# element  APIASTER
# element  APICES
# element  APINA
# element  APION
# element  APIS
# element  APIS
# AFTER ['APHRONITRE', 'APHTHAE', 'APHYLLANTPIES', 'APPIYTIS', 'APIARY', 'APIASTER', 'APICES', 'APINA', 'APION', 'APIS', 'APIS'] - len 11
# MOVING TOPICS TO ARTILCES PAGE 573
# ENTRO Page 591  - type page FullPage, term
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 594  - type page FullPage, term HXXA
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 599  - type page FullPage, term APOJAPO
# ENTRO-2 Page 599 - new def [('APODES', 51), ('APODICTICAL', 122), ('APODOSIS', 136), ('APODYTERIUM', 212), ('APOGEE', 224), ('APOLIDES', 280), ('APOLLINARIANS', 613)]
# ------ BEFORE ['APODES', 'APODICTICAL', 'APODOSIS', 'APODYTERIUM', 'APOGEE', 'APOLIDES', 'APOLLINARIANS'] - len 7
# element  APODES
# element  APODICTICAL
# element  APODOSIS
# element  APODYTERIUM
# element  APOGEE
# element  APOLIDES
# element  APOLLINARIANS
# AFTER ['APODES', 'APODICTICAL', 'APODOSIS', 'APODYTERIUM', 'APOGEE', 'APOLIDES', 'APOLLINARIANS'] - len 7
# MOVING TOPICS TO ARTILCES PAGE 599
# ENTRO Page 601  - type page FullPage, term DAA
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 611  - type page Topic, term APR
# ENTRO-2 Page 611 - new def [('APRICOT', 57), ('APRIES', 67), ('APRIL', 172), ('PRIORI', 204), ('APRON', 220), ('APSIS', 255), ('APTA', 505), ('APTERA', 638), ('APPROXIMATION', 789), ('APTHANE', 843), ('APPUI', 851), ('APTOTE', 877), ('APPULSE', 1147)]
# ------ BEFORE ['APRICOT', 'APRIES', 'APRIL', 'PRIORI', 'APRON', 'APSIS', 'APTA', 'APTERA', 'APPROXIMATION', 'APTHANE', 'APPUI', 'APTOTE', 'APPULSE'] - len 13
# element  APRICOT
# element  APRIES
# element  APRIL
# element  PRIORI
# element  APRON
# element  APSIS
# element  APTA
# element  APTERA
# element  APPROXIMATION
# element  APTHANE
# element  APPUI
# element  APTOTE
# element  APPULSE
# AFTER ['APRICOT', 'APRIES', 'APRIL', 'PRIORI', 'APRON', 'APSIS', 'APTA', 'APTERA', 'APPROXIMATION', 'APTHANE', 'APPUI', 'APTOTE', 'APPULSE'] - len 13
# MOVING TOPICS TO ARTILCES PAGE 611
# ENTRO Page 614  - type page FullPage, term ACLULALU
# ENTRO-2 Page 614 - new def [('AQUAMBOE', 773), ('AQUARIANS', 943), ('AQUARIUS', 1061), ('AQUARTIA', 1076), ('AQUATIC', 1097), ('AQUAVIVA', 1114), ('AQUEOUS', 1129)]
# ------ BEFORE ['AQUAMBOE', 'AQUARIANS', 'AQUARIUS', 'AQUARTIA', 'AQUATIC', 'AQUAVIVA'] - len 6
# element  AQUAMBOE
# element  AQUARIANS
# element  AQUARIUS
# element  AQUARTIA
# element  AQUATIC
# element  AQUAVIVA
# AFTER ['AQUAMBOE', 'AQUARIANS', 'AQUARIUS', 'AQUARTIA', 'AQUATIC', 'AQUAVIVA'] - len 6
# MOVING TOPICS TO ARTILCES PAGE 614
# ENTRO Page 621  - type page FullPage, term ARASZIARA
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 664  - type page Topic, term ARCLARCTBA
# ENTRO-2 Page 664 - new def [('ARCHBISHOP', 329), ('ARCHBISHOPRIC', 491), ('ARCHBUTLER', 504), ('ARCHCHANCELLOR', 561), ('ARCHCHANTOR', 635), ('ARCHCOUNT', 644), ('ARCHDEACON', 662), ('ARCHDUKE', 813), ('ARCHELAUS', 884)]
# ------ BEFORE ['ARCHBISHOP', 'ARCHBISHOPRIC', 'ARCHBUTLER', 'ARCHCHANCELLOR', 'ARCHCHANTOR', 'ARCHCOUNT', 'ARCHDEACON', 'ARCHDUKE', 'ARCHELAUS'] - len 9
# element  ARCHBISHOP
# element  ARCHBISHOPRIC
# element  ARCHBUTLER
# element  ARCHCHANCELLOR
# element  ARCHCHANTOR
# element  ARCHCOUNT
# element  ARCHDEACON
# element  ARCHDUKE
# element  ARCHELAUS
# AFTER ['ARCHBISHOP', 'ARCHBISHOPRIC', 'ARCHBUTLER', 'ARCHCHANCELLOR', 'ARCHCHANTOR', 'ARCHCOUNT', 'ARCHDEACON', 'ARCHDUKE', 'ARCHELAUS'] - len 9
# MOVING TOPICS TO ARTILCES PAGE 664
# ENTRO Page 668  - type page Topic, term ARCHIT
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 669  - type page Topic, term H
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 670  - type page Topic, term ECTURE
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 671  - type page Topic, term H
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 672  - type page Topic, term ARCHITECTURE
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 673  - type page Topic, term H
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 674  - type page Topic, term ARCHITECTURE
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 675  - type page Topic, term PI
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 676  - type page Topic, term ARCHITECTURE
# ENTRO-2 Page 676 - new def []
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 677  - type page Topic, term P
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 678  - type page Topic, term BARCHITR
# ENTRO-2 Page 678 - new def [('ABE', 278)]
# ------ BEFORE ['ABE'] - len 1
# element  ABE
# AFTER ['ABE'] - len 1
# MOVING TOPICS TO ARTILCES PAGE 678
# ENTRO Page 687  - type page FullPage, term ?/'
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 693  - type page Topic, term PI
# ENTRO-2 Page 693 - new def [('4J-', 744)]
# ------ BEFORE ['4J-'] - len 1
# element  4J-
# AFTER [] - len 0
# ENTRO Page 694  - type page Topic, term URE
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 697  - type page Topic, term P
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 698  - type page Topic, term ARCHITECTURE
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 699  - type page Topic, term P
# ENTRO-2 Page 699 - new def []
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 700  - type page Topic, term ARCHIT
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 705  - type page Topic, term P
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 706  - type page Topic, term ARCHITECTURE
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 711  - type page Topic, term P
# ENTRO-2 Page 711 - new def [('J^W/', 913)]
# ------ BEFORE ['J^W/'] - len 1
# element  J^W/
# AFTER [] - len 0
# ENTRO Page 721  - type page Topic, term PII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 722  - type page Topic, term ARCHITECTURE
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 723  - type page Topic, term PII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 724  - type page Topic, term ARCHITECTURE
# ENTRO-2 Page 724 - new def []
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 725  - type page FullPage, term PXXK
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 729  - type page Topic, term PII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 730  - type page Topic, term ARCHITECTURE
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 731  - type page Topic, term PII
# ENTRO-2 Page 731 - new def []
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 732  - type page Topic, term ARCHITECTURE
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 734  - type page FullPage, term VLPJXK
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 735  - type page Topic, term PII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 736  - type page Topic, term ARCHIT
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 737  - type page Topic, term P
# ENTRO-2 Page 737 - new def [('ARCHITALASSUS', 165), ('ARCHITRAVE', 177), ('ARCHIVAULT', 230), ('ARCHIVE', 288), ('ARCHMARSHAL', 308), ('ARCHONS', 324)]
# ------ BEFORE ['ARCHITALASSUS', 'ARCHITRAVE', 'ARCHIVAULT', 'ARCHIVE', 'ARCHMARSHAL', 'ARCHONS'] - len 6
# element  ARCHITALASSUS
# element  ARCHITRAVE
# element  ARCHIVAULT
# element  ARCHIVE
# element  ARCHMARSHAL
# element  ARCHONS
# AFTER ['ARCHITALASSUS', 'ARCHITRAVE', 'ARCHIVAULT', 'ARCHIVE', 'ARCHMARSHAL', 'ARCHONS'] - len 6
# MOVING TOPICS TO ARTILCES PAGE 737
# ENTRO Page 749  - type page Topic, term A
# ENTRO-2 Page 749 - new def [('POPOLI', 1571)]
# ------ BEFORE ['POPOLI'] - len 1
# element  POPOLI
# AFTER ['POPOLI'] - len 1
# MOVING TOPICS TO ARTILCES PAGE 749
# ENTRO Page 760  - type page FullPage, term ARIJARI
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 762  - type page Topic, term ARITH
# ENTRO-2 Page 762 - new def [("X'H'XV", 651), ('M°X33', 828)]
# ------ BEFORE ["X'H'XV", 'M°X33'] - len 2
# element  X'H'XV
# element  M°X33
# AFTER [] - len 0
# ENTRO Page 763  - type page Topic, term C
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 764  - type page Topic, term ARITHMETIC
# ENTRO-2 Page 764 - new def []
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 765  - type page Topic, term C
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 766  - type page Topic, term ARITHMETIC
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 767  - type page Topic, term C
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 768  - type page Topic, term ARITH
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 769  - type page Topic, term C
# ENTRO-2 Page 769 - new def []
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 770  - type page Topic, term ARITH
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 771  - type page Topic, term C
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 772  - type page Topic, term ARITH
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 773  - type page Topic, term C
# ENTRO-2 Page 773 - new def []
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 774  - type page Topic, term ARITH
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 775  - type page Topic, term I
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 776  - type page Topic, term ARITH
# ENTRO-2 Page 776 - new def [('L.150', 646), ('L.500', 649), ('L.45', 800)]
# ------ BEFORE ['L.150', 'L.500', 'L.45'] - len 3
# element  L.150
# element  L.500
# element  L.45
# AFTER [] - len 0
# ENTRO Page 777  - type page Topic, term 754314
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 778  - type page Topic, term 6684856
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 779  - type page Topic, term C
# ENTRO-2 Page 779 - new def [('IC34', 933)]
# ------ BEFORE ['IC34'] - len 1
# element  IC34
# AFTER [] - len 0
# ENTRO Page 780  - type page Topic, term ARITHMETIC
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 781  - type page Topic, term C
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 782  - type page Topic, term ARITHMETIC
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 783  - type page Topic, term C
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 785  - type page Topic, term C
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 786  - type page Topic, term F
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 787  - type page Topic, term C
# ENTRO-2 Page 787 - new def []
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 788  - type page Topic, term ARITHARITH
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 789  - type page Topic, term C
# ENTRO-2 Page 789 - new def [('10X10X10', 386)]
# ------ BEFORE ['10X10X10'] - len 1
# element  10X10X10
# AFTER [] - len 0
# ENTRO Page 791  - type page Topic, term C
# ENTRO-2 Page 791 - new def [('216=27X8', 942)]
# ------ BEFORE ['216=27X8'] - len 1
# element  216=27X8
# AFTER [] - len 0
# ENTRO Page 792  - type page Topic, term ARITHMETIC
# ENTRO-2 Page 792 - new def [('12X3', 176), ('-A=0', 670)]
# ------ BEFORE ['12X3', '-A=0'] - len 2
# element  12X3
# element  -A=0
# AFTER [] - len 0
# ENTRO Page 793  - type page Topic, term C
# ENTRO-2 Page 793 - new def [('•H6', 292), ('.37', 696), ('.2', 721), ('.784X.36', 769)]
# ------ BEFORE ['•H6', '.37', '.2', '.784X.36'] - len 4
# element  •H6
# element  .37
# element  .2
# element  .784X.36
# AFTER [] - len 0
# ENTRO Page 795  - type page Topic, term C
# ENTRO-2 Page 795 - new def [('.I2', 318)]
# ------ BEFORE ['.I2'] - len 1
# element  .I2
# AFTER [] - len 0
# ENTRO Page 796  - type page Topic, term ARITHMETIC
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 797  - type page Topic, term C
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 798  - type page Topic, term ARITH
# ENTRO-2 Page 798 - new def [('ARIUS', 531)]
# ------ BEFORE ['ARIUS'] - len 1
# element  ARIUS
# AFTER ['ARIUS'] - len 1
# MOVING TOPICS TO ARTILCES PAGE 798
# ENTRO Page 820  - type page Topic, term ARSARTA
# ENTRO-2 Page 820 - new def [('ARROJO', 51), ('ARRONDEE', 69), ('ARROW', 140), ('ARSCHIN', 188), ('ARSHOT', 207), ('ARSENAL', 233), ('ARSENIC', 255), ('ARSENIUS', 279), ('ARSMART', 465), ('ARSON', 470)]
# ------ BEFORE ['ARROJO', 'ARRONDEE', 'ARROW', 'ARSCHIN', 'ARSHOT', 'ARSENAL', 'ARSENIC', 'ARSENIUS', 'ARSMART', 'ARSON'] - len 10
# element  ARROJO
# element  ARRONDEE
# element  ARROW
# element  ARSCHIN
# element  ARSHOT
# element  ARSENAL
# element  ARSENIC
# element  ARSENIUS
# element  ARSMART
# element  ARSON
# AFTER ['ARROJO', 'ARRONDEE', 'ARROW', 'ARSCHIN', 'ARSHOT', 'ARSENAL', 'ARSENIC', 'ARSENIUS', 'ARSMART', 'ARSON'] - len 10
# MOVING TOPICS TO ARTILCES PAGE 820
# ENTRO Page 824  - type page Topic, term ARTBC
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 851  - type page FullPage, term ASSASS
# ENTRO-2 Page 851 - new def [('ASSIENTO', 253), ('ASSIGN', 314), ('ASSIGNEE', 329), ('ASSIGNING', 349), ('ASSIGNMENT', 383), ('ASSIMILATION', 400), ('ASSISE', 490)]
# ------ BEFORE ['ASSIENTO', 'ASSIGN', 'ASSIGNEE', 'ASSIGNING', 'ASSIGNMENT', 'ASSIMILATION', 'ASSISE'] - len 7
# element  ASSIENTO
# element  ASSIGN
# element  ASSIGNEE
# element  ASSIGNING
# element  ASSIGNMENT
# element  ASSIMILATION
# element  ASSISE
# AFTER ['ASSIENTO', 'ASSIGN', 'ASSIGNEE', 'ASSIGNING', 'ASSIGNMENT', 'ASSIMILATION', 'ASSISE'] - len 7
# MOVING TOPICS TO ARTILCES PAGE 851
# ENTRO Page 856  - type page FullPage, term PXLII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 860  - type page Topic, term XLII
# ENTRO-2 Page 860 - new def [('ASTROGNOSIA', 13), ('ASTROITES', 31), ('ASTROLABE', 48), ('ASTROLOGY', 135), ('ASTRONOMICAL', 183)]
# ------ BEFORE ['ASTROGNOSIA', 'ASTROITES', 'ASTROLABE', 'ASTROLOGY', 'ASTRONOMICAL'] - len 5
# element  ASTROGNOSIA
# element  ASTROITES
# element  ASTROLABE
# element  ASTROLOGY
# element  ASTRONOMICAL
# AFTER ['ASTROGNOSIA', 'ASTROITES', 'ASTROLABE', 'ASTROLOGY', 'ASTRONOMICAL'] - len 5
# MOVING TOPICS TO ARTILCES PAGE 860
# ENTRO Page 12  - type page Topic, term SEASSEA
# ENTRO-2 Page 12 - new def [('EARTH', 164), ('QUARRY', 500)]
# ------ BEFORE ['EARTH', 'QUARRY'] - len 2
# element  EARTH
# element  QUARRY
# AFTER ['EARTH', 'QUARRY'] - len 2
# MOVING TOPICS TO ARTILCES PAGE 12
# ENTRO Page 30  - type page Topic, term SELSEL
# ENTRO-2 Page 30 - new def [('SELENITJE', 365), ('MOON-STONE', 366), ('SELENOGRAPHY', 657), ('MOON', 684), ('SELF-MURDER', 872), ('SELEUCIA', 1507)]
# ------ BEFORE ['SELENITJE', 'MOON-STONE', 'SELENOGRAPHY', 'MOON', 'SELF-MURDER', 'SELEUCIA'] - len 6
# element  SELENITJE
# element  MOON-STONE
# element  SELENOGRAPHY
# element  MOON
# element  SELF-MURDER
# element  SELEUCIA
# AFTER ['SELENITJE', 'SELENOGRAPHY', 'MOON', 'SELEUCIA'] - len 4
# MOVING TOPICS TO ARTILCES PAGE 30
# ENTRO Page 32  - type page Topic, term SEMBSISEM
# ENTRO-2 Page 32 - new def [('SEMI', 822), ('CLE', 845)]
# ------ BEFORE ['SEMI', 'CLE'] - len 2
# element  SEMI
# element  CLE
# AFTER ['SEMI', 'CLE'] - len 2
# MOVING TOPICS TO ARTILCES PAGE 32
# ENTRO Page 41  - type page FullPage, term SSENSEN
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 48  - type page Topic, term SECLL
# ENTRO-2 Page 48 - new def [('SEQUANI', 321), ('SEQUESTRATION', 371), ('SEQUIN', 747), ('SERAGLIO', 767), ('SERAPH', 1004), ('SERAPHIC', 1059), ('ERAPIQN', 1085)]
# ------ BEFORE ['SEQUANI', 'SEQUESTRATION', 'SEQUIN', 'SERAGLIO', 'SERAPH', 'SERAPHIC', 'ERAPIQN'] - len 7
# element  SEQUANI
# element  SEQUESTRATION
# element  SEQUIN
# element  SERAGLIO
# element  SERAPH
# element  SERAPHIC
# element  ERAPIQN
# AFTER ['SEQUANI', 'SEQUESTRATION', 'SEQUIN', 'SERAGLIO', 'SERAPH', 'SERAPHIC', 'ERAPIQN'] - len 7
# MOVING TOPICS TO ARTILCES PAGE 48
# ENTRO Page 50  - type page Topic, term SERSERS
# ENTRO-2 Page 50 - new def [('SERPENT', 43), ('TALUS', 63)]
# ------ BEFORE ['SERPENT', 'TALUS'] - len 2
# element  SERPENT
# element  TALUS
# AFTER ['SERPENT', 'TALUS'] - len 2
# MOVING TOPICS TO ARTILCES PAGE 50
# ENTRO Page 59  - type page FullPage, term JSIISETS
# ENTRO-2 Page 59 - new def [('SESTOS', 117), ('LEANDER', 148), ('SET', 154), ('SETH', 526), ('SETHIANS', 545), ('SETIMO', 638), ('SETON', 657), ('SETTING', 736), ('SEVENTH', 863), ('SEVERIA', 875), ('SEVERING', 988), ('SEVERN', 1033)]
# ------ BEFORE ['SESTOS', 'LEANDER', 'SET', 'SETH', 'SETHIANS', 'SETIMO', 'SETON', 'SETTING', 'SEVENTH', 'SEVERIA', 'SEVERING', 'SEVERN'] - len 12
# element  SESTOS
# element  LEANDER
# element  SET
# element  SETH
# element  SETHIANS
# element  SETIMO
# element  SETON
# element  SETTING
# element  SEVENTH
# element  SEVERIA
# element  SEVERING
# element  SEVERN
# AFTER ['SESTOS', 'LEANDER', 'SET', 'SETH', 'SETHIANS', 'SETIMO', 'SETON', 'SETTING', 'SEVENTH', 'SEVERIA', 'SEVERING', 'SEVERN'] - len 12
# MOVING TOPICS TO ARTILCES PAGE 59
# ENTRO Page 81  - type page Topic, term SHISSHI
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 85  - type page Topic, term S
# ENTRO-2 Page 85 - new def [('I>12', 384), ('S31', 440)]
# ------ BEFORE ['I>12', 'S31'] - len 2
# element  I>12
# element  S31
# AFTER [] - len 0
# ENTRO Page 89  - type page Topic, term YCCLXV
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 92  - type page Topic, term ILDING
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 94  - type page FullPage, term MB
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 96  - type page Topic, term SHIPBUILDING
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 97  - type page Topic, term P
# ENTRO-2 Page 97 - new def []
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 99  - type page Topic, term PLSHIPBUILDING
# ENTRO-2 Page 99 - new def [('BAG', 140), ('BAG', 199)]
# ------ BEFORE ['BAG', 'BAG'] - len 2
# element  BAG
# element  BAG
# AFTER ['BAG', 'BAG'] - len 2
# MOVING TOPICS TO ARTILCES PAGE 99
# ENTRO Page 100  - type page Topic, term SHIPBTJLDING
# ENTRO-2 Page 100 - new def [('SHIPPING', 965)]
# ------ BEFORE ['SHIPPING'] - len 1
# element  SHIPPING
# AFTER ['SHIPPING'] - len 1
# MOVING TOPICS TO ARTILCES PAGE 100
# ENTRO Page 121  - type page Topic, term SIGISIGS
# ENTRO-2 Page 121 - new def [('S1EUR', 74), ('SIGEFH', 102), ('SIGHT', 185), ('SIGN', 271), ('SIGNALS', 339)]
# ------ BEFORE ['S1EUR', 'SIGEFH', 'SIGHT', 'SIGN', 'SIGNALS'] - len 5
# element  S1EUR
# element  SIGEFH
# element  SIGHT
# element  SIGN
# element  SIGNALS
# AFTER ['SIGEFH', 'SIGHT', 'SIGN', 'SIGNALS'] - len 4
# MOVING TOPICS TO ARTILCES PAGE 121
# ENTRO Page 133  - type page FullPage, term SMIA
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 135  - type page FullPage, term SMIA
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 142  - type page FullPage, term SMLVTCCIZXXTCCIZXX
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 146  - type page Topic, term SLASLE
# ENTRO-2 Page 146 - new def [('SKIN', 1), ('SKIRMISH', 116), ('SKULL', 150), ('SLAB', 197), ('SLATE', 223), ('SLAVE', 605), ('SLEEP', 1046)]
# ------ BEFORE ['SKIN', 'SKIRMISH', 'SKULL', 'SLAB', 'SLATE', 'SLAVE', 'SLEEP'] - len 7
# element  SKIN
# element  SKIRMISH
# element  SKULL
# element  SLAB
# element  SLATE
# element  SLAVE
# element  SLEEP
# AFTER ['SKIN', 'SKIRMISH', 'SKULL', 'SLAB', 'SLATE', 'SLAVE', 'SLEEP'] - len 7
# MOVING TOPICS TO ARTILCES PAGE 146
# ENTRO Page 148  - type page Topic, term SLOIISLOM
# ENTRO-2 Page 148 - new def [('SLESWICK', 24), ('SLIGO', 260), ('SLING', 377)]
# ------ BEFORE ['SLESWICK', 'SLIGO', 'SLING'] - len 3
# element  SLESWICK
# element  SLIGO
# element  SLING
# AFTER ['SLESWICK', 'SLIGO', 'SLING'] - len 3
# MOVING TOPICS TO ARTILCES PAGE 148
# ENTRO Page 152  - type page Topic, term SMOSMOS
# ENTRO-2 Page 152 - new def [('CCLXXI', 20)]
# ------ BEFORE ['CCLXXI'] - len 1
# element  CCLXXI
# AFTER ['CCLXXI'] - len 1
# MOVING TOPICS TO ARTILCES PAGE 152
# ENTRO Page 155  - type page Topic, term CCLXXI
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 172  - type page FullPage, term SOLSOISSONS
# ENTRO-2 Page 172 - new def [('SOISSONS', 4), ('SOKE', 133), ('SOL', 143), ('SUS', 228), ('SOLANUM', 258), ('SOLAR', 1022), ('3539SOLDER', 1036)]
# ------ BEFORE ['SOISSONS', 'SOKE', 'SOL', 'SUS', 'SOLANUM', 'SOLAR', '3539SOLDER'] - len 7
# element  SOISSONS
# element  SOKE
# element  SOL
# element  SUS
# element  SOLANUM
# element  SOLAR
# element  3539SOLDER
# AFTER ['SOISSONS', 'SOKE', 'SOL', 'SUS', 'SOLANUM', 'SOLAR'] - len 6
# MOVING TOPICS TO ARTILCES PAGE 172
# ENTRO Page 178  - type page Topic, term SORSORS
# ENTRO-2 Page 178 - new def [('SOOT', 2), ('SOPHI', 121), ('SOPHISM', 161), ('SOPHIST', 180), ('SOPHISTICATION', 197), ('SOPHOCLES', 264), ('SOPORIFIC', 342), ('SORBON', 379), ('SORBUS', 654)]
# ------ BEFORE ['SOOT', 'SOPHI', 'SOPHISM', 'SOPHIST', 'SOPHISTICATION', 'SOPHOCLES', 'SOPORIFIC', 'SORBON', 'SORBUS'] - len 9
# element  SOOT
# element  SOPHI
# element  SOPHISM
# element  SOPHIST
# element  SOPHISTICATION
# element  SOPHOCLES
# element  SOPORIFIC
# element  SORBON
# element  SORBUS
# AFTER ['SOOT', 'SOPHI', 'SOPHISM', 'SOPHIST', 'SOPHISTICATION', 'SOPHOCLES', 'SOPORIFIC', 'SORBON', 'SORBUS'] - len 9
# MOVING TOPICS TO ARTILCES PAGE 178
# ENTRO Page 183  - type page Topic, term SS
# ENTRO-2 Page 183 - new def [('&A', 15)]
# ------ BEFORE ['&A'] - len 1
# element  &A
# AFTER [] - len 0
# ENTRO Page 186  - type page Topic, term SPASPARS
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 210  - type page Topic, term IPS
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 232  - type page Empty, term 20I
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 257  - type page Topic, term STENCMRAPHY
# ENTRO-2 Page 257 - new def [('CCLXXV', 720)]
# ------ BEFORE ['CCLXXV'] - len 1
# element  CCLXXV
# AFTER ['CCLXXV'] - len 1
# MOVING TOPICS TO ARTILCES PAGE 257
# ENTRO Page 258  - type page Topic, term STENOGRAPHY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 259  - type page Topic, term STENOGRAPHY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 260  - type page Topic, term STENORAPHY
# ENTRO-2 Page 260 - new def [('STEPHEN', 477), ('STEPHENS', 512)]
# ------ BEFORE ['STEPHEN', 'STEPHENS'] - len 2
# element  STEPHEN
# element  STEPHENS
# AFTER ['STEPHEN', 'STEPHENS'] - len 2
# MOVING TOPICS TO ARTILCES PAGE 260
# ENTRO Page 261  - type page FullPage, term PCCIXXTV
# ENTRO-2 Page 261 - new def [('■-A^A', 124)]
# ------ BEFORE ['■-A^A'] - len 1
# element  ■-A^A
# AFTER [] - len 0
# ENTRO Page 263  - type page FullPage, term PCCXXXVT
# ENTRO-2 Page 263 - new def [('^2^.%-C', 13), ('GV.', 506)]
# ------ BEFORE ['^2^.%-C', 'GV.'] - len 2
# element  ^2^.%-C
# element  GV.
# AFTER [] - len 0
# ENTRO Page 286  - type page Topic, term S
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 291  - type page FullPage, term PCCPXXVT
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 296  - type page Topic, term S
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 315  - type page Topic, term PI
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 316  - type page Topic, term SURGERY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 317  - type page Topic, term PI
# ENTRO-2 Page 317 - new def []
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 318  - type page Topic, term SURGERY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 319  - type page Topic, term P
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 320  - type page Topic, term URCERY
# ENTRO-2 Page 320 - new def []
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 321  - type page Topic, term PII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 322  - type page Topic, term SURGERY
# ENTRO-2 Page 322 - new def []
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 323  - type page Topic, term PII
# ENTRO-2 Page 323 - new def []
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 325  - type page Topic, term PII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 326  - type page Topic, term SURGERY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 327  - type page Topic, term PII
# ENTRO-2 Page 327 - new def []
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 328  - type page Topic, term SURGERY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 329  - type page Topic, term PIT
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 330  - type page Topic, term SURGERY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 331  - type page Topic, term OPII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 332  - type page Topic, term SURCERY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 333  - type page Topic, term PII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 334  - type page Topic, term SRG
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 335  - type page Topic, term PII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 336  - type page Topic, term SUIP
# ENTRO-2 Page 336 - new def []
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 337  - type page Topic, term PII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 338  - type page Topic, term T
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 339  - type page Topic, term PII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 340  - type page Topic, term SURGRY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 341  - type page Topic, term
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 342  - type page Topic, term SURGERY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 343  - type page Topic, term PII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 344  - type page Topic, term SURGERY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 345  - type page Topic, term PIISURGERY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 346  - type page Topic, term SURGERY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 347  - type page Topic, term PII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 348  - type page Topic, term SURGER
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 349  - type page Topic, term PII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 350  - type page Topic, term SURGERY
# ENTRO-2 Page 350 - new def []
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 351  - type page Topic, term PII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 352  - type page Topic, term 0372
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 353  - type page Topic, term IPII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 354  - type page Topic, term SURERY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 355  - type page Topic, term PII
# ENTRO-2 Page 355 - new def []
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 357  - type page Topic, term PII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 358  - type page Topic, term SURERY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 359  - type page Topic, term PILSURGERY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 360  - type page Topic, term SURGERY
# ENTRO-2 Page 360 - new def []
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 361  - type page Topic, term PIT
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 362  - type page Topic, term SSURGERY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 363  - type page Topic, term PII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 365  - type page Topic, term PII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 366  - type page Topic, term SURGERY
# ENTRO-2 Page 366 - new def []
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 367  - type page Topic, term SURGERY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 368  - type page Topic, term URGEY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 369  - type page Topic, term OIIT
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 370  - type page Topic, term SURGERY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 371  - type page Topic, term
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 372  - type page Topic, term STJRGRY
# ENTRO-2 Page 372 - new def []
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 373  - type page Topic, term PITSURGERY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 374  - type page Topic, term SURGERY
# ENTRO-2 Page 374 - new def []
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 375  - type page Topic, term PII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 376  - type page Topic, term SURCERY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 377  - type page Topic, term P
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 378  - type page Topic, term URCERY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 379  - type page Topic, term PII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 380  - type page Topic, term SURGP
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 381  - type page Topic, term P
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 382  - type page Topic, term SURGERY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 383  - type page Topic, term PIII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 385  - type page Topic, term PIII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 386  - type page Topic, term SURGERY
# ENTRO-2 Page 386 - new def []
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 387  - type page Topic, term PIII
# ENTRO-2 Page 387 - new def []
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 388  - type page Topic, term URGEIY
# ENTRO-2 Page 388 - new def [('III', 583)]
# ------ BEFORE ['III'] - len 1
# element  III
# AFTER ['III'] - len 1
# ENTRO Page 389  - type page Topic, term PIII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 390  - type page Topic, term SURGERY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 391  - type page Topic, term HI
# ENTRO-2 Page 391 - new def []
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 392  - type page Topic, term SERY
# ENTRO-2 Page 392 - new def [('III', 359)]
# ------ BEFORE ['III'] - len 1
# element  III
# AFTER ['III'] - len 1
# ENTRO Page 393  - type page Topic, term P
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 394  - type page Topic, term SURGERY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 395  - type page Topic, term PIII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 397  - type page Topic, term PIII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 398  - type page Topic, term SURIJERY
# ENTRO-2 Page 398 - new def []
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 399  - type page Topic, term PIII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 401  - type page Topic, term PIII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 403  - type page Topic, term PIII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 404  - type page Topic, term SURCERY
# ENTRO-2 Page 404 - new def []
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 405  - type page FullPage, term PIIISURMP
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 406  - type page Topic, term SURERY
# ENTRO-2 Page 406 - new def []
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 407  - type page Topic, term PIII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 408  - type page Topic, term SURGERY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 409  - type page Topic, term PIII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 410  - type page Topic, term SURGERY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ...
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 825  - type page Topic, term PIIPOE
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 826  - type page Topic, term TRY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 827  - type page Topic, term PII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 828  - type page Topic, term POETYPII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 829  - type page Topic, term PII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 830  - type page Topic, term POETRY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 831  - type page Topic, term PII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 833  - type page Topic, term PII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 835  - type page Topic, term PLPOETRY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 836  - type page Topic, term PETRY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 837  - type page Topic, term PI
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 838  - type page Topic, term POETRY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 839  - type page Topic, term PII
# ENTRO-2 Page 839 - new def []
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 840  - type page Topic, term POETRY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 841  - type page Topic, term PI
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 842  - type page Topic, term TRY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 843  - type page Topic, term PII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 845  - type page Topic, term PII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 846  - type page Topic, term POETRY
# ENTRO-2 Page 846 - new def []
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 847  - type page Topic, term PIT
# ENTRO-2 Page 847 - new def []
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 848  - type page Topic, term 6330°
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 850  - type page Topic, term TRY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 851  - type page Topic, term POETRY
# ENTRO-2 Page 851 - new def [('CHARTRES', 76), ('GOD', 242)]
# ------ BEFORE ['CHARTRES', 'GOD'] - len 2
# element  CHARTRES
# element  GOD
# AFTER ['CHARTRES', 'GOD'] - len 2
# ENTRO Page 852  - type page Topic, term POETRY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 853  - type page Topic, term PIII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 855  - type page Topic, term PH
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 856  - type page Topic, term POETRY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 857  - type page Topic, term P
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 859  - type page Topic, term PHI
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 860  - type page Topic, term POETRY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 861  - type page Topic, term PIII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 862  - type page Topic, term 6344
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 863  - type page Topic, term PIII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 864  - type page Topic, term POETRY
# ENTRO-2 Page 864 - new def [('EUS', 798)]
# ------ BEFORE ['EUS'] - len 1
# element  EUS
# AFTER ['EUS'] - len 1
# ENTRO Page 865  - type page Topic, term PIII
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 866  - type page Topic, term DPVLUM
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 22  - type page FullPage, term POLR
# ENTRO-2 Page 22 - new def [('11O3', 550)]
# ------ BEFORE ['11O3'] - len 1
# element  11O3
# AFTER [] - len 0
# ENTRO Page 92  - type page Topic, term POR
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 142  - type page Topic, term CCXLV
# ENTRO-2 Page 142 - new def [('HIK', 380), ('PRIOR', 780)]
# ------ BEFORE ['HIK', 'PRIOR'] - len 2
# element  HIK
# element  PRIOR
# AFTER ['HIK', 'PRIOR'] - len 2
# MOVING TOPICS TO ARTILCES PAGE 142
# ENTRO Page 146  - type page Topic, term P
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 154  - type page FullPage, term SPHOJECTIQNS
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 155  - type page Topic, term (CCXLVI
# ENTRO-2 Page 155 - new def [('D=FTT', 19), ('AFGHI', 475), ('AQ^AR', 748), ('ABG', 794), ('ACH', 795), ('AH=HP', 1010), ('NH=CN', 1025), ('PROJECTION', 1234), ('BCD', 1536)]
# ------ BEFORE ['D=FTT', 'AFGHI', 'AQ^AR', 'ABG', 'ACH', 'AH=HP', 'NH=CN', 'PROJECTION', 'BCD'] - len 9
# element  D=FTT
# element  AFGHI
# element  AQ^AR
# element  ABG
# element  ACH
# element  AH=HP
# element  NH=CN
# element  PROJECTION
# element  BCD
# AFTER ['AFGHI', 'ABG', 'ACH', 'PROJECTION', 'BCD'] - len 5
# MOVING TOPICS TO ARTILCES PAGE 155
# ENTRO Page 178  - type page FullPage, term PRUPA
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 186  - type page Topic, term PPSE
# ENTRO-2 Page 186 - new def [('PSALTER', 88), ('PSALTERY', 132), ('PSAMMETICUS', 225), ('PSEUDO', 276), ('PSEUDONYMUS', 1143)]
# ------ BEFORE ['PSALTER', 'PSALTERY', 'PSAMMETICUS', 'PSEUDO', 'PSEUDONYMUS'] - len 5
# element  PSALTER
# element  PSALTERY
# element  PSAMMETICUS
# element  PSEUDO
# element  PSEUDONYMUS
# AFTER ['PSALTER', 'PSALTERY', 'PSAMMETICUS', 'PSEUDO', 'PSEUDONYMUS'] - len 5
# MOVING TOPICS TO ARTILCES PAGE 186
# ENTRO Page 193  - type page FullPage, term PUMPUM
# ENTRO-2 Page 193 - new def [('TION', 338), ('PUMICE', 429), ('PUMP', 625)]
# ------ BEFORE ['TION', 'PUMICE', 'PUMP'] - len 3
# element  TION
# element  PUMICE
# element  PUMP
# AFTER ['TION', 'PUMICE', 'PUMP'] - len 3
# MOVING TOPICS TO ARTILCES PAGE 193
# ENTRO Page 194  - type page Topic, term P
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 196  - type page Topic, term PCCXLV
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 203  - type page Topic, term TYROTICCHISTY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 217  - type page Topic, term S
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 218  - type page Topic, term S
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 219  - type page Topic, term S
# ENTRO-2 Page 219 - new def [('40Z', 197)]
# ------ BEFORE ['40Z'] - len 1
# element  40Z
# AFTER [] - len 0
# ENTRO Page 220  - type page Topic, term PYROT
# ENTRO-2 Page 220 - new def []
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 221  - type page Topic, term S
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 222  - type page Topic, term PYROTECHNY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 223  - type page Topic, term S
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 224  - type page Topic, term PYROTECHNY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 225  - type page Topic, term S
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 226  - type page Topic, term PYROTECHNY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 227  - type page Topic, term S
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 228  - type page Topic, term PYROTECHNY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 229  - type page Topic, term S
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 230  - type page Topic, term PYROT
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 231  - type page Topic, term S
# ENTRO-2 Page 231 - new def []
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 232  - type page Topic, term PYROTECHNY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 233  - type page Topic, term PYROTECHNY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 234  - type page Topic, term PYROTECHNY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 235  - type page Topic, term S
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 236  - type page Topic, term PYROTECHMY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 237  - type page Topic, term S
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 238  - type page Topic, term PYROT
# ENTRO-2 Page 238 - new def [('A', 325), ('A', 849), ('E', 876)]
# ------ BEFORE ['A', 'A', 'E'] - len 3
# element  A
# element  A
# element  E
# AFTER ['A', 'A', 'E'] - len 3
# ENTRO Page 241  - type page Topic, term S
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 242  - type page Topic, term 6
# ENTRO-2 Page 242 - new def [('NNN', 1184)]
# ------ BEFORE ['NNN'] - len 1
# element  NNN
# AFTER ['NNN'] - len 1
# ENTRO Page 243  - type page Topic, term S
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 247  - type page Topic, term S
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 248  - type page Topic, term PYROTECHNY
# ENTRO-2 Page 248 - new def [('D', 247), ('E', 290), ('G', 967)]
# ------ BEFORE ['D', 'E', 'G'] - len 3
# element  D
# element  E
# element  G
# AFTER ['D', 'E', 'G'] - len 3
# ENTRO Page 251  - type page Topic, term S
# ENTRO-2 Page 251 - new def [('A', 1199), ('A', 1200)]
# ------ BEFORE ['A', 'A'] - len 2
# element  A
# element  A
# AFTER ['A', 'A'] - len 2
# ENTRO Page 252  - type page Topic, term PYROTECHNY
# ENTRO-2 Page 252 - new def []
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 253  - type page Topic, term
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 254  - type page Topic, term PYROTECHNY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 255  - type page Topic, term S
# ENTRO-2 Page 255 - new def [('PYROTICS', 275), ('PYRRHICHA', 297), ('PYRRHICHIUS', 419), ('PYRRHO', 449), ('PYRRHUS', 561), ('PYRRHONIANS', 828), ('PYRUS', 845), ('PYTHAGORAS', 1552)]
# ------ BEFORE ['PYROTICS', 'PYRRHICHA', 'PYRRHICHIUS', 'PYRRHO', 'PYRRHUS', 'PYRRHONIANS', 'PYRUS', 'PYTHAGORAS'] - len 8
# element  PYROTICS
# element  PYRRHICHA
# element  PYRRHICHIUS
# element  PYRRHO
# element  PYRRHUS
# element  PYRRHONIANS
# element  PYRUS
# element  PYTHAGORAS
# AFTER ['PYROTICS', 'PYRRHICHA', 'PYRRHICHIUS', 'PYRRHO', 'PYRRHUS', 'PYRRHONIANS', 'PYRUS', 'PYTHAGORAS'] - len 8
# MOVING TOPICS TO ARTILCES PAGE 255
# ENTRO Page 271  - type page Topic, term Q
# ENTRO-2 Page 271 - new def [('W/%', 34), ('QUARTERS', 681)]
# ------ BEFORE ['W/%', 'QUARTERS'] - len 2
# element  W/%
# element  QUARTERS
# AFTER ['QUARTERS'] - len 1
# MOVING TOPICS TO ARTILCES PAGE 271
# ENTRO Page 281  - type page Topic, term Q
# ENTRO-2 Page 281 - new def [('QUIRK', 322), ('QUOIN', 435), ('QLJIRINALIA', 599), ('QUIRITES', 612), ('QUOTIDIAN', 815), ('QUORUM', 865), ('QUOTIENT', 967)]
# ------ BEFORE ['QUIRK', 'QUOIN', 'QLJIRINALIA', 'QUIRITES', 'QUOTIDIAN', 'QUORUM', 'QUOTIENT'] - len 7
# element  QUIRK
# element  QUOIN
# element  QLJIRINALIA
# element  QUIRITES
# element  QUOTIDIAN
# element  QUORUM
# element  QUOTIENT
# AFTER ['QUIRK', 'QUOIN', 'QLJIRINALIA', 'QUIRITES', 'QUOTIDIAN', 'QUORUM', 'QUOTIENT'] - len 7
# MOVING TOPICS TO ARTILCES PAGE 281
# ENTRO Page 299  - type page FullPage, term YCOIY
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 305  - type page Topic, term CCLV
# ENTRO-2 Page 305 - new def [('33J:', 2206)]
# ------ BEFORE ['33J:'] - len 1
# element  33J:
# AFTER [] - len 0
# ENTRO Page 307  - type page Topic, term CCLVII
# ENTRO-2 Page 307 - new def [('I', 17)]
# ------ BEFORE ['I'] - len 1
# element  I
# AFTER ['I'] - len 1
# MOVING TOPICS TO ARTILCES PAGE 307
# ENTRO Page 310  - type page Topic, term R
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 313  - type page Topic, term RANRAP
# ENTRO-2 Page 313 - new def [('RAPE', 727)]
# ------ BEFORE ['RAPE'] - len 1
# element  RAPE
# AFTER ['RAPE'] - len 1
# MOVING TOPICS TO ARTILCES PAGE 313
# ENTRO Page 363  - type page Topic, term R
# ENTRO-2 Page 363 - new def [('RESEN', 825), ('RESERVATION', 914), ('RESERVE', 997), ('RESERVOIR', 1053), ('RESET', 1079), ('RESIDENCE', 1100)]
# ------ BEFORE ['RESEN', 'RESERVATION', 'RESERVE', 'RESERVOIR', 'RESET', 'RESIDENCE'] - len 6
# element  RESEN
# element  RESERVATION
# element  RESERVE
# element  RESERVOIR
# element  RESET
# element  RESIDENCE
# AFTER ['RESEN', 'RESERVATION', 'RESERVE', 'RESERVOIR', 'RESET', 'RESIDENCE'] - len 6
# MOVING TOPICS TO ARTILCES PAGE 363
# ENTRO Page 368  - type page Topic, term REVREVREVEILLERT
# ENTRO-2 Page 368 - new def [('REUTLINGEN', 523), ('REVE', 572), ('REVEILLE', 601), ('REVEL', 637), ('REVELATION', 658), ('REVELS', 1008), ('REVENUE', 1051)]
# ------ BEFORE ['REUTLINGEN', 'REVE', 'REVEILLE', 'REVEL', 'REVELATION', 'REVELS', 'REVENUE'] - len 7
# element  REUTLINGEN
# element  REVE
# element  REVEILLE
# element  REVEL
# element  REVELATION
# element  REVELS
# element  REVENUE
# AFTER ['REUTLINGEN', 'REVE', 'REVEILLE', 'REVEL', 'REVELATION', 'REVELS', 'REVENUE'] - len 7
# MOVING TOPICS TO ARTILCES PAGE 368
# ENTRO Page 398  - type page Topic, term RIDLRID
# ENTRO-2 Page 398 - new def [('RICINUS', 139), ('RICKETS', 283), ('RICOCHET', 290), ('RIDGE', 453), ('RIDGLING', 469), ('RIDICULE', 485)]
# ------ BEFORE ['RICINUS', 'RICKETS', 'RICOCHET', 'RIDGE', 'RIDGLING', 'RIDICULE'] - len 6
# element  RICINUS
# element  RICKETS
# element  RICOCHET
# element  RIDGE
# element  RIDGLING
# element  RIDICULE
# AFTER ['RICINUS', 'RICKETS', 'RICOCHET', 'RIDGE', 'RIDGLING', 'RIDICULE'] - len 6
# MOVING TOPICS TO ARTILCES PAGE 398
# ENTRO Page 459  - type page Topic, term ROM
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 484  - type page Topic, term ROMROM
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 485  - type page Topic, term ROMIROM
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 499  - type page Topic, term ROMROMTR
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 565  - type page Topic, term ROSR
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 605  - type page Topic, term S
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 612  - type page Topic, term TOCVDX
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 643  - type page FullPage, term SARSATSARDONYX
# ENTRO-2 Page 643 - new def [('SARDINIA', 163), ('SARDIS', 466), ('SARDONYX', 577), ('SARGUS', 616), ('SARMENTOS^E', 621), ('SARSAPARILLA', 672), ('SARTORIUS', 677), ('SASHES', 686), ('SASINE', 747), ('SATELLITE', 759), ('SATRAPA', 770), ('SATTIN', 787), ('SATTINET', 810), ('SATURANTS', 828), ('SATURATION', 835), ('SATURDAY', 861), ('SATUREIA', 896)]
# ------ BEFORE ['SARDINIA', 'SARDIS', 'SARDONYX', 'SARGUS', 'SARMENTOS^E', 'SARSAPARILLA', 'SARTORIUS', 'SASHES', 'SASINE', 'SATELLITE', 'SATRAPA', 'SATTIN', 'SATTINET', 'SATURANTS', 'SATURATION', 'SATURDAY', 'SATUREIA'] - len 17
# element  SARDINIA
# element  SARDIS
# element  SARDONYX
# element  SARGUS
# element  SARMENTOS^E
# element  SARSAPARILLA
# element  SARTORIUS
# element  SASHES
# element  SASINE
# element  SATELLITE
# element  SATRAPA
# element  SATTIN
# element  SATTINET
# element  SATURANTS
# element  SATURATION
# element  SATURDAY
# element  SATUREIA
# AFTER ['SARDINIA', 'SARDIS', 'SARDONYX', 'SARGUS', 'SARSAPARILLA', 'SARTORIUS', 'SASHES', 'SASINE', 'SATELLITE', 'SATRAPA', 'SATTIN', 'SATTINET', 'SATURANTS', 'SATURATION', 'SATURDAY', 'SATUREIA'] - len 16
# MOVING TOPICS TO ARTILCES PAGE 643
# ENTRO Page 672  - type page Topic, term CCLXI
# ENTRO-2 Page 672 - new def [('SCOLGPENDRA', 871), ('SCOMBER', 1219)]
# ------ BEFORE ['SCOLGPENDRA', 'SCOMBER'] - len 2
# element  SCOLGPENDRA
# element  SCOMBER
# AFTER ['SCOLGPENDRA', 'SCOMBER'] - len 2
# MOVING TOPICS TO ARTILCES PAGE 672
# ENTRO Page 673  - type page Topic, term PCCPXL
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 688  - type page Topic, term S
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 732  - type page Topic, term SCOSC
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 749  - type page Topic, term SEL
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 762  - type page Topic, term SCO
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 769  - type page Topic, term S
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 775  - type page Topic, term SCO
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 778  - type page Topic, term D
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 798  - type page Topic, term SCOSSSCO
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 811  - type page Topic, term SCOSSCORS
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 831  - type page FullPage, term SCOMS
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 833  - type page Topic, term S
# ------ BEFORE [] - len 0
# AFTER [] - len 0
# ENTRO Page 841  - type page Topic, term SCOSCOM
# ------ BEFORE [] - len 0
# AFTER [] - len 0

# %% [markdown]
# ### 3. Merging topics together across pages
#
# First, we are going to transfor those pages, which only have 1 article, and the previous term is a topic, into topics, and give the previous term to these ones.

# %%
articles_refined= fixing_topics(articles_refined)

# %%
articles_refined= removing_fullpages(articles_refined)

# %% [markdown]
# Now, we are goint to merge topics.
# Topics can be across several pages, so we are going to **merge consecutive page-topics together**.

# %%
topics_refined, merged_topics, freq_topics_terms, provenance_removal =merge_topics(articles_refined)
# Out:
# STUDYING ACOUSTICSC at 76
# SIMILAR-TERMS, clean term ACOUSTICSC, next_term C, similarity 0.18181818181818182,  len def1 7091, check1 True, check 2  0.000000uture similarity 0.9473684210526315, two_next_term ACOUSTICS
# SIMILAR-2TERMS, clean term ACOUSTICSC, two_next_terms ACOUSTICS, check False
# SIMILAR-TERMS, clean term ACOUSTICSC, next_term , similarity 0.0,  len def1 6823, check1 True, check 2  0.000000uture similarity 0.75, two_next_term ASTICS
# SIMILAR-2TERMS, clean term ACOUSTICSC, two_next_terms ASTICS, check False
# SIMILAR-TERMS, clean term ACOUSTICSC, next_term I, similarity 0.18181818181818182,  len def1 6766, check1 True, check 2  0.000000uture similarity 0.9473684210526315, two_next_term ACOUSTICS
# SIMILAR-2TERMS, clean term ACOUSTICSC, two_next_terms ACOUSTICS, check False
# SIMILAR-TERMS, clean term ACOUSTICSC, next_term HI, similarity 0.16666666666666666,  len def1 3669, check1 False, check 2  0.000000uture similarity 0.42857142857142855, two_next_term ACQS
# PASANDO AL SIGUIENTE: clean_term ACOUSTICSC, next_term ACQS, two_next_terms ACQUA-CHE-TAVELLA
# STUDYING AGRICULTURE at 147
# SIMILAR-TERMS, clean term AGRICULTURE, next_term AGRICULTURE, similarity 1.0,  len def1 6851, check1 False, check 2  1.000000uture similarity 0.15384615384615385, two_next_term PI
# SIMILAR-2TERMS, clean term AGRICULTURE, two_next_terms PI, check True
# SIMILAR-TERMS, clean term AGRICULTURE, next_term AGRICULTURE, similarity 1.0,  len def1 7052, check1 False, check 2  1.000000uture similarity 0.0, two_next_term P
# SIMILAR-2TERMS, clean term AGRICULTURE, two_next_terms P, check True
# SIMILAR-TERMS, clean term AGRICULTURE, next_term P, similarity 0.0,  len def1 13682, check1 True, check 2  1.000000uture similarity 0.0, two_next_term P
# SIMILAR-2TERMS, clean term AGRICULTURE, two_next_terms P, check True
# SIMILAR-TERMS, clean term AGRICULTURE, next_term AGRICULTURE, similarity 1.0,  len def1 6879, check1 False, check 2  1.000000uture similarity 0.0, two_next_term P
# SIMILAR-2TERMS, clean term AGRICULTURE, two_next_terms P, check True
# SIMILAR-TERMS, clean term AGRICULTURE, next_term AGRICTJ, similarity 0.6666666666666666,  len def1 6958, check1 False, check 2  1.000000uture similarity 0.0, two_next_term P
# SIMILAR-2TERMS, clean term AGRICULTURE, two_next_terms P, check True
# SIMILAR-TERMS, clean term AGRICULTURE, next_term AGRICULTURE, similarity 1.0,  len def1 13934, check1 False, check 2  0.000000uture similarity 1.0, two_next_term AGRICULTURE
# SIMILAR-2TERMS, clean term AGRICULTURE, two_next_terms AGRICULTURE, check False
# SIMILAR-TERMS, clean term AGRICULTURE, next_term PIAGRICULTURE, similarity 0.9166666666666666,  len def1 7071, check1 False, check 2  0.000000uture similarity 0.16666666666666666, two_next_term T
# SIMILAR-2TERMS, clean term AGRICULTURE, two_next_terms T, check False
# SIMILAR-TERMS, clean term AGRICULTURE, next_term II, similarity 0.15384615384615385,  len def1 6823, check1 True, check 2  0.000000uture similarity 0.9565217391304348, two_next_term HAGRICULTURE
# SIMILAR-2TERMS, clean term AGRICULTURE, two_next_terms HAGRICULTURE, check False
# SIMILAR-TERMS, clean term AGRICULTURE, next_term PII, similarity 0.14285714285714285,  len def1 6560, check1 True, check 2  0.000000uture similarity 1.0, two_next_term AGRICULTURE
# SIMILAR-2TERMS, clean term AGRICULTURE, two_next_terms AGRICULTURE, check False
# SIMILAR-TERMS, clean term AGRICULTURE, next_term PII, similarity 0.14285714285714285,  len def1 6675, check1 True, check 2  0.000000uture similarity 1.0, two_next_term AGRICULTURE
# SIMILAR-2TERMS, clean term AGRICULTURE, two_next_terms AGRICULTURE, check False
# SIMILAR-TERMS, clean term AGRICULTURE, next_term IPII, similarity 0.13333333333333333,  len def1 13828, check1 False, check 2  1.000000uture similarity 0.14285714285714285, two_next_term PII
# SIMILAR-2TERMS, clean term AGRICULTURE, two_next_terms PII, check True
# SIMILAR-TERMS, clean term AGRICULTURE, next_term AGRICULTURE, similarity 1.0,  len def1 6753, check1 False, check 2  1.000000uture similarity 0.14285714285714285, two_next_term PII
# SIMILAR-2TERMS, clean term AGRICULTURE, two_next_terms PII, check True
# SIMILAR-TERMS, clean term AGRICULTURE, next_term AGRICU, similarity 0.7058823529411765,  len def1 6670, check1 False, check 2  1.000000uture similarity 0.14285714285714285, two_next_term PII
# SIMILAR-2TERMS, clean term AGRICULTURE, two_next_terms PII, check True
# SIMILAR-TERMS, clean term AGRICULTURE, next_term AGRICULTURE, similarity 1.0,  len def1 6668, check1 False, check 2  1.000000uture similarity 0.14285714285714285, two_next_term PII
# SIMILAR-2TERMS, clean term AGRICULTURE, two_next_terms PII, check True
# SIMILAR-TERMS, clean term AGRICULTURE, next_term PII, similarity 0.14285714285714285,  len def1 6655, check1 True, check 2  0.000000uture similarity 1.0, two_next_term AGRICULTURE
# SIMILAR-2TERMS, clean term AGRICULTURE, two_next_terms AGRICULTURE, check False
# SIMILAR-TERMS, clean term AGRICULTURE, next_term PIT, similarity 0.2857142857142857,  len def1 5923, check1 False, check 2  0.000000uture similarity 1.0, two_next_term AGRICULTURE
# SIMILAR-2TERMS, clean term AGRICULTURE, two_next_terms AGRICULTURE, check False
# SIMILAR-TERMS, clean term AGRICULTURE, next_term PII, similarity 0.14285714285714285,  len def1 6788, check1 True, check 2  0.000000uture similarity 1.0, two_next_term AGRICULTURE
# SIMILAR-2TERMS, clean term AGRICULTURE, two_next_terms AGRICULTURE, check False
# SIMILAR-TERMS, clean term AGRICULTURE, next_term PII, similarity 0.14285714285714285,  len def1 6582, check1 True, check 2  0.000000uture similarity 1.0, two_next_term AGRICULTURE
# SIMILAR-2TERMS, clean term AGRICULTURE, two_next_terms AGRICULTURE, check False
# SIMILAR-TERMS, clean term AGRICULTURE, next_term AGRIFOLIUM, similarity 0.47619047619047616,  len def1 24, check1 False, check 2  0.000000uture similarity 0.4, two_next_term AGRIMONIA
# SIMILAR-TERMS, clean term AGRICULTURE, next_term AGRIMONIA, similarity 0.4,  len def1 1, check1 False, check 2  0.000000uture similarity 0.43478260869565216, two_next_term AGRIMONOIDES
# SIMILAR-TERMS, clean term AGRICULTURE, next_term AGRIMONOIDES, similarity 0.43478260869565216,  len def1 29, check1 False, check 2  0.000000uture similarity 0.42105263157894735, two_next_term AGRIMONY
# PASANDO AL SIGUIENTE: clean_term AGRICULTURE, next_term AGRIMONY, two_next_terms AGRIONIA
# STUDYING ALGEBRA at 260
# SIMILAR-TERMS, clean term ALGEBRA, next_term S, similarity 0.0,  len def1 6321, check1 True, check 2  0.000000uture similarity 1.0, two_next_term ALGEBRA
# SIMILAR-2TERMS, clean term ALGEBRA, two_next_terms ALGEBRA, check False
# SIMILAR-TERMS, clean term ALGEBRA, next_term S, similarity 0.0,  len def1 6424, check1 True, check 2  0.000000uture similarity 0.0, two_next_term 2$2
# SIMILAR-2TERMS, clean term ALGEBRA, two_next_terms 2$2, check False
# SIMILAR-TERMS, clean term ALGEBRA, next_term S, similarity 0.0,  len def1 5725, check1 True, check 2  0.000000uture similarity 0.8333333333333334, two_next_term ALGEB
# SIMILAR-2TERMS, clean term ALGEBRA, two_next_terms ALGEB, check False
# SIMILAR-TERMS, clean term ALGEBRA, next_term S, similarity 0.0,  len def1 5950, check1 True, check 2  0.000000uture similarity 1.0, two_next_term ALGEBRA
# SIMILAR-2TERMS, clean term ALGEBRA, two_next_terms ALGEBRA, check False
# SIMILAR-TERMS, clean term ALGEBRA, next_term ALGEDO, similarity 0.6153846153846154,  len def1 639, check1 False, check 2  0.000000uture similarity 0.7142857142857143, two_next_term ALGENEB
# SIMILAR-2TERMS, clean term ALGEBRA, two_next_terms ALGENEB, check False
# SIMILAR-TERMS, clean term ALGEBRA, next_term ALGEZIRA, similarity 0.8,  len def1 351, check1 False, check 2  0.000000uture similarity 0.7142857142857143, two_next_term ALGHIER
# SIMILAR-2TERMS, clean term ALGEBRA, two_next_terms ALGHIER, check False
# SIMILAR-TERMS, clean term ALGEBRA, next_term ALGIABARII, similarity 0.5882352941176471,  len def1 368, check1 False, check 2  0.000000uture similarity 0.7142857142857143, two_next_term ALGIERS
# SIMILAR-2TERMS, clean term ALGEBRA, two_next_terms ALGIERS, check False
# SIMILAR-TERMS, clean term ALGEBRA, next_term TU, similarity 0.0,  len def1 9564, check1 False, check 2  0.000000uture similarity 0.5, two_next_term ALGOL
# PASANDO AL SIGUIENTE: clean_term ALGEBRA, next_term ALGOL, two_next_terms ALGONQUINS
# STUDYING ANATOMY at 372
# SIMILAR-TERMS, clean term ANATOMY, next_term H, similarity 0.0,  len def1 6813, check1 True, check 2  0.000000uture similarity 1.0, two_next_term ANATOMY
# SIMILAR-2TERMS, clean term ANATOMY, two_next_terms ANATOMY, check False
# SIMILAR-TERMS, clean term ANATOMY, next_term PI, similarity 0.0,  len def1 6340, check1 True, check 2  0.000000uture similarity 1.0, two_next_term ANATOMY
# SIMILAR-2TERMS, clean term ANATOMY, two_next_terms ANATOMY, check False
# SIMILAR-TERMS, clean term ANATOMY, next_term PI, similarity 0.0,  len def1 6603, check1 True, check 2  0.000000uture similarity 1.0, two_next_term ANATOMY
# SIMILAR-2TERMS, clean term ANATOMY, two_next_terms ANATOMY, check False
# SIMILAR-TERMS, clean term ANATOMY, next_term ANATOMY, similarity 1.0,  len def1 6787, check1 False, check 2  0.000000uture similarity 0.9333333333333333, two_next_term PANATOMY
# SIMILAR-2TERMS, clean term ANATOMY, two_next_terms PANATOMY, check False
# SIMILAR-TERMS, clean term ANATOMY, next_term ANATOMY, similarity 1.0,  len def1 6522, check1 False, check 2  0.000000uture similarity 1.0, two_next_term ANATOMY
# SIMILAR-2TERMS, clean term ANATOMY, two_next_terms ANATOMY, check False
# SIMILAR-TERMS, clean term ANATOMY, next_term ANATOMY, similarity 1.0,  len def1 6293, check1 False, check 2  1.000000uture similarity 0.0, two_next_term PI
# SIMILAR-2TERMS, clean term ANATOMY, two_next_terms PI, check True
# SIMILAR-TERMS, clean term ANATOMY, next_term ANATOMY, similarity 1.0,  len def1 6579, check1 False, check 2  1.000000uture similarity 0.0, two_next_term I
# SIMILAR-2TERMS, clean term ANATOMY, two_next_terms I, check True
# SIMILAR-TERMS, clean term ANATOMY, next_term PI, similarity 0.0,  len def1 6446, check1 True, check 2  0.000000uture similarity 1.0, two_next_term ANATOMY
# SIMILAR-2TERMS, clean term ANATOMY, two_next_terms ANATOMY, check False
# SIMILAR-TERMS, clean term ANATOMY, next_term ANATOMY, similarity 1.0,  len def1 8137, check1 False, check 2  0.000000uture similarity 0.4, two_next_term AAA
# SIMILAR-2TERMS, clean term ANATOMY, two_next_terms AAA, check False
# SIMILAR-TERMS, clean term ANATOMY, next_term JL, similarity 0.0,  len def1 3205, check1 False, check 2  0.000000uture similarity 0.14285714285714285, two_next_term GENERAL
# SIMILAR-TERMS, clean term ANATOMY, next_term GENERAL, similarity 0.14285714285714285,  len def1 3, check1 False, check 2  0.000000uture similarity 1.0, two_next_term ANATOMY
# SIMILAR-2TERMS, clean term ANATOMY, two_next_terms ANATOMY, check False
# SIMILAR-TERMS, clean term ANATOMY, next_term PII, similarity 0.0,  len def1 6886, check1 True, check 2  0.000000uture similarity 1.0, two_next_term ANATOMY
# SIMILAR-2TERMS, clean term ANATOMY, two_next_terms ANATOMY, check False
# PASANDO AL SIGUIENTE: clean_term ANATOMY, next_term ATABLENM, two_next_terms ATABLEMUSCLES
# STUDYING ATABLEMUSCLES at 405
# SIMILAR-TERMS, clean term ATABLEMUSCLES, next_term PIII, similarity 0.0,  len def1 5664, check1 True, check 2  0.000000uture similarity 0.3, two_next_term ANATOMY
# PASANDO AL SIGUIENTE: clean_term ATABLEMUSCLES, next_term ANATOMY, two_next_terms ANATOMY
# STUDYING ANATOMY at 413
# SIMILAR-TERMS, clean term ANATOMY, next_term ANAOMY, similarity 0.9230769230769231,  len def1 6244, check1 False, check 2  1.000000uture similarity 0.0, two_next_term IV
# SIMILAR-2TERMS, clean term ANATOMY, two_next_terms IV, check True
# SIMILAR-TERMS, clean term ANATOMY, next_term ANATOMY, similarity 1.0,  len def1 6317, check1 False, check 2  1.000000uture similarity 0.0, two_next_term IV
# SIMILAR-2TERMS, clean term ANATOMY, two_next_terms IV, check True
# SIMILAR-TERMS, clean term ANATOMY, next_term _, similarity 0.0,  len def1 6337, check1 True, check 2  1.000000uture similarity 0.0, two_next_term
# SIMILAR-2TERMS, clean term ANATOMY, two_next_terms , check True
# SIMILAR-TERMS, clean term ANATOMY, next_term ANATOMY, similarity 1.0,  len def1 6669, check1 False, check 2  0.000000uture similarity 1.0, two_next_term ANATOMY
# SIMILAR-2TERMS, clean term ANATOMY, two_next_terms ANATOMY, check False
# SIMILAR-TERMS, clean term ANATOMY, next_term ANATOMY, similarity 1.0,  len def1 6707, check1 False, check 2  1.000000uture similarity 0.0, two_next_term IV
# SIMILAR-2TERMS, clean term ANATOMY, two_next_terms IV, check True
# SIMILAR-TERMS, clean term ANATOMY, next_term ANATOMY, similarity 1.0,  len def1 6735, check1 False, check 2  0.000000uture similarity 1.0, two_next_term ANATOMY
# SIMILAR-2TERMS, clean term ANATOMY, two_next_terms ANATOMY, check False
# SIMILAR-TERMS, clean term ANATOMY, next_term ANATOMY, similarity 1.0,  len def1 6580, check1 False, check 2  0.000000uture similarity 1.0, two_next_term ANATOMY
# SIMILAR-2TERMS, clean term ANATOMY, two_next_terms ANATOMY, check False
# SIMILAR-TERMS, clean term ANATOMY, next_term ANATOMY, similarity 1.0,  len def1 5981, check1 False, check 2  0.000000uture similarity 0.0, two_next_term PV
# SIMILAR-2TERMS, clean term ANATOMY, two_next_terms PV, check False
# SIMILAR-TERMS, clean term ANATOMY, next_term ANATOMY, similarity 1.0,  len def1 6493, check1 False, check 2  0.000000uture similarity 0.0, two_next_term PV
# SIMILAR-2TERMS, clean term ANATOMY, two_next_terms PV, check False
# SIMILAR-TERMS, clean term ANATOMY, next_term PANATOMY, similarity 0.9333333333333333,  len def1 6833, check1 False, check 2  0.000000uture similarity 1.0, two_next_term ANATOMY
# SIMILAR-2TERMS, clean term ANATOMY, two_next_terms ANATOMY, check False
# SIMILAR-TERMS, clean term ANATOMY, next_term ANATOMY, similarity 1.0,  len def1 6094, check1 False, check 2  1.000000uture similarity 0.0, two_next_term V
# SIMILAR-2TERMS, clean term ANATOMY, two_next_terms V, check True
# SIMILAR-TERMS, clean term ANATOMY, next_term ANATOMY, similarity 1.0,  len def1 6362, check1 False, check 2  0.000000uture similarity 1.0, two_next_term ANATOMY
# SIMILAR-2TERMS, clean term ANATOMY, two_next_terms ANATOMY, check False
# SIMILAR-TERMS, clean term ANATOMY, next_term ANATOMY, similarity 1.0,  len def1 6699, check1 False, check 2  0.000000uture similarity 1.0, two_next_term ANATOMY
# SIMILAR-2TERMS, clean term ANATOMY, two_next_terms ANATOMY, check False
# SIMILAR-TERMS, clean term ANATOMY, next_term PANATOMY, similarity 0.9333333333333333,  len def1 5946, check1 False, check 2  1.000000uture similarity 0.0, two_next_term
# SIMILAR-2TERMS, clean term ANATOMY, two_next_terms , check True
# SIMILAR-TERMS, clean term ANATOMY, next_term ANATOMY, similarity 1.0,  len def1 6643, check1 False, check 2  0.000000uture similarity 1.0, two_next_term ANATOMY
# SIMILAR-2TERMS, clean term ANATOMY, two_next_terms ANATOMY, check False
# SIMILAR-TERMS, clean term ANATOMY, next_term PVANATOMY, similarity 0.875,  len def1 6673, check1 False, check 2  0.000000uture similarity 0.0, two_next_term PVH
# SIMILAR-2TERMS, clean term ANATOMY, two_next_terms PVH, check False
# SIMILAR-TERMS, clean term ANATOMY, next_term ANATOMY, similarity 1.0,  len def1 5628, check1 False, check 2  0.000000uture similarity 0.47058823529411764, two_next_term ANAXAGORAS
# PASANDO AL SIGUIENTE: clean_term ANATOMY, next_term ANAXAGORAS, two_next_terms ANAXIMENES
# STUDYING AF at 504
# SIMILAR-TERMS, clean term AF, next_term _, similarity 0.0,  len def1 13633, check1 True, check 2  0.000000uture similarity 0.2, two_next_term ANIMATED
# PASANDO AL SIGUIENTE: clean_term AF, next_term ANIMATED, two_next_terms ANIMATION
# STUDYING ANNUITIES at 527
# SIMILAR-TERMS, clean term ANNUITIES, next_term ANNUITIES, similarity 1.0,  len def1 3291, check1 False, check 2  0.000000uture similarity 0.7142857142857143, two_next_term ANNUI
# SIMILAR-2TERMS, clean term ANNUITIES, two_next_terms ANNUI, check False
# SIMILAR-TERMS, clean term ANNUITIES, next_term ANNUITIES, similarity 1.0,  len def1 4635, check1 False, check 2  0.000000uture similarity 0.75, two_next_term ANNUITY
# SIMILAR-2TERMS, clean term ANNUITIES, two_next_terms ANNUITY, check False
# PASANDO AL SIGUIENTE: clean_term ANNUITIES, next_term ANNULAR, two_next_terms ANNULET
# STUDYING ARCHIT at 668
# SIMILAR-TERMS, clean term ARCHIT, next_term H, similarity 0.2857142857142857,  len def1 6909, check1 True, check 2  0.000000uture similarity 0.16666666666666666, two_next_term ECTURE
# SIMILAR-TERMS, clean term ARCHIT, next_term ECTURE, similarity 0.16666666666666666,  len def1 7001, check1 False, check 2  1.000000uture similarity 0.2857142857142857, two_next_term H
# SIMILAR-2TERMS, clean term ARCHIT, two_next_terms H, check True
# SIMILAR-TERMS, clean term ARCHIT, next_term ARCHITECTURE, similarity 0.6666666666666666,  len def1 6961, check1 False, check 2  1.000000uture similarity 0.2857142857142857, two_next_term H
# SIMILAR-2TERMS, clean term ARCHIT, two_next_terms H, check True
# SIMILAR-TERMS, clean term ARCHIT, next_term ARCHITECTURE, similarity 0.6666666666666666,  len def1 7079, check1 False, check 2  1.000000uture similarity 0.25, two_next_term PI
# SIMILAR-2TERMS, clean term ARCHIT, two_next_terms PI, check True
# SIMILAR-TERMS, clean term ARCHIT, next_term ARCHITECTURE, similarity 0.6666666666666666,  len def1 6759, check1 False, check 2  1.000000uture similarity 0.0, two_next_term P
# SIMILAR-2TERMS, clean term ARCHIT, two_next_terms P, check True
# SIMILAR-TERMS, clean term ARCHIT, next_term ABE, similarity 0.2222222222222222,  len def1 7, check1 False, check 2  1.000000uture similarity 0.25, two_next_term PI
# SIMILAR-2TERMS, clean term ARCHIT, two_next_terms PI, check True
# SIMILAR-TERMS, clean term ARCHIT, next_term URE, similarity 0.2222222222222222,  len def1 6330, check1 False, check 2  1.000000uture similarity 0.0, two_next_term P
# SIMILAR-2TERMS, clean term ARCHIT, two_next_terms P, check True
# SIMILAR-TERMS, clean term ARCHIT, next_term ARCHITECTURE, similarity 0.6666666666666666,  len def1 6595, check1 False, check 2  1.000000uture similarity 0.0, two_next_term P
# SIMILAR-2TERMS, clean term ARCHIT, two_next_terms P, check True
# SIMILAR-TERMS, clean term ARCHIT, next_term ARCHIT, similarity 1.0,  len def1 6609, check1 False, check 2  1.000000uture similarity 0.0, two_next_term P
# SIMILAR-2TERMS, clean term ARCHIT, two_next_terms P, check True
# SIMILAR-TERMS, clean term ARCHIT, next_term ARCHITECTURE, similarity 0.6666666666666666,  len def1 6439, check1 False, check 2  1.000000uture similarity 0.0, two_next_term P
# SIMILAR-2TERMS, clean term ARCHIT, two_next_terms P, check True
# SIMILAR-TERMS, clean term ARCHIT, next_term PII, similarity 0.2222222222222222,  len def1 5979, check1 True, check 2  0.000000uture similarity 0.6666666666666666, two_next_term ARCHITECTURE
# SIMILAR-TERMS, clean term ARCHIT, next_term ARCHITECTURE, similarity 0.6666666666666666,  len def1 7168, check1 False, check 2  1.000000uture similarity 0.2222222222222222, two_next_term PII
# SIMILAR-2TERMS, clean term ARCHIT, two_next_terms PII, check True
# SIMILAR-TERMS, clean term ARCHIT, next_term ARCHITECTURE, similarity 0.6666666666666666,  len def1 6996, check1 False, check 2  1.000000uture similarity 0.2222222222222222, two_next_term PII
# SIMILAR-2TERMS, clean term ARCHIT, two_next_terms PII, check True
# SIMILAR-TERMS, clean term ARCHIT, next_term ARCHITECTURE, similarity 0.6666666666666666,  len def1 4879, check1 False, check 2  1.000000uture similarity 0.2222222222222222, two_next_term PII
# SIMILAR-2TERMS, clean term ARCHIT, two_next_terms PII, check True
# SIMILAR-TERMS, clean term ARCHIT, next_term ARCHITECTURE, similarity 0.6666666666666666,  len def1 6973, check1 False, check 2  1.000000uture similarity 0.2222222222222222, two_next_term PII
# SIMILAR-2TERMS, clean term ARCHIT, two_next_terms PII, check True
# SIMILAR-TERMS, clean term ARCHIT, next_term ARCHIT, similarity 1.0,  len def1 6965, check1 False, check 2  0.000000uture similarity 0.631578947368421, two_next_term ARCHITALASSUS
# SIMILAR-TERMS, clean term ARCHIT, next_term ARCHITALASSUS, similarity 0.631578947368421,  len def1 64, check1 False, check 2  0.000000uture similarity 0.75, two_next_term ARCHITRAVE
# SIMILAR-2TERMS, clean term ARCHIT, two_next_terms ARCHITRAVE, check False
# SIMILAR-TERMS, clean term ARCHIT, next_term ARCHIVAULT, similarity 0.75,  len def1 324, check1 False, check 2  0.000000uture similarity 0.7692307692307693, two_next_term ARCHIVE
# SIMILAR-2TERMS, clean term ARCHIT, two_next_terms ARCHIVE, check False
# PASANDO AL SIGUIENTE: clean_term ARCHIT, next_term ARCHMARSHAL, two_next_terms ARCHONS
# STUDYING ARITH at 762
# SIMILAR-TERMS, clean term ARITH, next_term C, similarity 0.0,  len def1 6737, check1 True, check 2  0.000000uture similarity 0.6666666666666666, two_next_term ARITHMETIC
# SIMILAR-TERMS, clean term ARITH, next_term ARITHMETIC, similarity 0.6666666666666666,  len def1 5871, check1 False, check 2  1.000000uture similarity 0.0, two_next_term C
# SIMILAR-2TERMS, clean term ARITH, two_next_terms C, check True
# SIMILAR-TERMS, clean term ARITH, next_term ARITHMETIC, similarity 0.6666666666666666,  len def1 5022, check1 False, check 2  1.000000uture similarity 0.0, two_next_term C
# SIMILAR-2TERMS, clean term ARITH, two_next_terms C, check True
# SIMILAR-TERMS, clean term ARITH, next_term ARITH, similarity 1.0,  len def1 4097, check1 False, check 2  1.000000uture similarity 0.0, two_next_term C
# SIMILAR-2TERMS, clean term ARITH, two_next_terms C, check True
# SIMILAR-TERMS, clean term ARITH, next_term ARITH, similarity 1.0,  len def1 4720, check1 False, check 2  1.000000uture similarity 0.0, two_next_term C
# SIMILAR-2TERMS, clean term ARITH, two_next_terms C, check True
# SIMILAR-TERMS, clean term ARITH, next_term ARITH, similarity 1.0,  len def1 3638, check1 False, check 2  1.000000uture similarity 0.0, two_next_term C
# SIMILAR-2TERMS, clean term ARITH, two_next_terms C, check True
# SIMILAR-TERMS, clean term ARITH, next_term ARITH, similarity 1.0,  len def1 4610, check1 False, check 2  1.000000uture similarity 0.3333333333333333, two_next_term I
# SIMILAR-2TERMS, clean term ARITH, two_next_terms I, check True
# SIMILAR-TERMS, clean term ARITH, next_term ARITH, similarity 1.0,  len def1 5171, check1 False, check 2  0.000000uture similarity 0.0, two_next_term 754314
# PASANDO AL SIGUIENTE: clean_term ARITH, next_term 754314, two_next_terms 6684856
# STUDYING 6684856 at 778
# SIMILAR-TERMS, clean term 6684856, next_term C, similarity 0.0,  len def1 4631, check1 True, check 2  0.000000uture similarity 0.0, two_next_term ARITHMETIC
# SIMILAR-TERMS, clean term 6684856, next_term ARITHMETIC, similarity 0.0,  len def1 3780, check1 False, check 2  1.000000uture similarity 0.0, two_next_term C
# SIMILAR-2TERMS, clean term 6684856, two_next_terms C, check True
# SIMILAR-TERMS, clean term 6684856, next_term ARITHMETIC, similarity 0.0,  len def1 5268, check1 False, check 2  1.000000uture similarity 0.0, two_next_term C
# SIMILAR-2TERMS, clean term 6684856, two_next_terms C, check True
# PASANDO AL SIGUIENTE: clean_term 6684856, next_term TZTT, two_next_terms 2X7=21
# STUDYING ARITHARITH at 788
# SIMILAR-TERMS, clean term ARITHARITH, next_term C, similarity 0.0,  len def1 5569, check1 True, check 2  1.000000uture similarity 0.0, two_next_term _
# SIMILAR-2TERMS, clean term ARITHARITH, two_next_terms _, check True
# SIMILAR-TERMS, clean term ARITHARITH, next_term C, similarity 0.0,  len def1 5167, check1 True, check 2  0.000000uture similarity 0.6, two_next_term ARITHMETIC
# SIMILAR-TERMS, clean term ARITHARITH, next_term ARITHMETIC, similarity 0.6,  len def1 5749, check1 False, check 2  1.000000uture similarity 0.0, two_next_term C
# SIMILAR-2TERMS, clean term ARITHARITH, two_next_terms C, check True
# SIMILAR-TERMS, clean term ARITHARITH, next_term _, similarity 0.0,  len def1 3579, check1 True, check 2  1.000000uture similarity 0.0, two_next_term C
# SIMILAR-2TERMS, clean term ARITHARITH, two_next_terms C, check True
# SIMILAR-TERMS, clean term ARITHARITH, next_term ARITHMETIC, similarity 0.6,  len def1 3619, check1 False, check 2  1.000000uture similarity 0.0, two_next_term C
# SIMILAR-2TERMS, clean term ARITHARITH, two_next_terms C, check True
# SIMILAR-TERMS, clean term ARITHARITH, next_term ARIUS, similarity 0.4,  len def1 11, check1 False, check 2  0.000000uture similarity 0.3076923076923077, two_next_term ARK
# SIMILAR-2TERMS, clean term ARITHARITH, two_next_terms ARK, check False
# PASANDO AL SIGUIENTE: clean_term ARITHARITH, next_term ARLES, two_next_terms ARLEUX
# STUDYING ARTBC at 824
# SIMILAR-TERMS, clean term ARTBC, next_term ART, similarity 0.75,  len def1 565, check1 False, check 2  0.000000uture similarity 0.5714285714285714, two_next_term ARTABANUS
# PASANDO AL SIGUIENTE: clean_term ARTBC, next_term ARTABANUS, two_next_terms ARTABAZUS
# STUDYING SHISSHI at 81
# SIMILAR-TERMS, clean term SHISSHI, next_term S, similarity 0.25,  len def1 5777, check1 True, check 2  1.000000uture similarity 0.0, two_next_term _
# SIMILAR-2TERMS, clean term SHISSHI, two_next_terms _, check True
# SIMILAR-TERMS, clean term SHISSHI, next_term YCCLXV, similarity 0.0,  len def1 246, check1 False, check 2  0.000000uture similarity 0.4, two_next_term HIP
# SIMILAR-2TERMS, clean term SHISSHI, two_next_terms HIP, check False
# PASANDO AL SIGUIENTE: clean_term SHISSHI, next_term ILDING, two_next_terms SHIPBUILDING
# STUDYING SHIPBUILDING at 96
# SIMILAR-TERMS, clean term SHIPBUILDING, next_term P, similarity 0.15384615384615385,  len def1 7007, check1 True, check 2  0.000000uture similarity 0.14285714285714285, two_next_term BC
# SIMILAR-2TERMS, clean term SHIPBUILDING, two_next_terms BC, check False
# SIMILAR-TERMS, clean term SHIPBUILDING, next_term XX, similarity 0.0,  len def1 1013, check1 True, check 2  0.000000uture similarity 0.26666666666666666, two_next_term BAG
# SIMILAR-2TERMS, clean term SHIPBUILDING, two_next_terms BAG, check False
# SIMILAR-TERMS, clean term SHIPBUILDING, next_term BAG, similarity 0.26666666666666666,  len def1 1, check1 False, check 2  0.000000uture similarity 0.7, two_next_term SHIPPING
# SIMILAR-TERMS, clean term SHIPBUILDING, next_term SHIPPING, similarity 0.7,  len def1 17, check1 False, check 2  0.000000uture similarity 0.35294117647058826, two_next_term SHIRE
# PASANDO AL SIGUIENTE: clean_term SHIPBUILDING, next_term SHIRE, two_next_terms SHIRLEY
# STUDYING CCLXXI at 155
# SIMILAR-TERMS, clean term CCLXXI, next_term ‘T', similarity 0.0,  len def1 256, check1 False, check 2  0.000000uture similarity 0.13333333333333333, two_next_term SMOLENSKO
# PASANDO AL SIGUIENTE: clean_term CCLXXI, next_term SMOLENSKO, two_next_terms SMOLLET
# STUDYING SS at 183
# PASANDO AL SIGUIENTE: clean_term SS, next_term SOUTHWARK, two_next_terms SOWING
# STUDYING SPASPARS at 186
# SIMILAR-TERMS, clean term SPASPARS, next_term “AH, similarity 0.18181818181818182,  len def1 11269, check1 False, check 2  0.000000uture similarity 0.18181818181818182, two_next_term IPS
# SIMILAR-2TERMS, clean term SPASPARS, two_next_terms IPS, check False
# PASANDO AL SIGUIENTE: clean_term SPASPARS, next_term SPAN, two_next_terms SPANHEIM
# STUDYING STENOGRAPHY at 258
# SIMILAR-TERMS, clean term STENOGRAPHY, next_term STENOGRAPHY, similarity 1.0,  len def1 6756, check1 False, check 2  0.000000uture similarity 0.5555555555555556, two_next_term STEPHEN
# PASANDO AL SIGUIENTE: clean_term STENOGRAPHY, next_term STEPHEN, two_next_terms STEPHENS
# STUDYING STRATAGEM at 287
# PASANDO AL SIGUIENTE: clean_term STRATAGEM, next_term STRATH, two_next_terms STRATHNAVER
# STUDYING STUDDING at 298
# PASANDO AL SIGUIENTE: clean_term STUDDING, next_term STUFF, two_next_terms STUICELY
# STUDYING SURGERY at 316
# SIMILAR-TERMS, clean term SURGERY, next_term PI, similarity 0.0,  len def1 6982, check1 True, check 2  0.000000uture similarity 1.0, two_next_term SURGERY
# SIMILAR-2TERMS, clean term SURGERY, two_next_terms SURGERY, check False
# SIMILAR-TERMS, clean term SURGERY, next_term P, similarity 0.0,  len def1 6629, check1 True, check 2  0.000000uture similarity 0.7692307692307693, two_next_term URCERY
# SIMILAR-2TERMS, clean term SURGERY, two_next_terms URCERY, check False
# SIMILAR-TERMS, clean term SURGERY, next_term PII, similarity 0.0,  len def1 7146, check1 True, check 2  0.000000uture similarity 1.0, two_next_term SURGERY
# SIMILAR-2TERMS, clean term SURGERY, two_next_terms SURGERY, check False
# SIMILAR-TERMS, clean term SURGERY, next_term PII, similarity 0.0,  len def1 14085, check1 True, check 2  1.000000uture similarity 0.0, two_next_term PII
# SIMILAR-2TERMS, clean term SURGERY, two_next_terms PII, check True
# SIMILAR-TERMS, clean term SURGERY, next_term SURGERY, similarity 1.0,  len def1 7098, check1 False, check 2  1.000000uture similarity 0.0, two_next_term PII
# SIMILAR-2TERMS, clean term SURGERY, two_next_terms PII, check True
# SIMILAR-TERMS, clean term SURGERY, next_term SURGERY, similarity 1.0,  len def1 6964, check1 False, check 2  0.000000uture similarity 0.0, two_next_term PIT
# SIMILAR-2TERMS, clean term SURGERY, two_next_terms PIT, check False
# SIMILAR-TERMS, clean term SURGERY, next_term SURGERY, similarity 1.0,  len def1 6854, check1 False, check 2  0.000000uture similarity 0.0, two_next_term OPII
# SIMILAR-TERMS, clean term SURGERY, next_term OPII, similarity 0.0,  len def1 6973, check1 False, check 2  0.000000uture similarity 0.8571428571428571, two_next_term SURCERY
# SIMILAR-2TERMS, clean term SURGERY, two_next_terms SURCERY, check False
# SIMILAR-TERMS, clean term SURGERY, next_term PII, similarity 0.0,  len def1 6837, check1 True, check 2  0.000000uture similarity 0.6, two_next_term SRG
# SIMILAR-2TERMS, clean term SURGERY, two_next_terms SRG, check False
# SIMILAR-TERMS, clean term SURGERY, next_term PII, similarity 0.0,  len def1 6834, check1 True, check 2  0.000000uture similarity 0.36363636363636365, two_next_term SUIP
# SIMILAR-TERMS, clean term SURGERY, next_term SUIP, similarity 0.36363636363636365,  len def1 6908, check1 False, check 2  1.000000uture similarity 0.0, two_next_term PII
# SIMILAR-2TERMS, clean term SURGERY, two_next_terms PII, check True
# SIMILAR-TERMS, clean term SURGERY, next_term T, similarity 0.0,  len def1 6942, check1 False, check 2  1.000000uture similarity 0.0, two_next_term PII
# SIMILAR-2TERMS, clean term SURGERY, two_next_terms PII, check True
# SIMILAR-TERMS, clean term SURGERY, next_term SURGRY, similarity 0.9230769230769231,  len def1 6929, check1 False, check 2  1.000000uture similarity 0.0, two_next_term
# SIMILAR-2TERMS, clean term SURGERY, two_next_terms , check True
# SIMILAR-TERMS, clean term SURGERY, next_term SURGERY, similarity 1.0,  len def1 6759, check1 False, check 2  1.000000uture similarity 0.0, two_next_term PII
# SIMILAR-2TERMS, clean term SURGERY, two_next_terms PII, check True
# SIMILAR-TERMS, clean term SURGERY, next_term SURGERY, similarity 1.0,  len def1 7043, check1 False, check 2  0.000000uture similarity 0.8235294117647058, two_next_term PIISURGERY
# SIMILAR-2TERMS, clean term SURGERY, two_next_terms PIISURGERY, check False
# SIMILAR-TERMS, clean term SURGERY, next_term SURGERY, similarity 1.0,  len def1 6872, check1 False, check 2  1.000000uture similarity 0.0, two_next_term PII
# SIMILAR-2TERMS, clean term SURGERY, two_next_terms PII, check True
# SIMILAR-TERMS, clean term SURGERY, next_term SURGER, similarity 0.9230769230769231,  len def1 6838, check1 False, check 2  1.000000uture similarity 0.0, two_next_term PII
# SIMILAR-2TERMS, clean term SURGERY, two_next_terms PII, check True
# SIMILAR-TERMS, clean term SURGERY, next_term SURGERY, similarity 1.0,  len def1 7091, check1 False, check 2  1.000000uture similarity 0.0, two_next_term PII
# SIMILAR-2TERMS, clean term SURGERY, two_next_terms PII, check True
# PASANDO AL SIGUIENTE: clean_term SURGERY, next_term 0372, two_next_terms IPII
# STUDYING IPII at 353
# SIMILAR-TERMS, clean term IPII, next_term SURERY, similarity 0.0,  len def1 7073, check1 False, check 2  1.000000uture similarity 0.8571428571428571, two_next_term PII
# SIMILAR-2TERMS, clean term IPII, two_next_terms PII, check True
# SIMILAR-TERMS, clean term IPII, next_term _, similarity 0.0,  len def1 6618, check1 True, check 2  1.000000uture similarity 0.8571428571428571, two_next_term PII
# SIMILAR-2TERMS, clean term IPII, two_next_terms PII, check True
# PASANDO AL SIGUIENTE: clean_term IPII, next_term SURERY, two_next_terms PILSURGERY
# STUDYING PILSURGERY at 359
# SIMILAR-TERMS, clean term PILSURGERY, next_term SURGERY, similarity 0.8235294117647058,  len def1 6732, check1 False, check 2  0.000000uture similarity 0.3076923076923077, two_next_term PIT
# SIMILAR-2TERMS, clean term PILSURGERY, two_next_terms PIT, check False
# SIMILAR-TERMS, clean term PILSURGERY, next_term SSURGERY, similarity 0.7777777777777778,  len def1 6929, check1 False, check 2  1.000000uture similarity 0.3076923076923077, two_next_term PII
# SIMILAR-2TERMS, clean term PILSURGERY, two_next_terms PII, check True
# SIMILAR-TERMS, clean term PILSURGERY, next_term PII, similarity 0.3076923076923077,  len def1 6775, check1 True, check 2  0.000000uture similarity 0.8235294117647058, two_next_term SURGERY
# SIMILAR-2TERMS, clean term PILSURGERY, two_next_terms SURGERY, check False
# SIMILAR-TERMS, clean term PILSURGERY, next_term SURGERY, similarity 0.8235294117647058,  len def1 6798, check1 False, check 2  0.000000uture similarity 0.6666666666666666, two_next_term URGEY
# PASANDO AL SIGUIENTE: clean_term PILSURGERY, next_term URGEY, two_next_terms OIIT
# STUDYING OIIT at 369
# SIMILAR-TERMS, clean term OIIT, next_term SURGERY, similarity 0.0,  len def1 6692, check1 False, check 2  1.000000uture similarity 0.0, two_next_term
# SIMILAR-2TERMS, clean term OIIT, two_next_terms , check True
# PASANDO AL SIGUIENTE: clean_term OIIT, next_term STJRGRY, two_next_terms PITSURGERY
# STUDYING PITSURGERY at 373
# SIMILAR-TERMS, clean term PITSURGERY, next_term SURGERY, similarity 0.8235294117647058,  len def1 7040, check1 False, check 2  1.000000uture similarity 0.3076923076923077, two_next_term PII
# SIMILAR-2TERMS, clean term PITSURGERY, two_next_terms PII, check True
# SIMILAR-TERMS, clean term PITSURGERY, next_term SURCERY, similarity 0.7058823529411765,  len def1 6583, check1 False, check 2  1.000000uture similarity 0.18181818181818182, two_next_term P
# SIMILAR-2TERMS, clean term PITSURGERY, two_next_terms P, check True
# SIMILAR-TERMS, clean term PITSURGERY, next_term URCERY, similarity 0.625,  len def1 6812, check1 False, check 2  1.000000uture similarity 0.3076923076923077, two_next_term PII
# SIMILAR-2TERMS, clean term PITSURGERY, two_next_terms PII, check True
# SIMILAR-TERMS, clean term PITSURGERY, next_term SURGP, similarity 0.5333333333333333,  len def1 6788, check1 False, check 2  1.000000uture similarity 0.18181818181818182, two_next_term P
# SIMILAR-2TERMS, clean term PITSURGERY, two_next_terms P, check True
# SIMILAR-TERMS, clean term PITSURGERY, next_term SURGERY, similarity 0.8235294117647058,  len def1 6874, check1 False, check 2  1.000000uture similarity 0.2857142857142857, two_next_term PIII
# SIMILAR-2TERMS, clean term PITSURGERY, two_next_terms PIII, check True
# SIMILAR-TERMS, clean term PITSURGERY, next_term PIII, similarity 0.2857142857142857,  len def1 6704, check1 True, check 2  0.000000uture similarity 0.8235294117647058, two_next_term SURGERY
# SIMILAR-2TERMS, clean term PITSURGERY, two_next_terms SURGERY, check False
# SIMILAR-TERMS, clean term PITSURGERY, next_term PIII, similarity 0.2857142857142857,  len def1 6864, check1 True, check 2  0.000000uture similarity 0.625, two_next_term URGEIY
# SIMILAR-TERMS, clean term PITSURGERY, next_term URGEIY, similarity 0.625,  len def1 6523, check1 False, check 2  1.000000uture similarity 0.2857142857142857, two_next_term PIII
# SIMILAR-2TERMS, clean term PITSURGERY, two_next_terms PIII, check True
# SIMILAR-TERMS, clean term PITSURGERY, next_term SURGERY, similarity 0.8235294117647058,  len def1 6983, check1 False, check 2  0.000000uture similarity 0.16666666666666666, two_next_term HI
# SIMILAR-2TERMS, clean term PITSURGERY, two_next_terms HI, check False
# SIMILAR-TERMS, clean term PITSURGERY, next_term SERY, similarity 0.5714285714285714,  len def1 6314, check1 False, check 2  1.000000uture similarity 0.18181818181818182, two_next_term P
# SIMILAR-2TERMS, clean term PITSURGERY, two_next_terms P, check True
# SIMILAR-TERMS, clean term PITSURGERY, next_term SURGERY, similarity 0.8235294117647058,  len def1 6680, check1 False, check 2  1.000000uture similarity 0.2857142857142857, two_next_term PIII
# SIMILAR-2TERMS, clean term PITSURGERY, two_next_terms PIII, check True
# SIMILAR-TERMS, clean term PITSURGERY, next_term _, similarity 0.0,  len def1 6391, check1 True, check 2  1.000000uture similarity 0.2857142857142857, two_next_term PIII
# SIMILAR-2TERMS, clean term PITSURGERY, two_next_terms PIII, check True
# SIMILAR-TERMS, clean term PITSURGERY, next_term SURIJERY, similarity 0.6666666666666666,  len def1 6772, check1 False, check 2  1.000000uture similarity 0.2857142857142857, two_next_term PIII
# SIMILAR-2TERMS, clean term PITSURGERY, two_next_terms PIII, check True
# SIMILAR-TERMS, clean term PITSURGERY, next_term PIII, similarity 0.2857142857142857,  len def1 6909, check1 True, check 2  1.000000uture similarity 0.0, two_next_term _
# SIMILAR-2TERMS, clean term PITSURGERY, two_next_terms _, check True
# SIMILAR-TERMS, clean term PITSURGERY, next_term PIII, similarity 0.2857142857142857,  len def1 6759, check1 True, check 2  0.000000uture similarity 0.7058823529411765, two_next_term SURCERY
# SIMILAR-2TERMS, clean term PITSURGERY, two_next_terms SURCERY, check False
# SIMILAR-TERMS, clean term PITSURGERY, next_term SURERY, similarity 0.75,  len def1 6925, check1 False, check 2  1.000000uture similarity 0.2857142857142857, two_next_term PIII
# SIMILAR-2TERMS, clean term PITSURGERY, two_next_terms PIII, check True
# SIMILAR-TERMS, clean term PITSURGERY, next_term SURGERY, similarity 0.8235294117647058,  len def1 6381, check1 False, check 2  1.000000uture similarity 0.2857142857142857, two_next_term PIII
# SIMILAR-2TERMS, clean term PITSURGERY, two_next_terms PIII, check True
# SIMILAR-TERMS, clean term PITSURGERY, next_term SURGERY, similarity 0.8235294117647058,  len def1 6398, check1 False, check 2  1.000000uture similarity 0.2857142857142857, two_next_term PIII
# SIMILAR-2TERMS, clean term PITSURGERY, two_next_terms PIII, check True
# SIMILAR-TERMS, clean term PITSURGERY, next_term _, similarity 0.0,  len def1 6810, check1 True, check 2  1.000000uture similarity 0.2857142857142857, two_next_term PIII
# SIMILAR-2TERMS, clean term PITSURGERY, two_next_terms PIII, check True
# SIMILAR-TERMS, clean term PITSURGERY, next_term SURGERY, similarity 0.8235294117647058,  len def1 6844, check1 False, check 2  1.000000uture similarity 0.18181818181818182, two_next_term P
# SIMILAR-2TERMS, clean term PITSURGERY, two_next_terms P, check True
# SIMILAR-TERMS, clean term PITSURGERY, next_term SURGERY, similarity 0.8235294117647058,  len def1 6779, check1 False, check 2  1.000000uture similarity 0.2857142857142857, two_next_term PIII
# SIMILAR-2TERMS, clean term PITSURGERY, two_next_terms PIII, check True
# SIMILAR-TERMS, clean term PITSURGERY, next_term OH, similarity 0.0,  len def1 6865, check1 False, check 2  1.000000uture similarity 0.18181818181818182, two_next_term P
# SIMILAR-2TERMS, clean term PITSURGERY, two_next_terms P, check True
# SIMILAR-TERMS, clean term PITSURGERY, next_term SURGERY, similarity 0.8235294117647058,  len def1 6720, check1 False, check 2  1.000000uture similarity 0.18181818181818182, two_next_term P
# SIMILAR-2TERMS, clean term PITSURGERY, two_next_terms P, check True
# SIMILAR-TERMS, clean term PITSURGERY, next_term _, similarity 0.0,  len def1 6641, check1 True, check 2  0.000000uture similarity 0.3076923076923077, two_next_term PHI
# SIMILAR-2TERMS, clean term PITSURGERY, two_next_terms PHI, check False
# SIMILAR-TERMS, clean term PITSURGERY, next_term SURGERY, similarity 0.8235294117647058,  len def1 6859, check1 False, check 2  0.000000uture similarity 0.3076923076923077, two_next_term PHI
# SIMILAR-2TERMS, clean term PITSURGERY, two_next_terms PHI, check False
# SIMILAR-TERMS, clean term PITSURGERY, next_term _, similarity 0.0,  len def1 6610, check1 True, check 2  1.000000uture similarity 0.2857142857142857, two_next_term PIII
# SIMILAR-2TERMS, clean term PITSURGERY, two_next_terms PIII, check True
# SIMILAR-TERMS, clean term PITSURGERY, next_term SURGERY, similarity 0.8235294117647058,  len def1 6728, check1 False, check 2  0.000000uture similarity 0.3076923076923077, two_next_term PHI
# SIMILAR-2TERMS, clean term PITSURGERY, two_next_terms PHI, check False
# SIMILAR-TERMS, clean term PITSURGERY, next_term SURGERY, similarity 0.8235294117647058,  len def1 6955, check1 False, check 2  0.000000uture similarity 0.8888888888888888, two_next_term PSURGERY
# SIMILAR-2TERMS, clean term PITSURGERY, two_next_terms PSURGERY, check False
# SIMILAR-TERMS, clean term PITSURGERY, next_term URRY, similarity 0.5714285714285714,  len def1 6952, check1 False, check 2  1.000000uture similarity 0.2857142857142857, two_next_term PIII
# SIMILAR-2TERMS, clean term PITSURGERY, two_next_terms PIII, check True
# SIMILAR-TERMS, clean term PITSURGERY, next_term BSURGERYPIII, similarity 0.6363636363636364,  len def1 7072, check1 False, check 2  1.000000uture similarity 0.2857142857142857, two_next_term PIII
# SIMILAR-2TERMS, clean term PITSURGERY, two_next_terms PIII, check True
# SIMILAR-TERMS, clean term PITSURGERY, next_term SURCERY, similarity 0.7058823529411765,  len def1 6886, check1 False, check 2  0.000000uture similarity 0.7619047619047619, two_next_term FIIISURGERY
# SIMILAR-2TERMS, clean term PITSURGERY, two_next_terms FIIISURGERY, check False
# SIMILAR-TERMS, clean term PITSURGERY, next_term SURGERY, similarity 0.8235294117647058,  len def1 6625, check1 False, check 2  1.000000uture similarity 0.2857142857142857, two_next_term PIII
# SIMILAR-2TERMS, clean term PITSURGERY, two_next_terms PIII, check True
# SIMILAR-TERMS, clean term PITSURGERY, next_term _, similarity 0.0,  len def1 6317, check1 True, check 2  0.000000uture similarity 0.14285714285714285, two_next_term FIII
# SIMILAR-TERMS, clean term PITSURGERY, next_term FIII, similarity 0.14285714285714285,  len def1 6208, check1 False, check 2  0.000000uture similarity 0.8235294117647058, two_next_term SURGERY
# SIMILAR-2TERMS, clean term PITSURGERY, two_next_terms SURGERY, check False
# PASANDO AL SIGUIENTE: clean_term PITSURGERY, next_term SURINAM, two_next_terms SURMOUNTED
# STUDYING SWESWE at 477
# SIMILAR-TERMS, clean term SWESWE, next_term 80, similarity 0.0,  len def1 6868, check1 False, check 2  0.000000uture similarity 0.7272727272727273, two_next_term SWEEP
# SIMILAR-2TERMS, clean term SWESWE, two_next_terms SWEEP, check False
# SIMILAR-TERMS, clean term SWESWE, next_term SWEET, similarity 0.7272727272727273,  len def1 213, check1 False, check 2  0.000000uture similarity 0.36363636363636365, two_next_term SWIFT
# PASANDO AL SIGUIENTE: clean_term SWESWE, next_term SWIFT, two_next_terms 17I3>
# STUDYING first_article at 574
# SIMILAR-TERMS, clean term _, next_term S, similarity 0.0,  len def1 6863, check1 True, check 2  0.000000uture similarity 0.0, two_next_term BSTHEO
# SIMILAR-TERMS, clean term _, next_term BSTHEO, similarity 0.0,  len def1 6696, check1 False, check 2  1.000000uture similarity 0.0, two_next_term S
# SIMILAR-2TERMS, clean term _, two_next_terms S, check True
# SIMILAR-TERMS, clean term _, next_term THEOLOGY, similarity 0.0,  len def1 6754, check1 False, check 2  1.000000uture similarity 0.0, two_next_term S
# SIMILAR-2TERMS, clean term _, two_next_terms S, check True
# PASANDO AL SIGUIENTE: clean_term _, next_term THEOPHILUS, two_next_terms THEOPHRASTUS
# STUDYING T at 618
# PASANDO AL SIGUIENTE: clean_term T, next_term TITHING, two_next_terms TITHONUS
# STUDYING TRICON at 651
# SIMILAR-TERMS, clean term TRICON, next_term ABC, similarity 0.2222222222222222,  len def1 25, check1 False, check 2  0.000000uture similarity 0.0, two_next_term AB—156
# SIMILAR-TERMS, clean term TRICON, next_term AB—156, similarity 0.0,  len def1 1323, check1 False, check 2  0.000000uture similarity 0.2222222222222222, two_next_term DBC
# SIMILAR-2TERMS, clean term TRICON, two_next_terms DBC, check False
# PASANDO AL SIGUIENTE: clean_term TRICON, next_term EDAFG, two_next_terms EDFG
# STUDYING TRICONOMETRY at 653
# SIMILAR-TERMS, clean term TRICONOMETRY, next_term ACB, similarity 0.13333333333333333,  len def1 231, check1 False, check 2  0.000000uture similarity 0.13333333333333333, two_next_term ACB
# SIMILAR-2TERMS, clean term TRICONOMETRY, two_next_terms ACB, check False
# SIMILAR-TERMS, clean term TRICONOMETRY, next_term TRIM, similarity 0.5,  len def1 3, check1 False, check 2  0.000000uture similarity 0.3333333333333333, two_next_term TR1NGA
# PASANDO AL SIGUIENTE: clean_term TRICONOMETRY, next_term TR1NGA, two_next_terms TRINIDAD
# STUDYING ! at 779
# SIMILAR-TERMS, clean term !, next_term WAR, similarity 0.0,  len def1 6248, check1 False, check 2  1.000000uture similarity 0.0, two_next_term PI
# SIMILAR-2TERMS, clean term !, two_next_terms PI, check True
# SIMILAR-TERMS, clean term !, next_term WAR, similarity 0.0,  len def1 12750, check1 False, check 2  0.000000uture similarity 0.0, two_next_term AR
# SIMILAR-2TERMS, clean term !, two_next_terms AR, check False
# SIMILAR-TERMS, clean term !, next_term PI, similarity 0.0,  len def1 13511, check1 True, check 2  1.000000uture similarity 0.0, two_next_term PI
# SIMILAR-2TERMS, clean term !, two_next_terms PI, check True
# SIMILAR-TERMS, clean term !, next_term I, similarity 0.0,  len def1 13485, check1 True, check 2  1.000000uture similarity 0.0, two_next_term PI
# SIMILAR-2TERMS, clean term !, two_next_terms PI, check True
# SIMILAR-TERMS, clean term !, next_term R, similarity 0.0,  len def1 6725, check1 False, check 2  1.000000uture similarity 0.0, two_next_term
# SIMILAR-2TERMS, clean term !, two_next_terms , check True
# SIMILAR-TERMS, clean term !, next_term PI, similarity 0.0,  len def1 6640, check1 True, check 2  0.000000uture similarity 0.0, two_next_term WAR
# SIMILAR-2TERMS, clean term !, two_next_terms WAR, check False
# SIMILAR-TERMS, clean term !, next_term PI, similarity 0.0,  len def1 6785, check1 True, check 2  0.000000uture similarity 0.0, two_next_term SWAR
# SIMILAR-TERMS, clean term !, next_term SWAR, similarity 0.0,  len def1 13044, check1 False, check 2  0.000000uture similarity 0.0, two_next_term WAR
# SIMILAR-2TERMS, clean term !, two_next_terms WAR, check False
# SIMILAR-TERMS, clean term !, next_term PII, similarity 0.0,  len def1 6726, check1 True, check 2  0.000000uture similarity 0.0, two_next_term SVAR
# SIMILAR-TERMS, clean term !, next_term SVAR, similarity 0.0,  len def1 6640, check1 False, check 2  1.000000uture similarity 0.0, two_next_term PII
# SIMILAR-2TERMS, clean term !, two_next_terms PII, check True
# SIMILAR-TERMS, clean term !, next_term WAR, similarity 0.0,  len def1 6928, check1 False, check 2  1.000000uture similarity 0.0, two_next_term PII
# SIMILAR-2TERMS, clean term !, two_next_terms PII, check True
# SIMILAR-TERMS, clean term !, next_term II, similarity 0.0,  len def1 13386, check1 True, check 2  1.000000uture similarity 0.0, two_next_term PII
# SIMILAR-2TERMS, clean term !, two_next_terms PII, check True
# SIMILAR-TERMS, clean term !, next_term WAT, similarity 0.0,  len def1 6689, check1 False, check 2  1.000000uture similarity 0.0, two_next_term PII
# SIMILAR-2TERMS, clean term !, two_next_terms PII, check True
# SIMILAR-TERMS, clean term !, next_term WAR, similarity 0.0,  len def1 6926, check1 False, check 2  0.000000uture similarity 0.0, two_next_term IPII
# SIMILAR-TERMS, clean term !, next_term IPII, similarity 0.0,  len def1 6744, check1 False, check 2  0.000000uture similarity 0.0, two_next_term WAR
# SIMILAR-2TERMS, clean term !, two_next_terms WAR, check False
# SIMILAR-TERMS, clean term !, next_term PII, similarity 0.0,  len def1 13316, check1 True, check 2  1.000000uture similarity 0.0, two_next_term II
# SIMILAR-2TERMS, clean term !, two_next_terms II, check True
# SIMILAR-TERMS, clean term !, next_term II, similarity 0.0,  len def1 9, check1 True, check 2  1.000000uture similarity 0.0, two_next_term PII
# SIMILAR-2TERMS, clean term !, two_next_terms PII, check True
# ...
# SIMILAR-TERMS, clean term POETRY, next_term POETRY, similarity 1.0,  len def1 7017, check1 False, check 2  0.000000uture similarity 0.25, two_next_term PX
# SIMILAR-2TERMS, clean term POETRY, two_next_terms PX, check False
# SIMILAR-TERMS, clean term POETRY, next_term POETRY, similarity 1.0,  len def1 6824, check1 False, check 2  0.000000uture similarity 0.8571428571428571, two_next_term PLPOETRY
# SIMILAR-2TERMS, clean term POETRY, two_next_terms PLPOETRY, check False
# SIMILAR-TERMS, clean term POETRY, next_term POETRY, similarity 1.0,  len def1 6530, check1 False, check 2  0.000000uture similarity 1.0, two_next_term POETRY
# SIMILAR-2TERMS, clean term POETRY, two_next_terms POETRY, check False
# SIMILAR-TERMS, clean term POETRY, next_term POETRY, similarity 1.0,  len def1 5791, check1 False, check 2  1.000000uture similarity 0.2222222222222222, two_next_term PII
# SIMILAR-2TERMS, clean term POETRY, two_next_terms PII, check True
# SIMILAR-TERMS, clean term POETRY, next_term POETRY, similarity 1.0,  len def1 6894, check1 False, check 2  1.000000uture similarity 0.2222222222222222, two_next_term PII
# SIMILAR-2TERMS, clean term POETRY, two_next_terms PII, check True
# SIMILAR-TERMS, clean term POETRY, next_term PIIPOETRY, similarity 0.8,  len def1 6261, check1 False, check 2  0.000000uture similarity 1.0, two_next_term POETRY
# SIMILAR-2TERMS, clean term POETRY, two_next_terms POETRY, check False
# SIMILAR-TERMS, clean term POETRY, next_term PILPOETRY, similarity 0.8,  len def1 6753, check1 False, check 2  0.000000uture similarity 1.0, two_next_term POETRY
# SIMILAR-2TERMS, clean term POETRY, two_next_terms POETRY, check False
# SIMILAR-TERMS, clean term POETRY, next_term PII, similarity 0.2222222222222222,  len def1 6861, check1 True, check 2  0.000000uture similarity 1.0, two_next_term POETRY
# SIMILAR-2TERMS, clean term POETRY, two_next_terms POETRY, check False
# SIMILAR-TERMS, clean term POETRY, next_term PII, similarity 0.2222222222222222,  len def1 6776, check1 True, check 2  0.000000uture similarity 1.0, two_next_term POETRY
# SIMILAR-2TERMS, clean term POETRY, two_next_terms POETRY, check False
# SIMILAR-TERMS, clean term POETRY, next_term PII, similarity 0.2222222222222222,  len def1 5862, check1 True, check 2  0.000000uture similarity 0.6666666666666666, two_next_term TRY
# SIMILAR-2TERMS, clean term POETRY, two_next_terms TRY, check False
# SIMILAR-TERMS, clean term POETRY, next_term POETRY, similarity 1.0,  len def1 4993, check1 False, check 2  1.000000uture similarity 0.2222222222222222, two_next_term PII
# SIMILAR-2TERMS, clean term POETRY, two_next_terms PII, check True
# SIMILAR-TERMS, clean term POETRY, next_term TRY, similarity 0.6666666666666666,  len def1 5582, check1 False, check 2  0.000000uture similarity 0.8, two_next_term PILPOETRY
# SIMILAR-2TERMS, clean term POETRY, two_next_terms PILPOETRY, check False
# SIMILAR-TERMS, clean term POETRY, next_term POETRY, similarity 1.0,  len def1 5158, check1 False, check 2  0.000000uture similarity 0.5, two_next_term PIIPOE
# SIMILAR-TERMS, clean term POETRY, next_term PIIPOE, similarity 0.5,  len def1 5015, check1 False, check 2  0.000000uture similarity 0.6666666666666666, two_next_term TRY
# SIMILAR-2TERMS, clean term POETRY, two_next_terms TRY, check False
# SIMILAR-TERMS, clean term POETRY, next_term PII, similarity 0.2222222222222222,  len def1 4490, check1 True, check 2  0.000000uture similarity 0.7142857142857143, two_next_term POETYPII
# SIMILAR-2TERMS, clean term POETRY, two_next_terms POETYPII, check False
# SIMILAR-TERMS, clean term POETRY, next_term PII, similarity 0.2222222222222222,  len def1 5404, check1 True, check 2  0.000000uture similarity 1.0, two_next_term POETRY
# SIMILAR-2TERMS, clean term POETRY, two_next_terms POETRY, check False
# SIMILAR-TERMS, clean term POETRY, next_term PII, similarity 0.2222222222222222,  len def1 11571, check1 True, check 2  1.000000uture similarity 0.2222222222222222, two_next_term PII
# SIMILAR-2TERMS, clean term POETRY, two_next_terms PII, check True
# SIMILAR-TERMS, clean term POETRY, next_term (O, similarity 0.25,  len def1 5374, check1 False, check 2  0.000000uture similarity 0.8571428571428571, two_next_term PLPOETRY
# SIMILAR-2TERMS, clean term POETRY, two_next_terms PLPOETRY, check False
# SIMILAR-TERMS, clean term POETRY, next_term PETRY, similarity 0.9090909090909091,  len def1 6086, check1 False, check 2  1.000000uture similarity 0.25, two_next_term PI
# SIMILAR-2TERMS, clean term POETRY, two_next_terms PI, check True
# SIMILAR-TERMS, clean term POETRY, next_term POETRY, similarity 1.0,  len def1 6026, check1 False, check 2  1.000000uture similarity 0.2222222222222222, two_next_term PII
# SIMILAR-2TERMS, clean term POETRY, two_next_terms PII, check True
# SIMILAR-TERMS, clean term POETRY, next_term POETRY, similarity 1.0,  len def1 5671, check1 False, check 2  1.000000uture similarity 0.25, two_next_term PI
# SIMILAR-2TERMS, clean term POETRY, two_next_terms PI, check True
# SIMILAR-TERMS, clean term POETRY, next_term TRY, similarity 0.6666666666666666,  len def1 5459, check1 False, check 2  1.000000uture similarity 0.2222222222222222, two_next_term PII
# SIMILAR-2TERMS, clean term POETRY, two_next_terms PII, check True
# SIMILAR-TERMS, clean term POETRY, next_term PII, similarity 0.2222222222222222,  len def1 6616, check1 True, check 2  0.000000uture similarity 1.0, two_next_term POETRY
# SIMILAR-2TERMS, clean term POETRY, two_next_terms POETRY, check False
# SIMILAR-TERMS, clean term POETRY, next_term PIT, similarity 0.4444444444444444,  len def1 6219, check1 False, check 2  0.000000uture similarity 0.0, two_next_term 6330°
# SIMILAR-TERMS, clean term POETRY, next_term 6330°, similarity 0.0,  len def1 11092, check1 False, check 2  0.000000uture similarity 0.6666666666666666, two_next_term TRY
# SIMILAR-2TERMS, clean term POETRY, two_next_terms TRY, check False
# SIMILAR-TERMS, clean term POETRY, next_term POETRY, similarity 1.0,  len def1 4654, check1 False, check 2  0.000000uture similarity 1.0, two_next_term POETRY
# SIMILAR-2TERMS, clean term POETRY, two_next_terms POETRY, check False
# SIMILAR-TERMS, clean term POETRY, next_term PIII, similarity 0.2,  len def1 11546, check1 True, check 2  0.000000uture similarity 0.25, two_next_term PH
# SIMILAR-2TERMS, clean term POETRY, two_next_terms PH, check False
# SIMILAR-TERMS, clean term POETRY, next_term POETRY, similarity 1.0,  len def1 5552, check1 False, check 2  1.000000uture similarity 0.2857142857142857, two_next_term P
# SIMILAR-2TERMS, clean term POETRY, two_next_terms P, check True
# SIMILAR-TERMS, clean term POETRY, next_term PHI, similarity 0.2222222222222222,  len def1 5737, check1 False, check 2  0.000000uture similarity 1.0, two_next_term POETRY
# SIMILAR-2TERMS, clean term POETRY, two_next_terms POETRY, check False
# SIMILAR-TERMS, clean term POETRY, next_term PIII, similarity 0.2,  len def1 6804, check1 True, check 2  0.000000uture similarity 0.0, two_next_term 6344
# SIMILAR-TERMS, clean term POETRY, next_term 6344, similarity 0.0,  len def1 5180, check1 False, check 2  1.000000uture similarity 0.2, two_next_term PIII
# SIMILAR-2TERMS, clean term POETRY, two_next_terms PIII, check True
# SIMILAR-TERMS, clean term POETRY, next_term POETRY, similarity 1.0,  len def1 5471, check1 False, check 2  1.000000uture similarity 0.2, two_next_term PIII
# SIMILAR-2TERMS, clean term POETRY, two_next_terms PIII, check True
# SIMILAR-TERMS, clean term POETRY, next_term DPVLUM, similarity 0.16666666666666666,  len def1 786, check1 False, check 2  1.000000uture similarity 0.0, two_next_term
# SIMILAR-2TERMS, clean term POETRY, two_next_terms , check True
# STUDYING POR at 92
# PASANDO AL SIGUIENTE: clean_term POR, next_term PORTUGALLICA, two_next_terms PORTULACA
# STUDYING PROCESSION at 150
# SIMILAR-TERMS, clean term PROCESSION, next_term PROCHEIN, similarity 0.7777777777777778,  len def1 302, check1 False, check 2  0.000000uture similarity 0.6363636363636364, two_next_term PROCLAMATION
# PASANDO AL SIGUIENTE: clean_term PROCESSION, next_term PROCLAMATION, two_next_terms PROCLUS
# STUDYING PCCXLV at 196
# SIMILAR-TERMS, clean term PCCXLV, next_term MN, similarity 0.0,  len def1 726, check1 False, check 2  0.000000uture similarity 0.0, two_next_term SS
# SIMILAR-2TERMS, clean term PCCXLV, two_next_terms SS, check False
# SIMILAR-TERMS, clean term PCCXLV, next_term EFG, similarity 0.0,  len def1 151, check1 False, check 2  0.000000uture similarity 0.0, two_next_term HH
# SIMILAR-2TERMS, clean term PCCXLV, two_next_terms HH, check False
# PASANDO AL SIGUIENTE: clean_term PCCXLV, next_term ABCD, two_next_terms TYROTICCHISTY
# STUDYING TYROTICCHISTY at 203
# SIMILAR-TERMS, clean term TYROTICCHISTY, next_term PUN, similarity 0.0,  len def1 459, check1 False, check 2  0.000000uture similarity 0.2222222222222222, two_next_term PUNCH
# PASANDO AL SIGUIENTE: clean_term TYROTICCHISTY, next_term PUNCH, two_next_terms PUNCHEON
# STUDYING PYROT at 220
# SIMILAR-TERMS, clean term PYROT, next_term S, similarity 0.0,  len def1 5627, check1 True, check 2  0.000000uture similarity 0.6666666666666666, two_next_term PYROTECHNY
# SIMILAR-TERMS, clean term PYROT, next_term PYROTECHNY, similarity 0.6666666666666666,  len def1 6722, check1 False, check 2  1.000000uture similarity 0.0, two_next_term S
# SIMILAR-2TERMS, clean term PYROT, two_next_terms S, check True
# SIMILAR-TERMS, clean term PYROT, next_term PYROTECHNY, similarity 0.6666666666666666,  len def1 6424, check1 False, check 2  1.000000uture similarity 0.0, two_next_term S
# SIMILAR-2TERMS, clean term PYROT, two_next_terms S, check True
# SIMILAR-TERMS, clean term PYROT, next_term PYROTECHNY, similarity 0.6666666666666666,  len def1 6252, check1 False, check 2  1.000000uture similarity 0.0, two_next_term S
# SIMILAR-2TERMS, clean term PYROT, two_next_terms S, check True
# SIMILAR-TERMS, clean term PYROT, next_term PYROTECHNY, similarity 0.6666666666666666,  len def1 6458, check1 False, check 2  1.000000uture similarity 0.0, two_next_term S
# SIMILAR-2TERMS, clean term PYROT, two_next_terms S, check True
# SIMILAR-TERMS, clean term PYROT, next_term PYROT, similarity 1.0,  len def1 6687, check1 False, check 2  1.000000uture similarity 0.0, two_next_term S
# SIMILAR-2TERMS, clean term PYROT, two_next_terms S, check True
# PASANDO AL SIGUIENTE: clean_term PYROT, next_term PYROTECHNY, two_next_terms PYROTECHNY
# STUDYING PYROTECHNY at 233
# SIMILAR-TERMS, clean term PYROTECHNY, next_term PYROTECHNY, similarity 1.0,  len def1 6750, check1 False, check 2  1.000000uture similarity 0.0, two_next_term S
# SIMILAR-2TERMS, clean term PYROTECHNY, two_next_terms S, check True
# SIMILAR-TERMS, clean term PYROTECHNY, next_term PYROTECHMY, similarity 0.9,  len def1 6666, check1 False, check 2  1.000000uture similarity 0.0, two_next_term S
# SIMILAR-2TERMS, clean term PYROTECHNY, two_next_terms S, check True
# SIMILAR-TERMS, clean term PYROTECHNY, next_term PYROT, similarity 0.6666666666666666,  len def1 6795, check1 False, check 2  1.000000uture similarity 0.0, two_next_term S
# SIMILAR-2TERMS, clean term PYROTECHNY, two_next_terms S, check True
# SIMILAR-TERMS, clean term PYROTECHNY, next_term 6, similarity 0.0,  len def1 6764, check1 False, check 2  1.000000uture similarity 0.0, two_next_term S
# SIMILAR-2TERMS, clean term PYROTECHNY, two_next_terms S, check True
# SIMILAR-TERMS, clean term PYROTECHNY, next_term CCLJ, similarity 0.14285714285714285,  len def1 5937, check1 False, check 2  1.000000uture similarity 0.0, two_next_term S
# SIMILAR-2TERMS, clean term PYROTECHNY, two_next_terms S, check True
# SIMILAR-TERMS, clean term PYROTECHNY, next_term PYROTECHNY, similarity 1.0,  len def1 6257, check1 False, check 2  1.000000uture similarity 0.0, two_next_term S
# SIMILAR-2TERMS, clean term PYROTECHNY, two_next_terms S, check True
# SIMILAR-TERMS, clean term PYROTECHNY, next_term PYROTECHNY, similarity 1.0,  len def1 6419, check1 False, check 2  1.000000uture similarity 0.0, two_next_term
# SIMILAR-2TERMS, clean term PYROTECHNY, two_next_terms , check True
# SIMILAR-TERMS, clean term PYROTECHNY, next_term PYROTECHNY, similarity 1.0,  len def1 6928, check1 False, check 2  0.000000uture similarity 0.6666666666666666, two_next_term PYROTICS
# PASANDO AL SIGUIENTE: clean_term PYROTECHNY, next_term PYROTICS, two_next_terms PYRRHICHA
# STUDYING CCLV at 305
# SIMILAR-TERMS, clean term CCLV, next_term 1^B, similarity 0.0,  len def1 114, check1 False, check 2  1.000000uture similarity 0.0, two_next_term I
# SIMILAR-2TERMS, clean term CCLV, two_next_terms I, check True
# PASANDO AL SIGUIENTE: clean_term CCLV, next_term RAMUS, two_next_terms RANA
# STUDYING R at 310
# PASANDO AL SIGUIENTE: clean_term R, next_term RANCID, two_next_terms RANDOLPH
# STUDYING ROM at 459
# PASANDO AL SIGUIENTE: clean_term ROM, next_term ROMROM, two_next_terms ROMIROM
# STUDYING ROMIROM at 485
# SIMILAR-TERMS, clean term ROMIROM, next_term ROMROMTR, similarity 0.8,  len def1 13498, check1 False, check 2  0.000000uture similarity 0.0, two_next_term °U
# SIMILAR-2TERMS, clean term ROMIROM, two_next_terms °U, check False
# SIMILAR-TERMS, clean term ROMIROM, next_term CO, similarity 0.2222222222222222,  len def1 12916, check1 False, check 2  0.000000uture similarity 0.46153846153846156, two_next_term ROMNEY
# PASANDO AL SIGUIENTE: clean_term ROMIROM, next_term ROMNEY, two_next_terms ROMPEE
# STUDYING ROSR at 565
# SIMILAR-TERMS, clean term ROSR, next_term ROSA, similarity 0.75,  len def1 2090, check1 False, check 2  0.000000uture similarity 0.5454545454545454, two_next_term ROSACEA
# SIMILAR-TERMS, clean term ROSR, next_term ROSACEA, similarity 0.5454545454545454,  len def1 176, check1 False, check 2  0.000000uture similarity 0.8, two_next_term ROSARY
# SIMILAR-2TERMS, clean term ROSR, two_next_terms ROSARY, check False
# PASANDO AL SIGUIENTE: clean_term ROSR, next_term ROSBACH, two_next_terms ROSCHILD
# STUDYING SACRILEGE at 607
# PASANDO AL SIGUIENTE: clean_term SACRILEGE, next_term SACRISTAN, two_next_terms SACRISTY
# STUDYING TOCVDX at 612
# SIMILAR-TERMS, clean term TOCVDX, next_term SAILING, similarity 0.0,  len def1 6080, check1 False, check 2  1.000000uture similarity 0.0, two_next_term S
# SIMILAR-2TERMS, clean term TOCVDX, two_next_terms S, check True
# PASANDO AL SIGUIENTE: clean_term TOCVDX, next_term SAILOR, two_next_terms SAINT
# STUDYING PCCPXL at 673
# PASANDO AL SIGUIENTE: clean_term PCCPXL, next_term SCONE, two_next_terms SCOPER
# STUDYING ^W at 707
# SIMILAR-TERMS, clean term ^W, next_term W3S, similarity 0.4,  len def1 12792, check1 False, check 2  0.000000uture similarity 0.0, two_next_term 1U
# SIMILAR-2TERMS, clean term ^W, two_next_terms 1U, check False
# SIMILAR-TERMS, clean term ^W, next_term SCOSC, similarity 0.0,  len def1 13385, check1 False, check 2  0.000000uture similarity 0.0, two_next_term K’
# SIMILAR-2TERMS, clean term ^W, two_next_terms K’, check False
# SIMILAR-TERMS, clean term ^W, next_term 3I+, similarity 0.0,  len def1 6411, check1 False, check 2  0.000000uture similarity 0.0, two_next_term SEL
# SIMILAR-2TERMS, clean term ^W, two_next_terms SEL, check False
# SIMILAR-TERMS, clean term ^W, next_term SCO, similarity 0.0,  len def1 13509, check1 False, check 2  1.000000uture similarity 0.0, two_next_term S
# SIMILAR-2TERMS, clean term ^W, two_next_terms S, check True
# SIMILAR-TERMS, clean term ^W, next_term SCO, similarity 0.0,  len def1 13663, check1 False, check 2  0.000000uture similarity 0.0, two_next_term D
# SIMILAR-2TERMS, clean term ^W, two_next_terms D, check False
# PASANDO AL SIGUIENTE: clean_term ^W, next_term SCOSSSCO, two_next_terms SCOSSCORS
# STUDYING SCOSSCORS at 811
# SIMILAR-TERMS, clean term SCOSSCORS, next_term S, similarity 0.2,  len def1 13185, check1 True, check 2  0.000000uture similarity 0.75, two_next_term SCOSCOM
# SIMILAR-2TERMS, clean term SCOSSCORS, two_next_terms SCOSCOM, check False
# SIMILAR-TERMS, clean term SCOSSCORS, next_term (A), similarity 0.0,  len def1 7137, check1 False, check 2  0.000000uture similarity 0.0, two_next_term L_
# SIMILAR-2TERMS, clean term SCOSSCORS, two_next_terms L_, check False
# PASANDO AL SIGUIENTE: clean_term SCOSSCORS, next_term SCOTOMIA, two_next_terms SCOTT

# %%
#for ed in merged_topics:
#    for clean_term in merged_topics[ed]:
#         print("ED: %s, term %s, meged_topics %s" %(ed, clean_term,  merged_topics[ed][clean_term]))

# %%
#for ed in freq_topics_terms:
#    print("ED: %s, freq_topics_terms %s" %(ed, freq_topics_terms[ed]))

# %%
#for ed in provenance_removal:
#    print("ED: %s, provenance_removal %s" %(ed, provenance_removal[ed]))

# %% [markdown]
# #### 3.1 Merging topics even more
#
# Before, we were merging topics that were in consecutive pages. But very often we have other types of pages (with tables, figures) between the same topic. Therefore we are going to merge the pages with the same topics.

# %%
final_refine, provenance_removal_refine,merged_topics_refine =merge_topics_refine(topics_refined)

# %%
#for ed in merged_topics_refine:
#    print("ED: %s, meged_topics %s" %(ed, merged_topics_refine[ed]))

# %%
#for ed in provenance_removal_refine:
#    print("ED: %s, provenance_removal_refine %s" %(ed, provenance_removal_refine[ed]))

# %% [markdown]
# Once the data has been merged, we are going to store it in a file, just to have the data merged.

# %%
#write_query_results("results_eb_2_edition_updated_new", final_refine)

# %% [markdown]
# ### 2. Creating a dataframe from the updated results
#
# Once, we have the terms properly merged, we are going to create a dataframe, which we will be use later to do further exploration. In this dataframe we have dropped some information from the original defoe files, that we don not longer need.
#
# **The dataframe will have the following columns**
#
# - definition:           Definition of a term
# - editionNum:           1,2,3,4,5,6,7,8
# - editionTitle:         Title of the edition
# - header:               Header of the page's term
# - place:                Place where the volume was edited (e.g. Edinburgh)
# - relatedTerms:         Related terms (see X article)
# - altoXML:              File Path of the XML file from which the term belongs
# - term:                 Term name
# - positionPage:         Position of ther term in the page
# - startsAt:             Number page in which the term definition starts
# - endsAt:               Number page in which the term definition ends
# - volumeTitle:          Title of the Volume
# - typeTerm:             Type of term [Topic| Articles]
# - year:                 Year of the edition
# - volumeNum:            Volume number (e.g. 1)
# - letters:              leters of the volume (A-B)
# - part:                 Part of the volume (e.g 1)
# - supplementTitle:      Supplement's Title
# - supplementsTo:        It suppelements to editions [1, 2, 3....]
# - numberOfWords:        Number of words per term definition
# - numberOfTerms:        Number of terms per page
# - numberOfPages:        Number of pages per volume
# - numberOfVolumes:      Number of volumes per edition or supplement

# %% [markdown]
# ### IMPORTANT DECISIONs

# %% [markdown]
# 1. Going to convert all the MIX articles (inside the dataframe)
# 2. I am going to fiter OUT all the entries which are not Articles nor Topics.

# %%
#df=create_dataframe_from_file("results_eb_1_edition_updated")

# %%
df=create_dataframe(final_refine)

# %%
len(df)
# Out:
# 16684

# %%
df
# Out:
#            term                                         definition  \
# 0          ARTS
# 1      SCIENCES  &C. A A >. A THE charafter of the firftietter ...
# 2          AACH  a little town in Germany, in the circle of Sua...
# 3         AAHUS  a little town in Germany, in the circle of Wef...
# 4           AAM  a Dutch measure of capacity for liquids, conta...
# ...         ...                                                ...
# 16964    SCRUPI  in natural history, foffils formed into large ...
# 16965   SCRUPLE  a weight equal to the third part of a dram, or...
# 16966  SCRUTINY               a ftrift examination of any thing. .
# 16967  SCUDDING  the movement by which a (hip is carried precip...
# 16968   SCUDERY  (George de), a French writer of eminence in hi...
#
#       relatedTerms  header  startsAt  endsAt  numberOfTerms  numberOfWords  \
# 0               []      &C        15      15              7              0
# 1               []      &C        15      15              7            579
# 2               []      &C        15      15              7             54
# 3               []      &C        15      15              7             37
# 4               []      &C        15      15              7             13
# ...            ...     ...       ...     ...            ...            ...
# 16964           []  SCRSOU       867     867             10             19
# 16965           []  SCRSOU       867     867             10             13
# 16966           []  SCRSOU       867     867             10              7
# 16967           []  SCRSOU       867     867             10            271
# 16968           []  SCRSOU       867     868             10            237
#
#        numberOfPages  positionPage  ... editionNum supplementTitle  \
# 0                872             0  ...          2
# 1                872             0  ...          2
# 2                872             0  ...          2
# 3                872             0  ...          2
# 4                872             0  ...          2
# ...              ...           ...  ...        ...             ...
# 16964            874             5  ...          2
# 16965            874             6  ...          2
# 16966            874             7  ...          2
# 16967            874             8  ...          2
# 16968            874             9  ...          2
#
#        supplementsTo  year      place               volumeTitle volumeNum  \
# 0                 []  1778  Edinburgh  Encyclopaedia Britannica         1
# 1                 []  1778  Edinburgh  Encyclopaedia Britannica         1
# 2                 []  1778  Edinburgh  Encyclopaedia Britannica         1
# 3                 []  1778  Edinburgh  Encyclopaedia Britannica         1
# 4                 []  1778  Edinburgh  Encyclopaedia Britannica         1
# ...              ...   ...        ...                       ...       ...
# 16964             []  1778  Edinburgh  Encyclopaedia Britannica         9
# 16965             []  1778  Edinburgh  Encyclopaedia Britannica         9
# 16966             []  1778  Edinburgh  Encyclopaedia Britannica         9
# 16967             []  1778  Edinburgh  Encyclopaedia Britannica         9
# 16968             []  1778  Edinburgh  Encyclopaedia Britannica         9
#
#        letters  part                          altoXML
# 0        A-AST     0  144850370/alto/188386616.34.xml
# 1        A-AST     0  144850370/alto/188386616.34.xml
# 2        A-AST     0  144850370/alto/188386616.34.xml
# 3        A-AST     0  144850370/alto/188386616.34.xml
# 4        A-AST     0  144850370/alto/188386616.34.xml
# ...        ...   ...                              ...
# 16964  POI-SCU     0  190273289/alto/190289802.34.xml
# 16965  POI-SCU     0  190273289/alto/190289802.34.xml
# 16966  POI-SCU     0  190273289/alto/190289802.34.xml
# 16967  POI-SCU     0  190273289/alto/190289802.34.xml
# 16968  POI-SCU     0  190273289/alto/190289802.34.xml
#
# [16684 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['term', 'definition', 'relatedTerms', 'header', 'startsAt', 'endsAt',
#        'numberOfTerms', 'numberOfWords', 'numberOfPages', 'positionPage',
#        'typeTerm', 'editionTitle', 'editionNum', 'supplementTitle',
#        'supplementsTo', 'year', 'place', 'volumeTitle', 'volumeNum', 'letters',
#        'part', 'altoXML'],
#       dtype='object')

# %%
includeKeywords=["Article", "Topic"]
df=df[df["typeTerm"].str.contains('|'.join(includeKeywords))].reset_index(drop=True)

# %%
df_vol1=df[df["volumeNum"]==1]

# %%
df.columns
# Out:
# Index(['term', 'definition', 'relatedTerms', 'header', 'startsAt', 'endsAt',
#        'numberOfTerms', 'numberOfWords', 'numberOfPages', 'positionPage',
#        'typeTerm', 'editionTitle', 'editionNum', 'supplementTitle',
#        'supplementsTo', 'year', 'place', 'volumeTitle', 'volumeNum', 'letters',
#        'part', 'altoXML'],
#       dtype='object')

# %%
df_vol1.loc[18]
# Out:
# term                                                          ABACUS
# definition         among the ancients, was a kind of cupboard, or...
# relatedTerms                                                      []
# header                                                          AABA
# startsAt                                                          17
# endsAt                                                            17
# numberOfTerms                                                     12
# numberOfWords                                                     40
# numberOfPages                                                    872
# positionPage                                                       1
# typeTerm                                                     Article
# editionTitle                         Second edition, Volume 1, A-AST
# editionNum                                                         2
# supplementTitle
# supplementsTo                                                     []
# year                                                            1778
# place                                                      Edinburgh
# volumeTitle                                 Encyclopaedia Britannica
# volumeNum                                                          1
# letters                                                        A-AST
# part                                                               0
# altoXML                              144850370/alto/188386642.34.xml
# Name: 18, dtype: object

# %% [markdown]
# ### 3. Saving the dataframe to json file

# %%
df.to_json(r'../../results_NLS/results_eb_2_edition_dataframe_new', orient="index")

# %%
for i in range (0, len(df.index)):
    if i < len(df.index)-1:
        end_year=df.loc[i, 'year']
        end_vol=df.loc[i, 'volumeNum']
        end=df.loc[i, 'endsAt']
        
        start=df.loc[i+1, 'startsAt']
        start_year=df.loc[i+1, 'year']
        start_vol=df.loc[i+1, 'volumeNum']
        if start < end and end_year == start_year  and end_vol == start_vol:
            print("INCONSISTENCY at rows %s and %s" %(i, i+1))

# %%
df[df["term"]=="ABACUS"]
# Out:
#       term                                         definition relatedTerms  \
# 18  ABACUS  among the ancients, was a kind of cupboard, or...           []
# 19  ABACUS  Major, in metallurgic operations, the name of ...           []
#
#    header  startsAt  endsAt  numberOfTerms  numberOfWords  numberOfPages  \
# 18   AABA        17      17             12             40            872
# 19   AABA        17      17             12             18            872
#
#     positionPage  ... editionNum supplementTitle  supplementsTo  year  \
# 18             1  ...          2                             []  1778
# 19             2  ...          2                             []  1778
#
#         place               volumeTitle volumeNum letters  part  \
# 18  Edinburgh  Encyclopaedia Britannica         1   A-AST     0
# 19  Edinburgh  Encyclopaedia Britannica         1   A-AST     0
#
#                             altoXML
# 18  144850370/alto/188386642.34.xml
# 19  144850370/alto/188386642.34.xml
#
# [2 rows x 22 columns]

# %%
df[df['term'].str.contains("ALGEBRA")]
# Out:
#         term                                         definition  \
# 997  ALGEBRA  History. call Giaber, and who is supposed to h...
#
#            relatedTerms header  startsAt  endsAt  numberOfTerms  \
# 997  [ARITHMETIC, HERE]      S       257     277              1
#
#      numberOfWords  numberOfPages  positionPage  ... editionNum  \
# 997          15865            872             0  ...          2
#
#     supplementTitle  supplementsTo  year      place               volumeTitle  \
# 997                             []  1778  Edinburgh  Encyclopaedia Britannica
#
#     volumeNum letters  part                          altoXML
# 997         1   A-AST     0  144850370/alto/188389762.34.xml
#
# [1 rows x 22 columns]

# %%
df_vol1.loc[1982]
# Out:
# term                                                           ARLES
# definition         a city of Provence, in France, seated on the.e...
# relatedTerms                                                      []
# header                                                        ARLARM
# startsAt                                                         800
# endsAt                                                           800
# numberOfTerms                                                      3
# numberOfWords                                                    488
# numberOfPages                                                    872
# positionPage                                                       1
# typeTerm                                                     Article
# editionTitle                         Second edition, Volume 1, A-AST
# editionNum                                                         2
# supplementTitle
# supplementsTo                                                     []
# year                                                            1778
# place                                                      Edinburgh
# volumeTitle                                 Encyclopaedia Britannica
# volumeNum                                                          1
# letters                                                        A-AST
# part                                                               0
# altoXML                              144850370/alto/188396769.34.xml
# Name: 1982, dtype: object

# %%
df_1771_small = df_vol1[df_vol1['typeTerm']=="Topic"]
df_1771_small = df_1771_small.head(100).reset_index(drop=True)
df_1771_small
# Out:
#            term                                         definition  \
# 0     ACOUSTICS  ACOUSTICS, Ch. 1. Di Serene Theories of Anothe...
# 1   AGRICULTURE  History. Thus, though the Britons had in a gre...
# 2       ALGEBRA  History. call Giaber, and who is supposed to h...
# 3       ANATOMY  ANATOMY. to acquire some knowledge of the inte...
# 4     ANNUITIES  Annuities Prob. 2. Annuity, rate, and time giv...
# 5  ARCHITECTURE  Plate XXV. (B). fig. a. F' g3Jtate of arehitef...
# 6         ARITH  A R I T H calculation from the use of little H...
# 7    ARITHMETIC  Practice. lue at i id. 'At is. At i d.=Ti At i...
#
#                                         relatedTerms       header  startsAt  \
# 0                                        [HARMONICA]   ACOUSTICSC        76
# 1  [ATR, VEGETABLES, IHEWS, PRIEFTLEY, MOULD, SOI...  AGRICULTURE       147
# 2                                 [ARITHMETIC, HERE]            S       257
# 3  [PHIL, TRANF, MED, CHIRURG, OBSERV, IKIN, LIEU...      ANATOMY       372
# 4                                 [CHANCES, ANNUITY]    ANNUITIES       527
# 5  [PRINCIPLES, FOR, COLUMNS, DIMINUTIO*, AUZOULT...       ARCHIT       668
# 6                                                 []        ARITH       762
# 7                 [CHAP, EXTRACTION, ROOTS, ALGEBRA]      6684856       778
#
#    endsAt  numberOfTerms  numberOfWords  numberOfPages  positionPage  ...  \
# 0      83              1          10074            872             0  ...
# 1     200              1          53057            872             0  ...
# 2     277              1          15865            872             0  ...
# 3     457              1          71328            872             0  ...
# 4     532              1           3803            872             0  ...
# 5     737              1          36268            872             0  ...
# 6     776              1          14416            872             0  ...
# 7     800              1          18909            872             0  ...
#
#   editionNum supplementTitle  supplementsTo  year      place  \
# 0          2                             []  1778  Edinburgh
# 1          2                             []  1778  Edinburgh
# 2          2                             []  1778  Edinburgh
# 3          2                             []  1778  Edinburgh
# 4          2                             []  1778  Edinburgh
# 5          2                             []  1778  Edinburgh
# 6          2                             []  1778  Edinburgh
# 7          2                             []  1778  Edinburgh
#
#                 volumeTitle volumeNum letters  part  \
# 0  Encyclopaedia Britannica         1   A-AST     0
# 1  Encyclopaedia Britannica         1   A-AST     0
# 2  Encyclopaedia Britannica         1   A-AST     0
# 3  Encyclopaedia Britannica         1   A-AST     0
# 4  Encyclopaedia Britannica         1   A-AST     0
# 5  Encyclopaedia Britannica         1   A-AST     0
# 6  Encyclopaedia Britannica         1   A-AST     0
# 7  Encyclopaedia Britannica         1   A-AST     0
#
#                            altoXML
# 0  144850370/alto/188387409.34.xml
# 1  144850370/alto/188388358.34.xml
# 2  144850370/alto/188389762.34.xml
# 3  144850370/alto/188391257.34.xml
# 4  144850370/alto/188393194.34.xml
# 5  144850370/alto/188395053.34.xml
# 6  144850370/alto/188396275.34.xml
# 7  144850370/alto/188396483.34.xml
#
# [8 rows x 22 columns]

# %%
df_1771_small.loc[6]["definition"]
# Out:
# 'A R I T H calculation from the use of little Hones {calculi\' ) in their A first arithmetical operations. Grecian me If this method, however, was at all made use of, it thod of mu [j ; hgve been but for a Ihort time, since we find the tion P Uta " Greeks very early made use of the letters of the alphalpn \' bet to represent their numbers. The 24 letters of their alphabet, taken according to their order, at first denoted the numbers 1, 2, 3, 4, 5, 7, 8, 9, 10, 20, 30, 40, 50, 60, 70, 80, 100, 200, 300, 400, 500, 600, 700, and 800 ; to which they added the three, following v, 7,\'?), to represent 6, 90, and 900. The difficulty of performing arithmetical operations by such marks as these may easily be imagined, and is very conspicuous from Archimedes’s treatise concerning the di3 menfions of a circle. Roman Nc The Romans followed a like method; and besides tation. chara&ers for each rank of clafies, they introduced others for five, fifty, and five hundred. Their method is still used for diftinguiffiin^ the chapters of books, and some other purposes. Their numeral letters and values are the following. I V X L C D M One, five, ten, fifty, one hundred, five hundred, one thousand Any number, however great, may be represented by repeating and combining these according to the following rules. 1 st , When the same letter is repeated twice, or oftener, its value is represented as often. Thus II signifies two ; XXX thirty, CC two hundred. 2 J , When a numeral letter of lesser value is placed after one of greater, their values are added : thus XI signifies eleven, LXV sixty-five, MDCXXVIII one thousand six hundred and twenty-eight. 3 d , When a numeral letter of lesser value is placed before one of greater, the value of the lesser is taken from that of the greater : thus IV signifies four, XL forty, XC ninety, CD four hundred. Sometimes 13 is used instead of D for 500, and the value is increased ten times by annexing 3 to the right hand. Thus J3 signifies 500. Also Ci3is used for 1000 130 5000 C Cj33 for 10000 1333 SO 000 CCC1333 for 100000 Sometimes thousands are represented by drawing a line over the top of the numeral, V being used for five thousand, L for fifty thousand, CC two hundred thousand. Sexagefimal About the year of Christ 200, a new kind of arith.Arithmetic. metic, called fexagefimal, was invented, as is supposed, by Claudius Ptolomasus. The design of it was to remedy the difficulties of the common method, especially with regard to fra&ions. In this kind of arithmetic, every unit was supposed to be divided into 60 parts, and each of these into 60 others, and so on : hence any number of ftich parts were called fexagefimal fractions ; and to make the computation in whole numbers more cafy, he made the progression in these also fexagefimal. Thus from one to 59 were marked in the common way : then 60 was called a fexagefma prlma, or first fexagefimal integer, and had one single daffi over it; so 60 was expressed thus I\' ; and so on to 59 times 60, or 3540, which was\'thus expressed LIX\'. He now proceeded to 60 times 60, which he called a fexageftma fecunda, and was thus expressed I". In like manner, twice 60 times 60, or 7200, was expressed by 11"; and METIC. Hiflory. so 4m till he came to 60 times 3600, which was a third fexagefimal, and expressed thus, I"\'. If any number less than 60 was joined with these fexagefimals, it was added in its proper characters without any daffi : thus I XV represented 60 and 15, or 75; IVXXV is four times 60 and 25, or 265; X\'H\'XV, is 10 times 3600, twice 60 and 15, or 36,135, &c. Sexagefimal fractions were marked by putting the daffi at the foot, or on the left hand of the letter: thus I,, or I, denoted 5^; or I) 160S & c * _ _ y The most perfect method of notation, which we Indian Chanow use, came into Europe from the Arabians, by the rafterswhen way of Spain. The Arabs, however, do not pretend in " to be the inventors of them, but acknowledge that they received them from the Indians. Some  ...
