# %% [markdown]
# # FINAL Dataframe-  NLS -  Encyclopaedia Britannica
#
# This notebook is going to merge all the data available that we have from our postprocess dataframes.
#
# For each postprocess edition dataframe that we got from **Merging_EB_Terms.ipynb** (e.g. results_eb_1_edition_dataframe, results_eb_2_edition_dataframe, etc) we are going to add the information from the dataframe that we got from **Metadata_EB.ipynb** (metadata_eb_dataframe).
#
# The idea is to have per edition dataframe (and also supplement dataframe), all the information (which currently is splitted across several dataframes) in one.
#
#
# This notebook will store the final dataframes in results_NLS directory, and their name schema will be **final_eb_< NUM_EDITION >_dataframe**.
#
# Per entry in these new dataframes we will have the following columns (see an example of one entry of the first edition):
#
# - MMSID:
# - editionTitle:                          First edition, 1771, Volume 1, A-B
# - editor:                                                  Smellie, William
# - editor_date:                                                   1740-1795
# - genre:                                                       encyclopedia
# - language:                                                             eng
# - termsOfAddress:                                                       NaN
# - numberOfPages:                                                        832
# - physicalDescription:               3 v., 160 plates : ill. ; 26 cm. (4to)
# - place:                                                         Edinburgh
# - publisher:              Printed for A. Bell and C. Macfarquhar; and so...
# - referencedBy:           [Alston, R.C.  Engl. language III, 560, ESTC T...
# - shelfLocator:                                                        EB.1
# - editionSubTitle:        Illustrated with one hundred and sixty copperp...
# - volumeTitle:            Encyclopaedia Britannica; or, A dictionary of ...
# - year:                                                                1771
# - volumeId:                                                       144133901
# - metsXML:                                               144133901-mets.xml
# - permanentURL:                            https://digital.nls.uk/144133901
# - publisherPersons:                     [C. Macfarquhar, Colin Macfarquhar]
# - volumeNum:                                                              1
# - letters:                                                              A-B
# - part:                                                                   0
# - editionNum:                                                             1
# - supplementTitle:
# - supplementSubTitle:
# - supplementsTo:                                                         []
# - numberOfVolumes:                                                        6
# - term:                                                                  OR
# - definition:             A NEW A D I C T I A A, the name of several riv...
# - relatedTerms:                                                          []
# - header:                                           EncyclopaediaBritannica
# - startsAt:                                                              15
# - endsAt:                                                                15
# - numberOfTerms:                                                         22
# - numberOfWords:                                                         54
# - positionPage:                                                           0
# - typeTerm:                                                         Article
# - altoXML:                                  144133901/alto/188082904.34.xml

# %% [markdown]
# ### Loading the necessary libraries

# %%
import yaml
import numpy as np
import collections
import string
import copy

# %%
import pandas as pd
from yaml import safe_load
from pandas.io.json import json_normalize
from difflib import SequenceMatcher

# %% [markdown]
# ### Functions

# %%
def add_metadata(df):
    
    mask = df["editionTitle"].str.contains('Volume')
    for i in range(0, len (mask)):
        if mask[i]:
            tmp=df.loc[i,'editionTitle'].split("Volume ")[1].split(",")
            if len(tmp)>=1:
                volume= tmp[0]
                letters = tmp[-1].replace(" ","")
                part_tmp = volume.split("Part ")
                if len(part_tmp)>1:
                    volume=part_tmp[0]
                    part = part_tmp[1]
    
                    try:
                        part = int(part)
                    except:
                        if "I" in part:
                            part = 1
                else:
                    part=0

                volume = int(volume)
                df.loc[i, "letters"] = letters
                df.loc[i,"part"] = part
                df.loc[i ,"volumeNum"] = volume
    return df

# %%
def create_dataframe(df_metadata, df_data, editionNum):
    
    
    appended_data = []
    df_m_ed = df_metadata[df_metadata['editionNum'] == editionNum]
    list_years=df_m_ed["year"].unique()
    
    for y in range(0, len(list_years)):
        df_d_year=df_data[df_data['year'] == list_years[y]].reset_index(drop=True)
        df_m_year = df_m_ed[df_m_ed['year'] == list_years[y]].reset_index(drop=True)
        list_vols = df_m_year["volumeNum"].unique()
        print("YEAR %s, list_vols %s" % (list_years[y], list_vols))
        for v in range(0,len(list_vols)):
            df_d_year_vl=df_d_year[df_d_year["volumeNum"] == list_vols[v]].reset_index(drop=True)
            df_m_year_vl = df_m_year[df_m_year['volumeNum']==list_vols[v]].reset_index(drop=True)
            list_parts = df_m_year_vl["part"].unique()
            print("VOL %s, list_parts are %s" % (list_vols[v], list_parts))
            for p in range(0, len(list_parts)):
                df_d_year_vl_p=df_d_year_vl[df_d_year_vl["part"] == list_parts[p]].reset_index(drop=True)
                df_m_year_vl_p=df_m_year_vl[df_m_year_vl["part"] == list_parts[p]].reset_index(drop=True)
            
                
                d_rows_year_vl_p=len(df_d_year_vl_p.index)-1
                print("number of data rows for year %s, vol %s and part %s is %s" % (list_years[y], list_vols[v], list_parts[p], d_rows_year_vl_p ))
        
                df_m_year_vl_p_f = df_m_year_vl_p.append([df_m_year_vl_p]*d_rows_year_vl_p,ignore_index=True).reset_index(drop=True)
                result = pd.concat([df_m_year_vl_p_f, df_d_year_vl_p], axis=1).reset_index(drop=True)
                print("Len of the new temporal concatenated df %s" %len(result.index))
                appended_data.append(result)
    
    if editionNum == 3:
        df_m_sup = df_m[df_m['supplementTitle'].str.contains("third")]
        list_years=df_m_sup["year"].unique()
        
        for y in range(0, len(list_years)):
            df_d_year=df_data[df_data['year'] == list_years[y]].reset_index(drop=True)
            df_m_year = df_m_sup[df_m_sup['year'] == list_years[y]].reset_index(drop=True)
            list_vols = df_m_year["volumeNum"].unique()
            print("SUP YEAR %s, list_vols %s" % (list_years[y], list_vols))
            for v in range(0,len(list_vols)):
                df_d_year_vl=df_d_year[df_d_year["volumeNum"] == list_vols[v]].reset_index(drop=True)
                df_m_year_vl = df_m_year[df_m_year['volumeNum']==list_vols[v]].reset_index(drop=True)
                list_parts = df_m_year_vl["part"].unique()
                print("SUP VOL %s, list_parts are %s" % (list_vols[v], list_parts))
                for p in range(0, len(list_parts)):
                    df_d_year_vl_p=df_d_year_vl[df_d_year_vl["part"] == list_parts[p]].reset_index(drop=True)
                    df_m_year_vl_p=df_m_year_vl[df_m_year_vl["part"] == list_parts[p]].reset_index(drop=True)
            
                
                    d_rows_year_vl_p=len(df_d_year_vl_p.index)-1
                    print("SUP number of data rows for year %s, vol %s and part %s is %s" % (list_years[y], list_vols[v], list_parts[p], d_rows_year_vl_p ))
        
                    df_m_year_vl_p_f = df_m_year_vl_p.append([df_m_year_vl_p]*d_rows_year_vl_p,ignore_index=True).reset_index(drop=True)
                    result = pd.concat([df_m_year_vl_p_f, df_d_year_vl_p], axis=1).reset_index(drop=True)
                    print("SUP Len of the new temporal concatenated df %s" %len(result.index))
                    appended_data.append(result)
                
                
    final_df = pd.concat(appended_data).reset_index(drop=True)
    final_df =  final_df.loc[:,~final_df.columns.duplicated()]
    return final_df

# %%
def create_dataframe_sup(df_metadata, df_data):

    appended_data=[]
    df_m_sup = df_m[df_m['supplementTitle'].str.contains("fourth")]
    list_years=df_m_sup["year"].unique()
        
    for y in range(0, len(list_years)):
        df_d_year=df_data[df_data['year'] == list_years[y]].reset_index(drop=True)
        df_m_year = df_m_sup[df_m_sup['year'] == list_years[y]].reset_index(drop=True)
        list_vols = df_m_year["volumeNum"].unique()
        print("SUP YEAR %s, list_vols %s" % (list_years[y], list_vols))
        for v in range(0,len(list_vols)):
            df_d_year_vl=df_d_year[df_d_year["volumeNum"] == list_vols[v]].reset_index(drop=True)
            df_m_year_vl = df_m_year[df_m_year['volumeNum']==list_vols[v]].reset_index(drop=True)
            list_parts = df_m_year_vl["part"].unique()
            print("SUP VOL %s, list_parts are %s" % (list_vols[v], list_parts))
            for p in range(0, len(list_parts)):
                df_d_year_vl_p=df_d_year_vl[df_d_year_vl["part"] == list_parts[p]].reset_index(drop=True)
                df_m_year_vl_p=df_m_year_vl[df_m_year_vl["part"] == list_parts[p]].reset_index(drop=True)
            
                
                d_rows_year_vl_p=len(df_d_year_vl_p.index)-1
                print("SUP number of data rows for year %s, vol %s and part %s is %s" % (list_years[y], list_vols[v], list_parts[p], d_rows_year_vl_p ))
        
                df_m_year_vl_p_f = df_m_year_vl_p.append([df_m_year_vl_p]*d_rows_year_vl_p,ignore_index=True).reset_index(drop=True)
                result = pd.concat([df_m_year_vl_p_f, df_d_year_vl_p], axis=1).reset_index(drop=True)
                print("SUP Len of the new temporal concatenated df %s" %len(result.index))
                appended_data.append(result)
                
                
    final_df = pd.concat(appended_data).reset_index(drop=True)
    final_df =  final_df.loc[:,~final_df.columns.duplicated()]
    return final_df

# %% [markdown]
# ### 1. Loading the metadata dataframe

# %%
df_m= pd.read_json(r'../../results_NLS/metadata_eb_dataframe', orient="index")

# %%
df_m[df_m["editionNum"]==3]
# Out:
#               MMSID                                editionTitle editor  \
# 14  997902543804341            Third edition, Volume 2, ANG-BAR   None
# 15  997902543804341            Third edition, Volume 3, BAR-BZO   None
# 16  997902543804341            Third edition, Volume 4, CAA-CIC   None
# 17  997902543804341            Third edition, Volume 5, CIC-DIA   None
# 18  997902543804341            Third edition, Volume 6, DIA-ETH   None
# 19  997902543804341            Third edition, Volume 7, ETM-GOA   None
# 20  997902543804341            Third edition, Volume 8, GOB-HYD   None
# 21  997902543804341   Third edition, Volume 9, Hydrostatics-LES   None
# 22  997902543804341           Third edition, Volume 10, LES-MEC   None
# 23  997902543804341  Third edition, Volume 11, Medals-Midwifery   None
# 26  997902543804341              Third edition, Volume 1, A-ANG   None
# 27  997902543804341           Third edition, Volume 12, MIE-NEG   None
# 28  997902543804341           Third edition, Volume 13, NEH-PAS   None
# 29  997902543804341           Third edition, Volume 15, PLA-RAM   None
# 30  997902543804341           Third edition, Volume 17, SCO-STR   None
# 33  997902543804341           Third edition, Volume 18, STR-ZYM   None
# 41  997902543804341           Third edition, Volume 16, RAN-SCO   None
# 73  997902543804341           Third edition, Volume 14, PAS-PLA   None
#
#    editor_date         genre language termsOfAddress  numberOfPages  \
# 14        None  encyclopedia      eng           None            922
# 15        None  encyclopedia      eng           None            856
# 16        None  encyclopedia      eng           None            842
# 17        None  encyclopedia      eng           None            858
# 18        None  encyclopedia      eng           None            850
# 19        None  encyclopedia      eng           None            882
# 20        None  encyclopedia      eng           None            832
# 21        None  encyclopedia      eng           None            872
# 22        None  encyclopedia      eng           None            842
# 23        None  encyclopedia      eng           None            862
# 26        None  encyclopedia      eng           None            894
# 27        None  encyclopedia      eng           None            870
# 28        None  encyclopedia      eng           None            874
# 29        None  encyclopedia      eng           None            894
# 30        None  encyclopedia      eng           None            918
# 33        None  encyclopedia      eng           None           1076
# 41        None  encyclopedia      eng           None            834
# 73        None  encyclopedia      eng           None            840
#
#                     physicalDescription      place  ...  \
# 14  18v.,plates : ill.,maps,music ; 4to  Edinburgh  ...
# 15  18v.,plates : ill.,maps,music ; 4to  Edinburgh  ...
# 16  18v.,plates : ill.,maps,music ; 4to  Edinburgh  ...
# 17  18v.,plates : ill.,maps,music ; 4to  Edinburgh  ...
# 18  18v.,plates : ill.,maps,music ; 4to  Edinburgh  ...
# 19  18v.,plates : ill.,maps,music ; 4to  Edinburgh  ...
# 20  18v.,plates : ill.,maps,music ; 4to  Edinburgh  ...
# 21  18v.,plates : ill.,maps,music ; 4to  Edinburgh  ...
# 22  18v.,plates : ill.,maps,music ; 4to  Edinburgh  ...
# 23  18v.,plates : ill.,maps,music ; 4to  Edinburgh  ...
# 26  18v.,plates : ill.,maps,music ; 4to  Edinburgh  ...
# 27  18v.,plates : ill.,maps,music ; 4to  Edinburgh  ...
# 28  18v.,plates : ill.,maps,music ; 4to  Edinburgh  ...
# 29  18v.,plates : ill.,maps,music ; 4to  Edinburgh  ...
# 30  18v.,plates : ill.,maps,music ; 4to  Edinburgh  ...
# 33  18v.,plates : ill.,maps,music ; 4to  Edinburgh  ...
# 41  18v.,plates : ill.,maps,music ; 4to  Edinburgh  ...
# 73  18v.,plates : ill.,maps,music ; 4to  Edinburgh  ...
#
#                         permanentURL  publisherPersons volumeNum  \
# 14  https://digital.nls.uk/149977338  [C. Macfarquhar]         2
# 15  https://digital.nls.uk/149977873  [C. Macfarquhar]         3
# 16  https://digital.nls.uk/149978642  [C. Macfarquhar]         4
# 17  https://digital.nls.uk/149979156  [C. Macfarquhar]         5
# 18  https://digital.nls.uk/149979622  [C. Macfarquhar]         6
# 19  https://digital.nls.uk/149981189  [C. Macfarquhar]         7
# 20  https://digital.nls.uk/149981670  [C. Macfarquhar]         8
# 21  https://digital.nls.uk/149982181  [C. Macfarquhar]         9
# 22  https://digital.nls.uk/149982692  [C. Macfarquhar]        10
# 23  https://digital.nls.uk/149983206  [C. Macfarquhar]        11
# 26  https://digital.nls.uk/190273291  [C. Macfarquhar]         1
# 27  https://digital.nls.uk/190273372  [C. Macfarquhar]        12
# 28  https://digital.nls.uk/191253798  [C. Macfarquhar]        13
# 29  https://digital.nls.uk/191253799  [C. Macfarquhar]        15
# 30  https://digital.nls.uk/191253800  [C. Macfarquhar]        17
# 33  https://digital.nls.uk/191253817  [C. Macfarquhar]        18
# 41  https://digital.nls.uk/191319917  [C. Macfarquhar]        16
# 73  https://digital.nls.uk/192200061  [C. Macfarquhar]        14
#
#              letters part  editionNum  supplementTitle supplementSubTitle  \
# 14           ANG-BAR    0           3
# 15           BAR-BZO    0           3
# 16           CAA-CIC    0           3
# 17           CIC-DIA    0           3
# 18           DIA-ETH    0           3
# 19           ETM-GOA    0           3
# 20           GOB-HYD    0           3
# 21  Hydrostatics-LES    0           3
# 22           LES-MEC    0           3
# 23  Medals-Midwifery    0           3
# 26             A-ANG    0           3
# 27           MIE-NEG    0           3
# 28           NEH-PAS    0           3
# 29           PLA-RAM    0           3
# 30           SCO-STR    0           3
# 33           STR-ZYM    0           3
# 41           RAN-SCO    0           3
# 73           PAS-PLA    0           3
#
#    supplementsTo numberOfVolumes
# 14            []              18
# 15            []              18
# 16            []              18
# 17            []              18
# 18            []              18
# 19            []              18
# 20            []              18
# 21            []              18
# 22            []              18
# 23            []              18
# 26            []              18
# 27            []              18
# 28            []              18
# 29            []              18
# 30            []              18
# 33            []              18
# 41            []              18
# 73            []              18
#
# [18 rows x 28 columns]

# %% [markdown]
# ### 2. Creating the NEW final dataframes for all Editions
#
#
# Possible values:
# - results_eb_4_5_6_suplement_dataframe
# - results_eb_8_edition_dataframe
# - results_eb_7_edition_dataframe
# - results_eb_6_edition_dataframe
# - results_eb_5_edition_dataframe
# - results_eb_4_edition_dataframe
# - results_eb_3_edition_dataframe
# - results_eb_2_edition_dataframe
# - results_eb_1_edition_dataframe

# %%
df_d = pd.read_json("../../results_NLS/results_eb_1_edition_dataframe", orient="index") 
len(df_d)
# Out:
# 18117

# %%
df_d.columns
# Out:
# Index(['term', 'definition', 'relatedTerms', 'header', 'startsAt', 'endsAt',
#        'numberOfTerms', 'numberOfWords', 'numberOfPages', 'positionPage',
#        'typeTerm', 'editionTitle', 'editionNum', 'supplementTitle',
#        'supplementsTo', 'year', 'place', 'volumeTitle', 'volumeNum', 'letters',
#        'part', 'altoXML'],
#       dtype='object')

# %%
df_d.tail(3)["volumeNum"]
# Out:
# 18114    3
# 18115    3
# 18116    3
# Name: volumeNum, dtype: int64

# %% [markdown]
# Note: add_metadata function can take a while.

# %%
df_d = add_metadata(df_d)

# %% [markdown]
# **IMPORTANT**
#
# - Use create_dataframe for creating the final dataframe for all editions. This function needs to **indicate the NUMBER of the edition, in the last argument**.
# - Use create_dataframe_sup for creating the final dataframe for the supplements.

# %%
df_final=create_dataframe(df_m, df_d, 1)
#df_final=create_dataframe_sup(df_m, df_d)
# Out:
# YEAR 1771, list_vols [1 2 3]
# VOL 1, list_parts are [0]
# number of data rows for year 1771, vol 1 and part 0 is 2519
# Len of the new temporal concatenated df 2520
# VOL 2, list_parts are [0]
# number of data rows for year 1771, vol 2 and part 0 is 3148
# Len of the new temporal concatenated df 3149
# VOL 3, list_parts are [0]
# number of data rows for year 1771, vol 3 and part 0 is 3253
# Len of the new temporal concatenated df 3254
# YEAR 1773, list_vols [1 2 3]
# VOL 1, list_parts are [0]
# number of data rows for year 1773, vol 1 and part 0 is 2483
# Len of the new temporal concatenated df 2484
# VOL 2, list_parts are [0]
# number of data rows for year 1773, vol 2 and part 0 is 3454
# Len of the new temporal concatenated df 3455
# VOL 3, list_parts are [0]
# number of data rows for year 1773, vol 3 and part 0 is 3254
# Len of the new temporal concatenated df 3255

# %% [markdown]
# And these are the columns of our FINAL DATAFRAME

# %%
df_final.columns
# Out:
# Index(['MMSID', 'editionTitle', 'editor', 'editor_date', 'genre', 'language',
#        'termsOfAddress', 'numberOfPages', 'physicalDescription', 'place',
#        'publisher', 'referencedBy', 'shelfLocator', 'editionSubTitle',
#        'volumeTitle', 'year', 'volumeId', 'metsXML', 'permanentURL',
#        'publisherPersons', 'volumeNum', 'letters', 'part', 'editionNum',
#        'supplementTitle', 'supplementSubTitle', 'supplementsTo',
#        'numberOfVolumes', 'term', 'definition', 'relatedTerms', 'header',
#        'startsAt', 'endsAt', 'numberOfTerms', 'numberOfWords', 'positionPage',
#        'typeTerm', 'altoXML'],
#       dtype='object')

# %%
df_final
# Out:
#                   MMSID                        editionTitle            editor  \
# 0       992277653804341  First edition, 1771, Volume 1, A-B  Smellie, William
# 1       992277653804341  First edition, 1771, Volume 1, A-B  Smellie, William
# 2       992277653804341  First edition, 1771, Volume 1, A-B  Smellie, William
# 3       992277653804341  First edition, 1771, Volume 1, A-B  Smellie, William
# 4       992277653804341  First edition, 1771, Volume 1, A-B  Smellie, William
# ...                 ...                                 ...               ...
# 18112  9929192893804340  First edition, 1773, Volume 3, M-Z  Smellie, William
# 18113  9929192893804340  First edition, 1773, Volume 3, M-Z  Smellie, William
# 18114  9929192893804340  First edition, 1773, Volume 3, M-Z  Smellie, William
# 18115  9929192893804340  First edition, 1773, Volume 3, M-Z  Smellie, William
# 18116  9929192893804340  First edition, 1773, Volume 3, M-Z  Smellie, William
#
#       editor_date         genre language termsOfAddress  numberOfPages  \
# 0       1740-1795  encyclopedia      eng           None            832
# 1       1740-1795  encyclopedia      eng           None            832
# 2       1740-1795  encyclopedia      eng           None            832
# 3       1740-1795  encyclopedia      eng           None            832
# 4       1740-1795  encyclopedia      eng           None            832
# ...           ...           ...      ...            ...            ...
# 18112   1740-1795  encyclopedia      eng           None            864
# 18113   1740-1795  encyclopedia      eng           None            864
# 18114   1740-1795  encyclopedia      eng           None            864
# 18115   1740-1795  encyclopedia      eng           None            864
# 18116   1740-1795  encyclopedia      eng           None            864
#
#                                      physicalDescription      place  ...  \
# 0                 3 v., 160 plates : ill. ; 26 cm. (4to)  Edinburgh  ...
# 1                 3 v., 160 plates : ill. ; 26 cm. (4to)  Edinburgh  ...
# 2                 3 v., 160 plates : ill. ; 26 cm. (4to)  Edinburgh  ...
# 3                 3 v., 160 plates : ill. ; 26 cm. (4to)  Edinburgh  ...
# 4                 3 v., 160 plates : ill. ; 26 cm. (4to)  Edinburgh  ...
# ...                                                  ...        ...  ...
# 18112  3 v. (viii, 697, [1] p., LVIII leaves of plate...     London  ...
# 18113  3 v. (viii, 697, [1] p., LVIII leaves of plate...     London  ...
# 18114  3 v. (viii, 697, [1] p., LVIII leaves of plate...     London  ...
# 18115  3 v. (viii, 697, [1] p., LVIII leaves of plate...     London  ...
# 18116  3 v. (viii, 697, [1] p., LVIII leaves of plate...     London  ...
#
#                                               definition relatedTerms  header  \
# 0      A NEW A D I C T I A A, the name of several riv...           []    EBAA
# 1                    a term, among alchemifts, for lead,           []    EBAA
# 2      the name of a town and river in Swabia. It is ...           []    EBAA
# 3      the name of two rivers, one in the country of ...           []    EBAA
# 4               a small town and diftrift in Weftphalia.           []    EBAA
# ...                                                  ...          ...     ...
# 18112  01 Zafre, in chemistry, the name of a blue fuf...           []  YOAYUC
# 18113  antyof Spain in the province of Leon, fituater...           []  YOAYUC
# 18114  AR a country on the east coast of Africa, situ...           []  YOAYUC
# 18115  in botany, a genus of the monoe ia monandria c...           []  YOAYUC
# 18116  inbotany, agenus of thedioecia pemandriaclass....           []  YOAYUC
#
#       startsAt endsAt  numberOfTerms  numberOfWords positionPage typeTerm  \
# 0           15     15             22             54            0  Article
# 1           15     15             22              6            1  Article
# 2           15     15             22             17            2  Article
# 3           15     15             22             19            3  Article
# 4           15     15             22              7            4  Article
# ...        ...    ...            ...            ...          ...      ...
# 18112      855    855             14             57           10  Article
# 18113      855    855             14             31           11  Article
# 18114      855    855             14             54           12  Article
# 18115      855    855             14             56           13  Article
# 18116      855    855             14             43           14  Article
#
#                                altoXML
# 0      144133901/alto/188082904.34.xml
# 1      144133901/alto/188082904.34.xml
# 2      144133901/alto/188082904.34.xml
# 3      144133901/alto/188082904.34.xml
# 4      144133901/alto/188082904.34.xml
# ...                                ...
# 18112  144850368/alto/188374994.34.xml
# 18113  144850368/alto/188374994.34.xml
# 18114  144850368/alto/188374994.34.xml
# 18115  144850368/alto/188374994.34.xml
# 18116  144850368/alto/188374994.34.xml
#
# [18117 rows x 39 columns]

# %% [markdown]
# ### 3. Saving new final dataframes to disk

# %%
df_final.to_json(r'../../results_NLS/final_eb_1_dataframe', orient="index")

# %% [markdown]
# ### 4. Loading new final dataframes to memory

# %%
df = pd.read_json('../../results_NLS/final_eb_1_dataframe', orient="index")

# %%
df.head(2)
# Out:
#              MMSID                        editionTitle            editor  \
# 0  992277653804341  First edition, 1771, Volume 1, A-B  Smellie, William
# 1  992277653804341  First edition, 1771, Volume 1, A-B  Smellie, William
#
#   editor_date         genre language  termsOfAddress  numberOfPages  \
# 0   1740-1795  encyclopedia      eng             NaN            832
# 1   1740-1795  encyclopedia      eng             NaN            832
#
#                       physicalDescription      place  ...  \
# 0  3 v., 160 plates : ill. ; 26 cm. (4to)  Edinburgh  ...
# 1  3 v., 160 plates : ill. ; 26 cm. (4to)  Edinburgh  ...
#
#                                           definition relatedTerms header  \
# 0  A NEW A D I C T I A A, the name of several riv...           []   EBAA
# 1                a term, among alchemifts, for lead,           []   EBAA
#
#   startsAt endsAt  numberOfTerms  numberOfWords positionPage typeTerm  \
# 0       15     15             22             54            0  Article
# 1       15     15             22              6            1  Article
#
#                            altoXML
# 0  144133901/alto/188082904.34.xml
# 1  144133901/alto/188082904.34.xml
#
# [2 rows x 39 columns]

# %%
df.loc[0]
# Out:
# MMSID                                                    992277653804341
# editionTitle                          First edition, 1771, Volume 1, A-B
# editor                                                  Smellie, William
# editor_date                                                    1740-1795
# genre                                                       encyclopedia
# language                                                             eng
# termsOfAddress                                                       NaN
# numberOfPages                                                        832
# physicalDescription               3 v., 160 plates : ill. ; 26 cm. (4to)
# place                                                          Edinburgh
# publisher              Printed for A. Bell and C. Macfarquhar; and so...
# referencedBy           [Alston, R.C.  Engl. language III, 560, ESTC T...
# shelfLocator                                                        EB.1
# editionSubTitle        Illustrated with one hundred and sixty copperp...
# volumeTitle            Encyclopaedia Britannica; or, A dictionary of ...
# year                                                                1771
# volumeId                                                       144133901
# metsXML                                               144133901-mets.xml
# permanentURL                            https://digital.nls.uk/144133901
# publisherPersons                     [C. Macfarquhar, Colin Macfarquhar]
# volumeNum                                                              1
# letters                                                              A-B
# part                                                                   0
# editionNum                                                             1
# supplementTitle
# supplementSubTitle
# supplementsTo                                                         []
# numberOfVolumes                                                        6
# term                                                                  OR
# definition             A NEW A D I C T I A A, the name of several riv...
# relatedTerms                                                          []
# header                                                              EBAA
# startsAt                                                              15
# endsAt                                                                15
# numberOfTerms                                                         22
# numberOfWords                                                         54
# positionPage                                                           0
# typeTerm                                                         Article
# altoXML                                  144133901/alto/188082904.34.xml
# Name: 0, dtype: object
