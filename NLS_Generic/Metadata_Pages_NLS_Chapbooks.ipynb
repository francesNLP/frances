# %% [markdown]
# # Metadata and Pages Text-  NLS

# %% [markdown]
# We can have two types of digital collections:
#     - One that has a volume
#     - Has several books per collection

# %% [markdown]
# ### Loading the necessary libraries

# %%
import yaml
import numpy as np
import collections
import string
import copy

# %%
import pandas as pd
from yaml import safe_load
from pandas.io.json import json_normalize
from difflib import SequenceMatcher

# %%
import chart_studio.plotly as py
import plotly.figure_factory as ff
import plotly.express as px

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
#!python -m spacy download en_core_web_sm

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# ### Functions

# %%
def read_query_results(filename):
    with open('results/'+filename, 'r') as f:
        query_results = safe_load(f)
    return query_results

# %%
def write_query_results(filename, results):
    with open('results/'+filename, 'w') as f:
        documents = yaml.dump(results, f)

# %%
def find_persons(text):
    if text:
        doc2 = nlp(text)
    
        # Identify the persons
        persons = [ent.text for ent in doc2.ents if ent.label_ == 'PERSON']
    
        # Return persons
        return persons
    else:
        return None

# %%
def create_dataframe(metadata_results, collection_name):
  
    for volume in metadata_results:
        for page in metadata_results[volume]:
            print(page.keys())
            column_list=list(page.keys())
            break
        break
        
    data=[]
    for volume in metadata_results:
        for page in metadata_results[volume]:
            try:
                data.append(page)
            except:
                pass
    df = pd.DataFrame(data, columns = column_list)
    
     
    df= df.rename(columns={"serie":"serieTitle", "subtitle":"serieSubTitle",
                           "num_words":"numberOfWords",\
                           "title":"volumeTitle", "referenced_by":"referencedBy",\
                           "num_pages":"numberOfPages", "name_termsOfAddress":"termsOfAddress", \
                           "source_text_file": "altoXML", "num_text_unit": "numberOfPages", \
                           "text_unit_id":"pageNum",\
                           "num_words":"numberOfWords", \
                           "physical_description": "physicalDescription"})
    
   
    df= df.drop(['geographic', 'country', 'topic', 'city', 'temporal', 'dateIssued'], axis=1)
    
    alto=df["altoXML"]
    
    df["altoXML"]= df["volumeId"]+"/"+alto
    
    list_mmsid=(df["MMSID"].unique()).tolist()
    
    for i, row in df.iterrows():
        position= list_mmsid.index(row['MMSID'])
        df.at[i,'serieNum'] = position
        
    df["serieNum"]=df["serieNum"].fillna(0).astype(int)
    df["part"] = 0
    df["year"] = df["year"].fillna(0).astype(int)
    df["collectionName"]=collection_name
    
    vol_tmp=df["volumeTitle"].apply(lambda x: x.split('.'))
    list_vol=(vol_tmp).tolist()

    
    for i, row in df.iterrows():
        if len(list_vol[i])>1:
            if "year" in list_vol[i][1]:
                vol_info='.'.join(list_vol[i][0:2])
                sub_info=' '.join(list_vol[i][2:])
            else:
                vol_info='.'.join(list_vol[i][0:1])
                sub_info=' '.join(list_vol[i][1:])
            df.at[i,'volumeTitle'] = vol_info
            if df.at[i,'serieSubTitle']:
                df.at[i,'serieSubTitle'] = sub_info + " " + df.at[i,'serieSubTitle']
            else:
                df.at[i,'serieSubTitle'] = sub_info
        else:
            vol_info="".join(list_vol[i][0])
            df.at[i,'volumeTitle'] = vol_info
    
    vol_tmp=df["volumeTitle"].apply(lambda x: x.split(':'))
    list_vol=(vol_tmp).tolist()

    
    for i, row in df.iterrows():
        if len(list_vol[i])>1:
            if "year" in list_vol[i][1]:
                vol_info='.'.join(list_vol[i][0:2])
                sub_info=' '.join(list_vol[i][2:])
            else:
                vol_info='.'.join(list_vol[i][0:1])
                sub_info=' '.join(list_vol[i][1:])
            df.at[i,'volumeTitle'] = vol_info
            if df.at[i,'serieSubTitle']:
                df.at[i,'serieSubTitle'] = sub_info + " " + df.at[i,'serieSubTitle']
            else:
                df.at[i,'serieSubTitle'] = sub_info
        else:
            vol_info="".join(list_vol[i][0])
            df.at[i,'volumeTitle'] = vol_info
      
    df["serieTitle"]=df["volumeTitle"]
    if df["edition"].loc[0]!= None:
        df["volumeTitle"]=df["volumeTitle"]+" "+df["edition"]
    
    tmp = df['pageNum'].apply(lambda s:s.split('Page')[1])
    df['pageNum']= tmp
   
    try:
        df["referencedBy"]=df["referencedBy"].split("----")
    except:
        pass
    
    ### this takes a while! 
    df["publisherPersons"]=df["publisher"].apply(lambda x: find_persons(x))

    ### this should be improved in the future - these would not work for other collections
    ##  i have detected copies of the same book, with different volumeID. 
    # So, going to add them as new vols, of the same serie. 
    
    series_vol=df.groupby(['MMSID', 'volumeId']).size().reset_index()
    count_vol=series_vol.groupby(['MMSID'])['volumeId'].size().reset_index()
    for i, row in count_vol.iterrows():
        mmsid=row['MMSID']
        num_vol=row['volumeId']
        df.loc[df['MMSID'] == mmsid, 'numberOfVolumes'] = num_vol
    
    
    series_mmsid=series_vol.groupby(['MMSID'])['volumeId'].unique().reset_index()
    if df["edition"].loc[0] == None :
        for i, row in series_mmsid.iterrows():
            mmsid=row['MMSID']
            num_vol=len(row['volumeId'])
            list_vol=row['volumeId']
            for nv in range(0, num_vol):
                v_id=list_vol[nv]
                df.loc[df['volumeId'] == v_id, 'volumeNum'] = nv+1
    else:
        for i, row in df.iterrows():
            volum_num=row['edition']
            if "Volume" in volum_num:
                vnum=volum_num.split("Volume ")[1]
                vn=vnum.split(" ")[0]
            else:
                vn="1"
            row['volumeNum']=vn    
            v_id=row['volumeId']
            df.loc[df['volumeId'] == v_id, 'volumeNum'] = vn

    df["volumeNum"]=df["volumeNum"].fillna(0).astype(int)
    df["numberOfVolumes"]=df["numberOfVolumes"].fillna(0).astype(int)
    
    
    return df

# %% [markdown]
# ### 1. Reading data

# %% [markdown]
# Here we are going to take the output of the defoe files and we are going to create the final dataframe, that we will use later for creating the knowlege graph.

# %%
# !ls results/
# Out:
# README                                gazetters_scotland.ttl
# README.md                             ladiesDebating.ttl
# chapbooks_dataframe                   ladiesDebating_dataframe
# chapbooks_metadata_pages.yml          ladiesDebating_dataframe.ttl
# chapbooks_scotland.ttl                ladiesDebating_metadata_pages.yml
# gazetterOfScotland_dataframe          ladies_debating.ttl
# gazetterOfScotland_metadata_pages.yml

# %% [markdown]
# ### Note: The next line takes time!

# %%
query_results=read_query_results('chapbooks_metadata_pages.yml')

# %%
metadata_results = copy.deepcopy(query_results)

# %% [markdown]
# ### Note: The next line takes (a lot of) time!

# %%
df= create_dataframe(metadata_results, "Chapbooks printed in Scotland")
# Out:
# dict_keys(['MMSID', 'city', 'country', 'dateIssued', 'edition', 'editor', 'editor_date', 'genre', 'geographic', 'language', 'metsXML', 'name_termsOfAddress', 'num_pages', 'num_words', 'permanentURL', 'physical_description', 'place', 'publisher', 'referenced_by', 'shelfLocator', 'source_text_file', 'subtitle', 'temporal', 'text', 'text_unit_id', 'title', 'topic', 'volumeId', 'year'])

# %% [markdown]
# ### Listing the columns

# %%
df.columns
# Out:
# Index(['MMSID', 'edition', 'editor', 'editor_date', 'genre', 'language',
#        'metsXML', 'termsOfAddress', 'numberOfPages', 'numberOfWords',
#        'permanentURL', 'physicalDescription', 'place', 'publisher',
#        'referencedBy', 'shelfLocator', 'altoXML', 'serieSubTitle', 'text',
#        'pageNum', 'volumeTitle', 'volumeId', 'year', 'serieNum', 'part',
#        'collectionName', 'serieTitle', 'publisherPersons', 'numberOfVolumes',
#        'volumeNum'],
#       dtype='object')

# %%
#df.groupby(['MMSID', 'permanentURL']).size()
#df.loc[df['volumeTitle'].str.len() >200]
df["volumeTitle"]
df.iloc[0]
# Out:
# MMSID                                                   9937033633804341
# edition                                                             None
# editor                                                       Milne, John
# editor_date                                                    1792-1871
# genre                              Chapbooks-Scotland-Aberdeen-1801-1900
# language                                                             eng
# metsXML                                               104184105-mets.xml
# termsOfAddress                                                      None
# numberOfPages                                                          8
# numberOfWords                                                         53
# permanentURL                            https://digital.nls.uk/104184105
# physicalDescription                                        8 p. ; 18 cm.
# place                                                           Aberdeen
# publisher                             Printed by A. Imlay, 22, Long Acre
# referencedBy                                                        None
# shelfLocator                                               L.C.2786.A(1)
# altoXML                                  104184105/alto/107134030.34.xml
# serieSubTitle                                  to the tune of Johnny Cop
# text                   A SONG JRAISB OP THE ^ HIGHLAND LADS. To the T...
# pageNum                                                                1
# volumeTitle                          song in praise of the highland lads
# volumeId                                                       104184105
# year                                                                1826
# serieNum                                                               0
# part                                                                   0
# collectionName                             Chapbooks printed in Scotland
# serieTitle                           song in praise of the highland lads
# publisherPersons                                                      []
# numberOfVolumes                                                        1
# volumeNum                                                              1
# Name: 0, dtype: object

# %%
#df[df["volumeId"]=="104184137"]
df.loc[396]
# Out:
# MMSID                                                   9930677523804341
# edition                                                             None
# editor                                                              None
# editor_date                                                         None
# genre                                                               None
# language                                                             eng
# metsXML                                               104184137-mets.xml
# termsOfAddress                                                      None
# numberOfPages                                                          8
# numberOfWords                                                         29
# permanentURL                            https://digital.nls.uk/104184137
# physicalDescription                                            8p. ; 8vo
# place                                                         Edinburgh]
# publisher                                            Printed in the year
# referencedBy                                 ESTC T170290----Foxon M547
# shelfLocator                                               L.C.2786A(23)
# altoXML                                  104184137/alto/107129278.34.xml
# serieSubTitle           with some of the causes, and direfull effects...
# text                   A MOURN Ft JLL SONG. UPON THE BREACH OF Nation...
# pageNum                                                                1
# volumeTitle            mournfull song, upon the breach of national, a...
# volumeId                                                       104184137
# year                                                                1724
# serieNum                                                              32
# part                                                                   0
# collectionName                             Chapbooks printed in Scotland
# serieTitle             mournfull song, upon the breach of national, a...
# publisherPersons                                                      []
# numberOfVolumes                                                        1
# volumeNum                                                              1
# Name: 396, dtype: object

# %%
df.iloc[0]
# Out:
# MMSID                                                   9937033633804341
# edition                                                             None
# editor                                                       Milne, John
# editor_date                                                    1792-1871
# genre                              Chapbooks-Scotland-Aberdeen-1801-1900
# language                                                             eng
# metsXML                                               104184105-mets.xml
# termsOfAddress                                                      None
# numberOfPages                                                          8
# numberOfWords                                                         53
# permanentURL                            https://digital.nls.uk/104184105
# physicalDescription                                        8 p. ; 18 cm.
# place                                                           Aberdeen
# publisher                             Printed by A. Imlay, 22, Long Acre
# referencedBy                                                        None
# shelfLocator                                               L.C.2786.A(1)
# altoXML                                  104184105/alto/107134030.34.xml
# serieSubTitle                                  to the tune of Johnny Cop
# text                   A SONG JRAISB OP THE ^ HIGHLAND LADS. To the T...
# pageNum                                                                1
# volumeTitle                          song in praise of the highland lads
# volumeId                                                       104184105
# year                                                                1826
# serieNum                                                               0
# part                                                                   0
# collectionName                             Chapbooks printed in Scotland
# serieTitle                           song in praise of the highland lads
# publisherPersons                                                      []
# numberOfVolumes                                                        1
# volumeNum                                                              1
# Name: 0, dtype: object

# %% [markdown]
# ### Brief explanation of each column

# %% [markdown]
# - MMSID: Metadata Management System ID
# - serieTitle:        Title of the collection
# - serieSubTilte:     Subtitle of the collection
# - editor:              Editor (person) of an edition or a supplement
# - termsOfAddress:      Terms of Address of the editor (e.g. Sir)
# - editor_date: Year of Birth - Year of Death
# - genre:        genre of the editions
# - language:     language used to write the volumes
# - numberOfPages: number of pages of a volume
# - physicalDescription: physical description of a collection
# - place: place printed of a edition or a supplement
# - publisher: publisher (organization or person) of a collection
# - referencedBy: books which reference a collection
# - shelfLocator: shelf locator of a collection
# - subTitle: subtitle of an edition
# - volumeTitle: title of a volume
# - year: year of print
# - volumeId: volume identifier
# - metsXML: XML mets file
# - permanentURL: URL of a volume
# - publisherPersons: list of publishers which are persons - we have applied NLP for detecting the people!
# - volumeNum: Number of a volume
# - part: Part of a volume
# - collectionNum: Number of a collection
# - numberOfVolumes: Number of volumes per edition or supplement
# - text: text of page
# - numberOfWords: number of words per page
# - altoXML: alto xml of each page
# - PageNum: number of page

# %% [markdown]
# ### Sanity checks

# %%
df[df["volumeId"]=="104184137"]
# Out:
#                 MMSID edition editor editor_date genre language  \
# 396  9930677523804341    None   None        None  None      eng
# 397  9930677523804341    None   None        None  None      eng
# 398  9930677523804341    None   None        None  None      eng
# 399  9930677523804341    None   None        None  None      eng
# 400  9930677523804341    None   None        None  None      eng
# 401  9930677523804341    None   None        None  None      eng
# 402  9930677523804341    None   None        None  None      eng
# 403  9930677523804341    None   None        None  None      eng
#
#                 metsXML termsOfAddress  numberOfPages  numberOfWords  ...  \
# 396  104184137-mets.xml           None              8             29  ...
# 397  104184137-mets.xml           None              8            249  ...
# 398  104184137-mets.xml           None              8            274  ...
# 399  104184137-mets.xml           None              8            269  ...
# 400  104184137-mets.xml           None              8            290  ...
# 401  104184137-mets.xml           None              8            278  ...
# 402  104184137-mets.xml           None              8            280  ...
# 403  104184137-mets.xml           None              8            205  ...
#
#                                            volumeTitle   volumeId  year  \
# 396  mournfull song, upon the breach of national, a...  104184137  1724
# 397  mournfull song, upon the breach of national, a...  104184137  1724
# 398  mournfull song, upon the breach of national, a...  104184137  1724
# 399  mournfull song, upon the breach of national, a...  104184137  1724
# 400  mournfull song, upon the breach of national, a...  104184137  1724
# 401  mournfull song, upon the breach of national, a...  104184137  1724
# 402  mournfull song, upon the breach of national, a...  104184137  1724
# 403  mournfull song, upon the breach of national, a...  104184137  1724
#
#     serieNum part                 collectionName  \
# 396       32    0  Chapbooks printed in Scotland
# 397       32    0  Chapbooks printed in Scotland
# 398       32    0  Chapbooks printed in Scotland
# 399       32    0  Chapbooks printed in Scotland
# 400       32    0  Chapbooks printed in Scotland
# 401       32    0  Chapbooks printed in Scotland
# 402       32    0  Chapbooks printed in Scotland
# 403       32    0  Chapbooks printed in Scotland
#
#                                             serieTitle publisherPersons  \
# 396  mournfull song, upon the breach of national, a...               []
# 397  mournfull song, upon the breach of national, a...               []
# 398  mournfull song, upon the breach of national, a...               []
# 399  mournfull song, upon the breach of national, a...               []
# 400  mournfull song, upon the breach of national, a...               []
# 401  mournfull song, upon the breach of national, a...               []
# 402  mournfull song, upon the breach of national, a...               []
# 403  mournfull song, upon the breach of national, a...               []
#
#     numberOfVolumes volumeNum
# 396               1         1
# 397               1         1
# 398               1         1
# 399               1         1
# 400               1         1
# 401               1         1
# 402               1         1
# 403               1         1
#
# [8 rows x 30 columns]

# %%
df.loc[0]
# Out:
# MMSID                                                   9937033633804341
# edition                                                             None
# editor                                                       Milne, John
# editor_date                                                    1792-1871
# genre                              Chapbooks-Scotland-Aberdeen-1801-1900
# language                                                             eng
# metsXML                                               104184105-mets.xml
# termsOfAddress                                                      None
# numberOfPages                                                          8
# numberOfWords                                                         53
# permanentURL                            https://digital.nls.uk/104184105
# physicalDescription                                        8 p. ; 18 cm.
# place                                                           Aberdeen
# publisher                             Printed by A. Imlay, 22, Long Acre
# referencedBy                                                        None
# shelfLocator                                               L.C.2786.A(1)
# altoXML                                  104184105/alto/107134030.34.xml
# serieSubTitle                                  to the tune of Johnny Cop
# text                   A SONG JRAISB OP THE ^ HIGHLAND LADS. To the T...
# pageNum                                                                1
# volumeTitle                          song in praise of the highland lads
# volumeId                                                       104184105
# year                                                                1826
# serieNum                                                               0
# part                                                                   0
# collectionName                             Chapbooks printed in Scotland
# serieTitle                           song in praise of the highland lads
# publisherPersons                                                      []
# numberOfVolumes                                                        1
# volumeNum                                                              1
# Name: 0, dtype: object

# %%
df[["volumeId","numberOfVolumes"]]
# Out:
#         volumeId  numberOfVolumes
# 0      104184105                1
# 1      104184105                1
# 2      104184105                1
# 3      104184105                1
# 4      104184105                1
# ...          ...              ...
# 47324  120101372                2
# 47325  120101372                2
# 47326  120101372                2
# 47327  120101372                2
# 47328  120101372                2
#
# [47329 rows x 2 columns]

# %%
df.groupby(df["MMSID"])["volumeId"].count()
# Out:
# MMSID
# 9910029463804341     8
# 9910476853804341    48
# 9911213523804341    34
# 9911322163804341    12
# 991351003804341     24
#                     ..
# 99910913804341      18
# 9991175753804341     8
# 999360103804341      8
# 999441113804341     20
# 999989663804341     16
# Name: volumeId, Length: 2728, dtype: int64

# %%
df.groupby(df["volumeId"])["volumeId"].count()
# Out:
# volumeId
# 104184105     8
# 104184106     8
# 104184107    12
# 104184108    12
# 104184109    16
#              ..
# 117874574     8
# 117874575     8
# 117874576     8
# 117874577     8
# 120101372    24
# Name: volumeId, Length: 3080, dtype: int64

# %%
df[df["volumeId"]=="109857781"]
# Out:
# Empty DataFrame
# Columns: [MMSID, edition, editor, editor_date, genre, language, metsXML, termsOfAddress, numberOfPages, numberOfWords, permanentURL, physicalDescription, place, publisher, referencedBy, shelfLocator, altoXML, serieSubTitle, text, pageNum, volumeTitle, volumeId, year, serieNum, part, collectionName, serieTitle, publisherPersons, numberOfVolumes, volumeNum]
# Index: []
#
# [0 rows x 30 columns]

# %%
df.groupby(['MMSID','permanentURL'])['permanentURL'].size()
# Out:
# MMSID             permanentURL
# 9910029463804341  https://digital.nls.uk/104184208     8
# 9910476853804341  https://digital.nls.uk/104185169    24
#                   https://digital.nls.uk/104185768    24
# 9911213523804341  https://digital.nls.uk/104184169    24
#                   https://digital.nls.uk/104186985    10
#                                                       ..
# 9991175753804341  https://digital.nls.uk/104185287     8
# 999360103804341   https://digital.nls.uk/104185844     8
# 999441113804341   https://digital.nls.uk/104184325    20
# 999989663804341   https://digital.nls.uk/104185807     8
#                   https://digital.nls.uk/104186586     8
# Name: permanentURL, Length: 3080, dtype: int64

# %%
df.groupby(df["MMSID"])["volumeId"].count()
# Out:
# MMSID
# 9910029463804341     8
# 9910476853804341    48
# 9911213523804341    34
# 9911322163804341    12
# 991351003804341     24
#                     ..
# 99910913804341      18
# 9991175753804341     8
# 999360103804341      8
# 999441113804341     20
# 999989663804341     16
# Name: volumeId, Length: 2728, dtype: int64

# %% [markdown]
# ## Saving the final dataframe into a json file

# %%
df['volumeTitle'] = df['volumeTitle'].str.replace('[\[\]]', '', regex=True)
df['serieTitle'] = df['serieTitle'].str.replace('[\[\]]', '', regex=True)
df['serieSubTitle'] = df['serieSubTitle'].str.replace('[\[\]]', '', regex=True)

# %%
df.to_json(r'./results/chapbooks_dataframe', orient="index")

# %% [markdown]
# ### A couple of explorations

# %%
df["volumeTitle"]
# Out:
# 0        song in praise of the highland lads
# 1        song in praise of the highland lads
# 2        song in praise of the highland lads
# 3        song in praise of the highland lads
# 4        song in praise of the highland lads
#                         ...
# 47324                   Burns' popular songs
# 47325                   Burns' popular songs
# 47326                   Burns' popular songs
# 47327                   Burns' popular songs
# 47328                   Burns' popular songs
# Name: volumeTitle, Length: 47329, dtype: object

# %%
df["editor"]
# Out:
# 0          Milne, John
# 1          Milne, John
# 2          Milne, John
# 3          Milne, John
# 4          Milne, John
#              ...
# 47324    Burns, Robert
# 47325    Burns, Robert
# 47326    Burns, Robert
# 47327    Burns, Robert
# 47328    Burns, Robert
# Name: editor, Length: 47329, dtype: object

# %%
df.groupby(df["editor"]).count()
# Out:
#                    MMSID  edition  editor_date  genre  language  metsXML  \
# editor
# Abercromby, Ralph     24        0           24     24        24       24
# Abraham               24        0            0     24        24       24
# Aesop.                24        0            0     24        24       24
# Ainslie, Hew          24        0           24     24        24       24
# Aitken, A.            12        0            0      0        12       12
# ...                  ...      ...          ...    ...       ...      ...
# Wolfe, Charles        48        0           48     48        48       48
# Wolfe, James          48        0           48     48        48       48
# Woodward, Josiah      24        0           24      0        24       24
# Yarrington, Rob.       8        0            0      8         8        8
# Young Gentleman        8        0            0      8         8        8
#
#                    termsOfAddress  numberOfPages  numberOfWords  permanentURL  \
# editor
# Abercromby, Ralph              24             24             24            24
# Abraham                        24             24             24            24
# Aesop.                          0             24             24            24
# Ainslie, Hew                    0             24             24            24
# Aitken, A.                      0             12             12            12
# ...                           ...            ...            ...           ...
# Wolfe, Charles                  0             48             48            48
# Wolfe, James                    0             48             48            48
# Woodward, Josiah                0             24             24            24
# Yarrington, Rob.                0              8              8             8
# Young Gentleman                 8              8              8             8
#
#                    ...  volumeTitle  volumeId  year  serieNum  part  \
# editor             ...
# Abercromby, Ralph  ...           24        24    24        24    24
# Abraham            ...           24        24    24        24    24
# Aesop.             ...           24        24    24        24    24
# Ainslie, Hew       ...           24        24    24        24    24
# Aitken, A.         ...           12        12    12        12    12
# ...                ...          ...       ...   ...       ...   ...
# Wolfe, Charles     ...           48        48    48        48    48
# Wolfe, James       ...           48        48    48        48    48
# Woodward, Josiah   ...           24        24    24        24    24
# Yarrington, Rob.   ...            8         8     8         8     8
# Young Gentleman    ...            8         8     8         8     8
#
#                    collectionName  serieTitle  publisherPersons  \
# editor
# Abercromby, Ralph              24          24                24
# Abraham                        24          24                24
# Aesop.                         24          24                24
# Ainslie, Hew                   24          24                24
# Aitken, A.                     12          12                12
# ...                           ...         ...               ...
# Wolfe, Charles                 48          48                48
# Wolfe, James                   48          48                48
# Woodward, Josiah               24          24                24
# Yarrington, Rob.                8           8                 8
# Young Gentleman                 8           8                 8
#
#                    numberOfVolumes  volumeNum
# editor
# Abercromby, Ralph               24         24
# Abraham                         24         24
# Aesop.                          24         24
# Ainslie, Hew                    24         24
# Aitken, A.                      12         12
# ...                            ...        ...
# Wolfe, Charles                  48         48
# Wolfe, James                    48         48
# Woodward, Josiah                24         24
# Yarrington, Rob.                 8          8
# Young Gentleman                  8          8
#
# [366 rows x 29 columns]

# %%
df.groupby(df["publisher"]).count()
# Out:
#                                                     MMSID  edition  editor  \
# publisher
# (Printed by J. Chalmers & Co. Castlestreet Aber...      8        0       8
# - Printed and sold by M. Randall                        8        0       0
# - Printed by C. Randall.                               16        0       0
# -Printed by C. Randall                                  8        0       8
# -Printed by J. Morren                                  16        0       0
# ...                                                   ...      ...     ...
# printed, for the author                                 8        0       8
# re-printed and sold by James Watson                    24        0      24
# reprinted, and sold by most book-sellers in town       20        0       0
# s.n.                                                  272        0     156
# s.n.]                                                 196        0      64
#
#                                                     editor_date  genre  \
# publisher
# (Printed by J. Chalmers & Co. Castlestreet Aber...            8      8
# - Printed and sold by M. Randall                              0      8
# - Printed by C. Randall.                                      0     16
# -Printed by C. Randall                                        8      8
# -Printed by J. Morren                                         0     16
# ...                                                         ...    ...
# printed, for the author                                       0      0
# re-printed and sold by James Watson                           0      0
# reprinted, and sold by most book-sellers in town              0      0
# s.n.                                                         86    256
# s.n.]                                                        40    196
#
#                                                     language  metsXML  \
# publisher
# (Printed by J. Chalmers & Co. Castlestreet Aber...         8        8
# - Printed and sold by M. Randall                           8        8
# - Printed by C. Randall.                                  16       16
# -Printed by C. Randall                                     8        8
# -Printed by J. Morren                                     16       16
# ...                                                      ...      ...
# printed, for the author                                    8        8
# re-printed and sold by James Watson                       24       24
# reprinted, and sold by most book-sellers in town          20       20
# s.n.                                                     272      272
# s.n.]                                                    196      196
#
#                                                     termsOfAddress  \
# publisher
# (Printed by J. Chalmers & Co. Castlestreet Aber...               0
# - Printed and sold by M. Randall                                 0
# - Printed by C. Randall.                                         0
# -Printed by C. Randall                                           0
# -Printed by J. Morren                                            0
# ...                                                            ...
# printed, for the author                                          0
# re-printed and sold by James Watson                              0
# reprinted, and sold by most book-sellers in town                 0
# s.n.                                                            62
# s.n.]                                                            0
#
#                                                     numberOfPages  \
# publisher
# (Printed by J. Chalmers & Co. Castlestreet Aber...              8
# - Printed and sold by M. Randall                                8
# - Printed by C. Randall.                                       16
# -Printed by C. Randall                                          8
# -Printed by J. Morren                                          16
# ...                                                           ...
# printed, for the author                                         8
# re-printed and sold by James Watson                            24
# reprinted, and sold by most book-sellers in town               20
# s.n.                                                          272
# s.n.]                                                         196
#
#                                                     numberOfWords  ...  \
# publisher                                                          ...
# (Printed by J. Chalmers & Co. Castlestreet Aber...              8  ...
# - Printed and sold by M. Randall                                8  ...
# - Printed by C. Randall.                                       16  ...
# -Printed by C. Randall                                          8  ...
# -Printed by J. Morren                                          16  ...
# ...                                                           ...  ...
# printed, for the author                                         8  ...
# re-printed and sold by James Watson                            24  ...
# reprinted, and sold by most book-sellers in town               20  ...
# s.n.                                                          272  ...
# s.n.]                                                         196  ...
#
#                                                     volumeTitle  volumeId  \
# publisher
# (Printed by J. Chalmers & Co. Castlestreet Aber...            8         8
# - Printed and sold by M. Randall                              8         8
# - Printed by C. Randall.                                     16        16
# -Printed by C. Randall                                        8         8
# -Printed by J. Morren                                        16        16
# ...                                                         ...       ...
# printed, for the author                                       8         8
# re-printed and sold by James Watson                          24        24
# reprinted, and sold by most book-sellers in town             20        20
# s.n.                                                        272       272
# s.n.]                                                       196       196
#
#                                                     year  serieNum  part  \
# publisher
# (Printed by J. Chalmers & Co. Castlestreet Aber...     8         8     8
# - Printed and sold by M. Randall                       8         8     8
# - Printed by C. Randall.                              16        16    16
# -Printed by C. Randall                                 8         8     8
# -Printed by J. Morren                                 16        16    16
# ...                                                  ...       ...   ...
# printed, for the author                                8         8     8
# re-printed and sold by James Watson                   24        24    24
# reprinted, and sold by most book-sellers in town      20        20    20
# s.n.                                                 272       272   272
# s.n.]                                                196       196   196
#
#                                                     collectionName  \
# publisher
# (Printed by J. Chalmers & Co. Castlestreet Aber...               8
# - Printed and sold by M. Randall                                 8
# - Printed by C. Randall.                                        16
# -Printed by C. Randall                                           8
# -Printed by J. Morren                                           16
# ...                                                            ...
# printed, for the author                                          8
# re-printed and sold by James Watson                             24
# reprinted, and sold by most book-sellers in town                20
# s.n.                                                           272
# s.n.]                                                          196
#
#                                                     serieTitle  \
# publisher
# (Printed by J. Chalmers & Co. Castlestreet Aber...           8
# - Printed and sold by M. Randall                             8
# - Printed by C. Randall.                                    16
# -Printed by C. Randall                                       8
# -Printed by J. Morren                                       16
# ...                                                        ...
# printed, for the author                                      8
# re-printed and sold by James Watson                         24
# reprinted, and sold by most book-sellers in town            20
# s.n.                                                       272
# s.n.]                                                      196
#
#                                                     publisherPersons  \
# publisher
# (Printed by J. Chalmers & Co. Castlestreet Aber...                 8
# - Printed and sold by M. Randall                                   8
# - Printed by C. Randall.                                          16
# -Printed by C. Randall                                             8
# -Printed by J. Morren                                             16
# ...                                                              ...
# printed, for the author                                            8
# re-printed and sold by James Watson                               24
# reprinted, and sold by most book-sellers in town                  20
# s.n.                                                             272
# s.n.]                                                            196
#
#                                                     numberOfVolumes  volumeNum
# publisher
# (Printed by J. Chalmers & Co. Castlestreet Aber...                8          8
# - Printed and sold by M. Randall                                  8          8
# - Printed by C. Randall.                                         16         16
# -Printed by C. Randall                                            8          8
# -Printed by J. Morren                                            16         16
# ...                                                             ...        ...
# printed, for the author                                           8          8
# re-printed and sold by James Watson                              24         24
# reprinted, and sold by most book-sellers in town                 20         20
# s.n.                                                            272        272
# s.n.]                                                           196        196
#
# [522 rows x 29 columns]

# %%
fig = px.line(df, x="volumeId", y="numberOfPages", title='Number of pages per collection and volume')
fig.show()
# Out:
# <div>                            <div id="8b9d00b2-874a-449b-a337-433d58cc53fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8b9d00b2-874a-449b-a337-433d58cc53fc")) {                    Plotly.newPlot(                        "8b9d00b2-874a-449b-a337-433d58cc53fc",                        [{"hovertemplate":"volumeId=%{x}<br>numberOfPages=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["104184105","104184105","104184105","104184105","104184105","104184105","104184105","104184105","104184106","104184106","104184106","104184106","104184106","104184106","104184106","104184106","104184107","104184107","104184107","104184107","104184107","104184107","104184107","104184107","104184107","104184107","104184107","104184107","104184108","104184108","104184108","104184108","104184108","104184108","104184108","104184108","104184108","104184108","104184108","104184108","104184109","104184109","104184109","104184109","104184109","104184109","104184109","104184109","104184109","104184109","104184109","104184109","104184109","104184109","104184109","104184109","104184110","104184110","104184110","104184110","104184110","104184110","104184110","104184110","104184111","104184111","104184111","104184111","104184111","104184111","104184111","104184111","104184111","104184111","104184111","104184111","104184112","104184112","104184112","104184112","104184112","104184112","104184112","104184112","104184112","104184112","104184112","104184112","104184112","104184112","104184112","104184112","104184112","104184112","104184112","104184112","104184112","104184112","104184112","104184112","104184113","104184113","104184113","104184113","104184113","104184113","104184113","104184113","104184113","104184113","104184113","104184113","104184113","104184113","104184113","104184113","104184113","104184113","104184113","104184113","104184113","104184113","104184113","104184113","104184114","104184114","104184114","104184114","104184114","104184114","104184114","104184114","104184114","104184114","104184114","104184114","104184114","104184114","104184114","104184114","104184115","104184115","104184115","104184115","104184115","104184115","104184115","104184115","104184116","104184116","104184116","104184116","104184116","104184116","104184116","104184116","104184117","104184117","104184117","104184117","104184117","104184117","104184117","104184117","104184118","104184118","104184118","104184118","104184118","104184118","104184118","104184118","104184119","104184119","104184119","104184119","104184119","104184119","104184119","104184119","104184119","104184119","104184119","104184119","104184119","104184119","104184119","104184119","104184119","104184119","104184119","104184119","104184119","104184119","104184119","104184119","104184120","104184120","104184120","104184120","104184120","104184120","104184120","104184120","104184120","104184120","104184120","104184120","104184121","104184121","104184121","104184121","104184121","104184121","104184121","104184121","104184122","104184122","104184122","104184122","104184122","104184122","104184122","104184122","104184122","104184122","104184122","104184122","104184122","104184122","104184122","104184122","104184122","104184122","104184122","104184122","104184122","104184122","104184122","104184122","104184123","104184123","104184123","104184123","104184123","104184123","104184123","104184123","104184123","104184123","104184123","104184123","104184123","104184123","104184123","104184123","104184123","104184123","104184123","104184123","104184123","104184123","104184123","104184123","104184124","104184124","104184124","104184124","104184124","104184124","104184124","104184124 ...

# %%
collection=df.groupby(['serieTitle','volumeId'])['volumeId'].size()
collection
# Out:
# serieTitle                                                           volumeId
#  history of Moll Flanders                                            104184799    24
#                                                                      104186700    24
#  hundred] godly lessons                                              104184318     8
# 'Twas on the morn of sweet May Day                                   104185804     8
#                                                                      104186584     8
#                                                                                   ..
# young lasses' song, or What wou'd a young lassie do wi' an auld man  104184876     8
# young man's dream                                                    104185671     8
# young squire's frolic                                                104185386     8
# young woman's wish                                                   104185681     8
# younger brother or, The sufferings of Saint Andre                    104186596    24
# Name: volumeId, Length: 3080, dtype: int64

# %%
a=df.groupby(['genre', 'volumeId']).size()
a
# Out:
# genre                         volumeId
# Biography                     104184957    144
#                               104184969     48
#                               104186348     48
#                               104186391     30
# Chapbooks-England-1801-1900.  104187077      8
#                                           ...
# letter                        104184120     12
# short story                   104184108     12
#                               104184119     24
#                               104184368     24
# speech                        104185456     24
# Length: 2826, dtype: int64

# %%
a=df.groupby(['place', 'volumeId']).size()
a
# Out:
# place        volumeId
# Aberdeen     104184105     8
#              104184115     8
#              104184118     8
#              104184124     8
#              104184125     8
#                           ..
# Stirling]    104186915     8
#              104186916     8
#              104186917     8
#              104186918     8
# s.n., s.d.]  104185838    20
# Length: 3079, dtype: int64
